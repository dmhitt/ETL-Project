# %%
# Dependencies
import pymongo
import requests
import json
import pandas as pd

# Google developer API key
from config import gkey

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# geocoordinates
target_coordinates = "33.69173830884756,  -118.01170349121094"
target_radius = 10000
target_type = "restaurant"


# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    'sensor':'false',
     "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.69173830884756%2C++-118.01170349121094&radius=10000&type=restaurant&sensor=false&key=AIzaSyBzyFnYZltJKc9RAbuaH8ezzvFQfIDcnXk

# %%
#print(json.dumps(response.json(), indent=4, sort_keys=True))

# %%
 # set up a parameters dictionary
target_next_page_token=response.json()["next_page_token"]
params2 = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    'sensor':False,
    "key": gkey,
    "pagetoken":target_next_page_token
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response2 = requests.get(base_url, params=params2)
print(response2)
print(response2.url)
# Out:
# <Response [200]>
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.69173830884756%2C++-118.01170349121094&radius=10000&type=restaurant&sensor=False&key=AIzaSyBzyFnYZltJKc9RAbuaH8ezzvFQfIDcnXk&pagetoken=ATtYBwKB5l79-FfLbdTtvOO70ufcTrKWlPjVa-zwijHNcxe8jBfmlBMTUWbXD_kNkYqSHY3G0oPqaNsG-xKNcLJkl-hOSHHDWeYlQmUK7qsUTjlw8r41P3hWwUuw4HJv7lsyjUnqMj1Bt-aKfXtTp3rmegUYrnwaOemaYqylQqJ1PE4GdUpWX-bS9yvZ0m7TfdoD7mYsL3cEo3g8BFhFJhFmDLWnd8pgOoZXAZXFmOM9ZXnGKVJc-Wlq7Wtbl4xH1PmUHyOK0LEK-vXCY9gxgEOsHY4gguKwZDUTL0RJCWYWHbKUuQtYLKAmcdmwKWXsEuFGw2fdHGrSKK9bFokD_B8rH2E-T6HqBg8uVxMiSwKnX7UNcbkwRedswoyd4Q1wPppZK8hfVdTJqgewog0-OayRaMyr4sn_TdMuEcJqCHW76c_T457chzwkXxCU3bs

# %%
 # set up a parameters dictionary
target_next_page_token=response2.json()["next_page_token"]
params3 = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    'sensor':False,
    "key": gkey,
    "pagetoken":target_next_page_token
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response3 = requests.get(base_url, params=params3)
print(response3)
print(response3.url)
# Out:
# <Response [200]>
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.69173830884756%2C++-118.01170349121094&radius=10000&type=restaurant&sensor=False&key=AIzaSyBzyFnYZltJKc9RAbuaH8ezzvFQfIDcnXk&pagetoken=ATtYBwJnJwoo9NlDjG2uvjXe27xIaVRdiy_fuu-Si1nnV0hZ0rGWB88i1HEereVuF4U8Wp5wBlIhhPiq13jkgt5v07DFWxs12ClxXrvfC38DpIvlck6A9n3ZFmSi1yXSqLYq25ipMuYQ1Dz7XZZD2pJzE3eAx0_Cx4XD2YwF73FVUzlEa3ESjBG_A0dl0fpM-az6rd0SX-B-DYRB1kZE66qouQcFerUm6hJzEvclZXmcn7u69T1Hka3j_rjyB0_oUe2smlqsyIiHouyZe3pcjb5vKeYPoeRzTJcMoMP5AbMj1CAMd2-g3WD9vp2hpAlctq2Hln4vXPMCzq4sVqeGjc1s3x3MujNk9TF_d1wv8VboE1q6YOKWBZ2kaRPZmD7H9NWWTajOGs0xVn-7wPT1W78LhU08J6sYsT-cgXRCPmP4wqdMU8xg6BIRHt8gh7ulZtxTEeEtH2hjVJD8QhcXE-WwsJ7PrTDurRxdsDvDUUTYPfFwqu46SijHCe4HSB0IT5IZE0ECgpn7tYHnF9HJ49HaCqVhggFAuzJ0u1WMN9erLzqYCoVoEFvuLTnXECsu9pWc0PIR-BLv8SrHEvqT1_NgAtHdv5YCwZDLRoCOvcoPiV8O1S5Z3_zDwX61V1EdnhlSr8BXw0FW5eS5_32H

# %%
#print(target_next_page_token)

# %%
response = requests.get(base_url, params=params)
while response.json().get('status')!='OK':
        from time import sleep
        from random import random
        sleep(random())
        response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()
 
# Print the json (pretty printed)
#print(json.dumps(places_data, indent=4, sort_keys=True))

# %%
#convert response to json
places_data2 = response2.json()
 
# Print the json (pretty printed)
print(json.dumps(places_data2, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwJnJwoo9NlDjG2uvjXe27xIaVRdiy_fuu-Si1nnV0hZ0rGWB88i1HEereVuF4U8Wp5wBlIhhPiq13jkgt5v07DFWxs12ClxXrvfC38DpIvlck6A9n3ZFmSi1yXSqLYq25ipMuYQ1Dz7XZZD2pJzE3eAx0_Cx4XD2YwF73FVUzlEa3ESjBG_A0dl0fpM-az6rd0SX-B-DYRB1kZE66qouQcFerUm6hJzEvclZXmcn7u69T1Hka3j_rjyB0_oUe2smlqsyIiHouyZe3pcjb5vKeYPoeRzTJcMoMP5AbMj1CAMd2-g3WD9vp2hpAlctq2Hln4vXPMCzq4sVqeGjc1s3x3MujNk9TF_d1wv8VboE1q6YOKWBZ2kaRPZmD7H9NWWTajOGs0xVn-7wPT1W78LhU08J6sYsT-cgXRCPmP4wqdMU8xg6BIRHt8gh7ulZtxTEeEtH2hjVJD8QhcXE-WwsJ7PrTDurRxdsDvDUUTYPfFwqu46SijHCe4HSB0IT5IZE0ECgpn7tYHnF9HJ49HaCqVhggFAuzJ0u1WMN9erLzqYCoVoEFvuLTnXECsu9pWc0PIR-BLv8SrHEvqT1_NgAtHdv5YCwZDLRoCOvcoPiV8O1S5Z3_zDwX61V1EdnhlSr8BXw0FW5eS5_32H",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.71428,
#                     "lng": -117.989525
#                 },
#                 "viewport": {
# ...

# %%
#convert response to json
places_data3 = response3.json()
 
# Print the json (pretty printed)
print(json.dumps(places_data3, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 33.7158811,
#                     "lng": -118.0426453
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.7170979802915,
#                         "lng": -118.0413881697085
#                     },
#                     "southwest": {
#                         "lat": 33.7144000197085,
#                         "lng": -118.0440861302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Buon Gusto",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2218,
# ...

# %%
#print(response.json()['next_page_token'])

# %%
places_data["results"][3].keys()
# Out:
# dict_keys(['business_status', 'geometry', 'icon', 'name', 'opening_hours', 'photos', 'place_id', 'plus_code', 'price_level', 'rating', 'reference', 'scope', 'types', 'user_ratings_total', 'vicinity'])

# %%
result_ready  = places_data['results'][0]
for item in result_ready.keys():
    print(item)
    #print(result_ready[item])
    #print('')
# Out:
# business_status
# geometry
# icon
# name
# opening_hours
# photos
# place_id
# plus_code
# price_level
# rating
# reference
# scope
# types
# user_ratings_total
# vicinity

# %%
# Define the 'restaurant_db' database in Mongo
db = client.restaurant_db

# %%
# Declare the collection
result = db.result

# %%
for biz in places_data['results']:
    name = biz['name']
    address = biz['vicinity']
    
        
    post = {
        'name': name,
        'address': address,
               
    }

    result.insert_one(post)

# %%
df=pd.DataFrame(places_data['results'])
df
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 33.7341503, 'lng': -117.9...
# 1          OPERATIONAL  {'location': {'lat': 33.6907124, 'lng': -117.9...
# 2          OPERATIONAL  {'location': {'lat': 33.65664439999999, 'lng':...
# 3          OPERATIONAL  {'location': {'lat': 33.732545, 'lng': -117.99...
# 4          OPERATIONAL  {'location': {'lat': 33.7296127, 'lng': -117.9...
# 5          OPERATIONAL  {'location': {'lat': 33.7586417, 'lng': -118.0...
# 6          OPERATIONAL  {'location': {'lat': 33.69599830000001, 'lng':...
# 7          OPERATIONAL  {'location': {'lat': 33.73047, 'lng': -117.995...
# 8          OPERATIONAL  {'location': {'lat': 33.6839637, 'lng': -117.9...
# 9          OPERATIONAL  {'location': {'lat': 33.71207810000001, 'lng':...
# 10         OPERATIONAL  {'location': {'lat': 33.69607999999999, 'lng':...
# 11         OPERATIONAL  {'location': {'lat': 33.71803930000001, 'lng':...
# ...

# %%
df.count()
# Out:
# business_status       20
# geometry              20
# icon                  20
# name                  20
# opening_hours         19
# photos                20
# place_id              20
# plus_code             20
# price_level           19
# rating                20
# reference             20
# scope                 20
# types                 20
# user_ratings_total    20
# vicinity              20
# permanently_closed     1
# dtype: int64

# %%
#df.to_csv("restaurants.csv")

# %%
#type(places_data)

# %%
df2=pd.DataFrame(places_data2['results'])

# %%
#df2.to_csv("restaurants.csv")

# %%
df3=pd.DataFrame(places_data3['results'])
df3
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 33.7158811, 'lng': -118.0...
# 1          OPERATIONAL  {'location': {'lat': 33.7160049, 'lng': -117.9...
# 2          OPERATIONAL  {'location': {'lat': 33.7148153, 'lng': -118.0...
# 3          OPERATIONAL  {'location': {'lat': 33.7367674, 'lng': -118.0...
# 4          OPERATIONAL  {'location': {'lat': 33.6811111, 'lng': -117.9...
# 5          OPERATIONAL  {'location': {'lat': 33.6282768, 'lng': -117.9...
# 6          OPERATIONAL  {'location': {'lat': 33.703107, 'lng': -117.95...
# 7   CLOSED_TEMPORARILY  {'location': {'lat': 33.72982820000001, 'lng':...
# 8          OPERATIONAL  {'location': {'lat': 33.6581485, 'lng': -117.9...
# 9          OPERATIONAL  {'location': {'lat': 33.69180729999999, 'lng':...
# 10         OPERATIONAL  {'location': {'lat': 33.7042857, 'lng': -117.9...
# 11         OPERATIONAL  {'location': {'lat': 33.7295905, 'lng': -118.0...
# ...

# %%
#df3.to_csv("restaurants.csv")
df3.count()
# Out:
# business_status       20
# geometry              20
# icon                  20
# name                  20
# opening_hours         19
# photos                20
# place_id              20
# plus_code             20
# price_level           20
# rating                20
# reference             20
# scope                 20
# types                 20
# user_ratings_total    20
# vicinity              20
# permanently_closed     1
# dtype: int64

# %%
df_row=pd.concat([df,df2,df3])

# %%
df_row
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 33.7341503, 'lng': -117.9...
# 1          OPERATIONAL  {'location': {'lat': 33.6907124, 'lng': -117.9...
# 2          OPERATIONAL  {'location': {'lat': 33.65664439999999, 'lng':...
# 3          OPERATIONAL  {'location': {'lat': 33.732545, 'lng': -117.99...
# 4          OPERATIONAL  {'location': {'lat': 33.7296127, 'lng': -117.9...
# 5          OPERATIONAL  {'location': {'lat': 33.7586417, 'lng': -118.0...
# 6          OPERATIONAL  {'location': {'lat': 33.69599830000001, 'lng':...
# 7          OPERATIONAL  {'location': {'lat': 33.73047, 'lng': -117.995...
# 8          OPERATIONAL  {'location': {'lat': 33.6839637, 'lng': -117.9...
# 9          OPERATIONAL  {'location': {'lat': 33.71207810000001, 'lng':...
# 10         OPERATIONAL  {'location': {'lat': 33.69607999999999, 'lng':...
# 11         OPERATIONAL  {'location': {'lat': 33.71803930000001, 'lng':...
# ...

# %%
df_row.to_csv("restaurants4.csv")

# %%
type(df_row)
# Out:
# pandas.core.frame.DataFrame

# %%
df_row()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-c3ef5c56e1b2> in <module>
# ----> 1 df_row()
#
# TypeError: 'DataFrame' object is not callable

# %%
df_row.count()
# Out:
# business_status       60
# geometry              60
# icon                  60
# name                  60
# opening_hours         57
# photos                60
# place_id              60
# plus_code             60
# price_level           59
# rating                60
# reference             60
# scope                 60
# types                 60
# user_ratings_total    60
# vicinity              60
# permanently_closed     3
# dtype: int64

# %%
type(df_row)
# Out:
# pandas.core.frame.DataFrame
