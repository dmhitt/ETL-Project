# %% [markdown]
# # Project ETL
# * Get reaturant data from Yelp using the API
# * Insert te data in a dataframe
# * Do some clean up
# * Insert data into MongoDB
# * Get restaurant reviews from Yelp doing another API call
# * Insert the Yelp reviews into MongoDB
# * Get restaurant reviews from Google
# * Insert Google Reviews into MongoDB

# %%
import pymongo
import requests
import json
import pandas as pd

from config import api_key
from config import gkey

from yelpapi import YelpAPI
yelp_api = YelpAPI(api_key)

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %% [markdown]
# ## Yelp API Call - Retrieve first 50 restaurants

# %%
term = 'Fast Food'
#location = 'Huntington Beach, CA'
search_limit = 50
latitude = 33.69173830884756
longitude = -118.01170349121094
radius = 10000
responses = yelp_api.search_query(term = term,
                                 limit = search_limit,
                                 #location = location,   
                                 latitude = latitude,
                                 longitude = longitude,
                                 radius = radius
                                )
total = responses['total']
print (total)
# Out:
# 731

# %%
#Insert first 50 restaurants into the data_businesses Dataframe
cols = list(responses['businesses'][0].keys())
data_businesses = pd.DataFrame(columns=cols)
for biz in responses['businesses']:
    data_businesses = data_businesses.append(biz, ignore_index=True)

# %%
data_businesses.head()
# Out:
#                        id                                       alias  \
# 0  MT5fR6lbW1_T965F2m_0iA          jay-birds-chicken-huntington-beach
# 1  ia09aCVFnDFwoRweRwhcLQ                     bunz-huntington-beach-3
# 2  UgMxuIEzFxFFNzIYGypq1Q                   chick-fil-a-westminster-5
# 3  _eQYxkulx7KfPxxFa-RsZQ  northside-market-and-deli-huntington-beach
# 4  Ex9SF7GmB-io1Dk3kLASVg            in-n-out-burger-huntington-beach
#
#                         name  \
# 0         Jay Bird's Chicken
# 1                       Bunz
# 2                Chick-fil-A
# 3  Northside Market and Deli
# 4            In-N-Out Burger
#
#                                            image_url is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/ErcH-I...     False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/gekf12...     False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/0olxU9...     False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/307ewG...     False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/upwGSc...     False
#
#                                                  url review_count  \
# 0  https://www.yelp.com/biz/jay-birds-chicken-hun...          202
# 1  https://www.yelp.com/biz/bunz-huntington-beach...         1428
# 2  https://www.yelp.com/biz/chick-fil-a-westminst...          463
# 3  https://www.yelp.com/biz/northside-market-and-...           76
# 4  https://www.yelp.com/biz/in-n-out-burger-hunti...          539
#
#                                           categories  rating  \
# 0  [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.5
# 1  [{'alias': 'hotdog', 'title': 'Hot Dogs'}, {'a...     4.5
# 2  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     3.5
# 3  [{'alias': 'beer_and_wine', 'title': 'Beer, Wi...     5.0
# 4  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
#
#                                          coordinates        transactions  \
# 0    {'latitude': 33.65868, 'longitude': -117.99952}                  []
# 1  {'latitude': 33.733991, 'longitude': -117.998171}  [delivery, pickup]
# 2  {'latitude': 33.7260145, 'longitude': -117.988...          [delivery]
# 3    {'latitude': 33.66678, 'longitude': -118.01087}          [delivery]
# 4  {'latitude': 33.700393, 'longitude': -117.988632}                  []
#
#                                             location         phone  \
# 0  {'address1': '303 3rd St', 'address2': 'Ste 10...  +17145943233
# 1  {'address1': '7491 Center Ave', 'address2': No...  +17147667060
# 2  {'address1': '16388 Beach Blvd', 'address2': '...  +17148473847
# 3  {'address1': '301 17th St', 'address2': None, ...  +17149606600
# 4  {'address1': '18062 Beach Blvd', 'address2': '...  +18007861000
#
#     display_phone     distance price
# 0  (714) 594-3233  3842.134254   NaN
# 1  (714) 766-7060  4862.155711     $
# 2  (714) 847-3847  4363.484471     $
# 3  (714) 960-6600  2778.451318     $
# 4  (800) 786-1000  2341.339239     $

# %% [markdown]
# ## Yelp API Call - Retrieve rest of restaurants

# %%
count_retrive = 50
total = 200
while count_retrive < total :
    term = 'Fast Food'
    search_limit = 50
    #location = 'Huntington Beach, CA'
    latitude = 33.69173830884756
    longitude = -118.01170349121094
    radius = 10000
    offset = 50
    responses = yelp_api.search_query(term = term,
                                 limit = search_limit,
                                 #location = location,
                                 latitude = latitude,
                                 longitude = longitude,
                                 radius = radius,
                                 offset = offset
                                )

    for biz in responses['businesses']:
        data_businesses = data_businesses.append(biz, ignore_index=True)

    count_retrive += 50

# %%
data_businesses.count()
# Out:
# id               200
# alias            200
# name             200
# image_url        200
# is_closed        200
# url              200
# review_count     200
# categories       200
# rating           200
# coordinates      200
# transactions     200
# location         200
# phone            200
# display_phone    200
# distance         200
# price            180
# dtype: int64

# %%
data_businesses.tail(50)
# Out:
#                          id  \
# 150  zuo-A4AbQRCfPFk3dio10A
# 151  VK5srLzMW_P9K1E7DrcPVA
# 152  SM-5ZmkSX4b0cUxnP_ay-w
# 153  -E3RrsOr4QUIr_q-sS1D4g
# 154  YurnRnzUFPL7k5btLfVMaw
# 155  -H1-4ZODbynAqOa6EmixNQ
# 156  8oRP81DNGbA9wkdw4QvIIg
# 157  h5hYd_5PTMGH_XJsdklIEw
# 158  3kuIMzYI1ThSftPshoWsiA
# 159  3lwmVFaw6g1FjGt_EnHZ1Q
# 160  3PW6Anukdx0NOvTQaZBg7w
# 161  jWB3VgArM7Ch8WBUwW6r1w
# 162  vO1JtdKhSJ-KwfeeQNf7GA
# 163  ioQdWB9hvEYsrHqY5von_A
# 164  epw2LIQnhHfLPIa91ODrkw
# 165  IuxPziF-7wOf1BLcl8XEzA
# 166  xKNP6I6XX_JXvwrvkZFVWw
# 167  rnXENEX9JjGkmPc0gNBmUw
# 168  IUeOwfhDxqF3gO2XlM25Ew
# 169  QzOEaVOo4KD5fGOoBKyhvQ
# 170  licoIh_57cAZZHYFtkWqvw
# 171  _R33Udm4pR1he2MoCkGjRw
# 172  xq67cUnXjpD-7cuzv5KE3A
# 173  SagMuhaLcv4_GQTKDgeznQ
# 174  TABZVlhoRakyDCLnQW0kLg
# 175  hIAwfe5zfJPdGTbuvNQ9XA
# 153   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     4.5
# 154  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     2.5
# 155  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 156  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 157  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     3.5
# 158  [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.0
# 159  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.5
# 160  [{'alias': 'mediterranean', 'title': 'Mediterr...     4.5
# 161  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     3.0
# 162         [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
# 163  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     4.0
# 164  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.0
# 165  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 166  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     2.5
# 167  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.0
# 168  [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.0
# 169  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.0
# 170  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.5
# 171  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     4.5
# 172  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.5
# 173  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.0
# 174  [{'alias': 'tradamerican', 'title': 'American ...     3.0
# 175  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...     5.0
# 176  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.0
# 177  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     3.0
# 178  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.0
# 179  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.5
# 180  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...     4.5
# 181  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 182  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 183  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.5
# 184  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.5
# 185         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 186  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...     4.5
# 187         [{'alias': 'burgers', 'title': 'Burgers'}]     3.5
# 188  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
# 189  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.5
# 190         [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
# 191  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.5
# 192  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5
# 193  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 194  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     4.5
# 195  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 196  [{'alias': 'foodstands', 'title': 'Food Stands...     3.5
# 197  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5
# 198  [{'alias': 'chicken_wings', 'title': 'Chicken ...     2.5
# 199  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.0
#
#                                            coordinates        transactions  \
# 150  {'latitude': 33.687335, 'longitude': -117.953815}          [delivery]
# 151  {'latitude': 33.7090097, 'longitude': -117.989...          [delivery]
# 152   {'latitude': 33.680653, 'longitude': -118.00446}  [pickup, delivery]
# 153     {'latitude': 33.71513, 'longitude': -117.9905}          [delivery]
# 154  {'latitude': 33.6928501, 'longitude': -117.989...  [pickup, delivery]
# 155  {'latitude': 33.6918073, 'longitude': -117.989...          [delivery]
# 156  {'latitude': 33.734568, 'longitude': -117.997137}  [pickup, delivery]
# 157    {'latitude': 33.73049, 'longitude': -118.01476}  [pickup, delivery]
# 158  {'latitude': 33.6844454803127, 'longitude': -1...  [pickup, delivery]
# 159  {'latitude': 33.729202, 'longitude': -118.006337}          [delivery]
# 160  {'latitude': 33.6732780456456, 'longitude': -1...          [delivery]
# 161  {'latitude': 33.6819805, 'longitude': -117.988...          [delivery]
# 162  {'latitude': 33.657094, 'longitude': -117.987319}          [delivery]
# 163  {'latitude': 33.7156762105983, 'longitude': -1...  [pickup, delivery]
# 164  {'latitude': 33.6848391759678, 'longitude': -1...  [pickup, delivery]
# 165  {'latitude': 33.6760442, 'longitude': -117.988...  [pickup, delivery]
# 166  {'latitude': 33.680663, 'longitude': -118.0044...          [delivery]
# 167    {'latitude': 33.71722, 'longitude': -117.98864}          [delivery]
# 168    {'latitude': 33.63585, 'longitude': -117.91853}  [pickup, delivery]
# 169  {'latitude': 33.6912900640998, 'longitude': -1...          [delivery]
# 170  {'latitude': 33.729671, 'longitude': -118.023292}          [delivery]
# 171    {'latitude': 33.71626, 'longitude': -118.00246}  [pickup, delivery]
# 172  {'latitude': 33.679168, 'longitude': -117.988113}  [pickup, delivery]
# 173  {'latitude': 33.715732, 'longitude': -118.038709}          [delivery]
# 174  {'latitude': 33.7760700644352, 'longitude': -1...                  []
# 175  {'latitude': 33.64324383, 'longitude': -117.92...  [pickup, delivery]
# 176   {'latitude': 33.716155, 'longitude': -117.99079}  [pickup, delivery]
# 177  {'latitude': 33.6918812634702, 'longitude': -1...  [pickup, delivery]
# 178  {'latitude': 33.7158141563885, 'longitude': -1...          [delivery]
# 179  {'latitude': 33.6850142059601, 'longitude': -1...  [pickup, delivery]
# 180    {'latitude': 33.72361, 'longitude': -117.96365}  [pickup, delivery]
# 181  {'latitude': 33.6802631908106, 'longitude': -1...                  []
# 182    {'latitude': 33.72993, 'longitude': -117.99804}  [pickup, delivery]
# 183   {'latitude': 33.742688, 'longitude': -118.00645}          [delivery]
# 184  {'latitude': 33.7165108, 'longitude': -117.971...  [pickup, delivery]
# 185  {'latitude': 33.7233235069998, 'longitude': -1...          [delivery]
# 186  {'latitude': 33.7152859953738, 'longitude': -1...  [pickup, delivery]
# 187    {'latitude': 33.71598, 'longitude': -118.00045}  [pickup, delivery]
# 188  {'latitude': 33.72490133, 'longitude': -117.98...  [pickup, delivery]
# 189    {'latitude': 33.70262, 'longitude': -117.95382}          [delivery]
# 190  {'latitude': 33.730479, 'longitude': -117.995955}  [pickup, delivery]
# 191  {'latitude': 33.725616, 'longitude': -117.989692}          [delivery]
# 192  {'latitude': 33.6677035393026, 'longitude': -1...          [delivery]
# 193    {'latitude': 33.71429, 'longitude': -117.98953}  [pickup, delivery]
# 194  {'latitude': 33.7002731859684, 'longitude': -1...  [pickup, delivery]
# 195  {'latitude': 33.658492, 'longitude': -118.001519}  [pickup, delivery]
# 196  {'latitude': 33.6523845, 'longitude': -117.994...          [delivery]
# 197    {'latitude': 33.72227, 'longitude': -118.04037}          [delivery]
# 198  {'latitude': 33.65698783, 'longitude': -117.98...  [pickup, delivery]
# 199    {'latitude': 33.72216, 'longitude': -118.04085}                  []
#
#                                               location         phone  \
# 150  {'address1': '18976 Brookhurst St', 'address2'...  +17144082492
# 151  {'address1': '17451 Beach Blvd', 'address2': '...  +17148614088
# 152  {'address1': '7101 W Yorktown Ave Bldg 3 Ste 1...  +17145369776
# 153  {'address1': '7862 Warner Ave', 'address2': 'S...  +17148471113
# 154  {'address1': '18575 Beach Blvd', 'address2': '...  +17143759338
# 155  {'address1': '18645 Beach Blvd', 'address2': '...  +17148614448
# 156  {'address1': '7561 Center Ave', 'address2': 'S...  +17148952800
# 157  {'address1': '6531 Edinger Ave', 'address2': '...  +17148922900
# 158  {'address1': '19092 Beach Blvd', 'address2': '...  +17145934111
# 159  {'address1': '16082 Goldenwest St.', 'address2...  +17148483993
# 160  {'address1': '19893 Brookhurst St', 'address2'...  +17149647482
# 161  {'address1': '19320 Beach Blvd', 'address2': '...  +17149628500
# 162  {'address1': '21032 Beach Blvd', 'address2': N...  +17145362616
# 163  {'address1': '5183 Warner Ave', 'address2': ''...  +17148407971
# 164  {'address1': '19125 Goldenwest St', 'address2'...  +17143748505
# 165  {'address1': '19752 Beach Blvd', 'address2': '...  +17145936400
# 166  {'address1': '7101 Yorktown Ave', 'address2': ...  +16572047171
# 167  {'address1': '16866 Beach Blvd', 'address2': '...  +17148481361
# 168  {'address1': '196 E 17th St', 'address2': '', ...  +19493835040
# 169  {'address1': '18691 Brookhurst St', 'address2'...  +17149682448
# 170  {'address1': '6042 Edinger Ave', 'address2': '...  +17148462235
# 171  {'address1': '7251 Warner Ave', 'address2': 'S...  +16573013033
# 172  {'address1': '19512 Beach Blvd', 'address2': '...  +17149687374
# 173  {'address1': '5171 Warner Ave', 'address2': ''...  +17146254305
# 174  {'address1': '12775 Beach Blvd', 'address2': '...  +17143730188
# 175  {'address1': '615 W 19th St', 'address2': None...  +19014683426
# 176  {'address1': '7891 Warner Ave', 'address2': ''...  +17148470555
# 177  {'address1': '18641 Beach Blvd', 'address2': '...  +17143759222
# 178  {'address1': '5095 Warner Ave', 'address2': ''...  +17143779201
# 187  (714) 842-1551   2879.662166     $
# 188  (714) 622-5938   4382.153086    $$
# 189  (714) 964-2022   5488.094763     $
# 190  (714) 890-6100   4546.439985     $
# 191  (714) 841-4984   4272.103496     $
# 192  (714) 969-7689   2683.142327     $
# 193  (714) 594-5730   3239.081087    $$
# 194  (714) 377-0718   3812.516739    $$
# 195  (714) 960-2525   3815.052798    $$
# 196  (714) 969-1000   4793.398311     $
# 197  (562) 592-0050   4294.775567     $
# 198  (714) 374-0077   4438.993843   NaN
# 199  (714) 377-0238   4332.591942     $

# %% [markdown]
# # Insert Business into MongoDB

# %%
# Define the 'restaurantes_db' database in Mongo
db = client.restaurants5_db

# Declare the collections
business = db.business
reviews = db.reviews

records = json.loads(data_businesses.T.to_json()).values()
db.business.insert_many(records)

#records = json.loads(data_review.T.to_json()).values()
#db.reviews.insert_many(records)

# %%
#responses_review = yelp_api.reviews_query(id = 'ObCj8Y3KAdk4bgc8oSxNcA')
       
#responses_review

# %% [markdown]
# # New API Call to Retrieve the Reviews

# %%
first_time = True

for index, row in data_businesses.iterrows():
    
    id_business =  row['id']
    responses_review = yelp_api.reviews_query(id = id_business)
    if first_time:
        print (f'index = {index}')
        cols = list(responses_review['reviews'][0].keys())
        cols.append('id_reviews')
        print(cols)
        data_reviews = pd.DataFrame(columns=cols)
        first_time = False

    
    for resp in responses_review['reviews']:
        #print (f"resp = {resp}")
        my_row = {"id":id_business, 
                "url":resp['url'],
                "text":resp['text'],
                "rating":resp['rating'],
                "time_created":resp['time_created'],
                "user":resp['user'],
                "id_reviews":resp['id']}                    
        #my_row.append(id_business)
        #print (f"my_row = {my_row}")
        #print ('----')
        data_reviews=data_reviews.append(my_row, ignore_index=True)
        my_row.clear()
        
     
print (f'index = {index}')
# Out:
# index = 0
# ['id', 'url', 'text', 'rating', 'time_created', 'user', 'id_reviews']
# index = 199

# %%
data_reviews.count()
total_reviews=(len(data_reviews))
print(total_reviews)
# Out:
# 600

# %%
data_reviews.head(10)
# Out:
#                        id                                                url  \
# 0  MT5fR6lbW1_T965F2m_0iA  https://www.yelp.com/biz/jay-birds-chicken-hun...
# 1  MT5fR6lbW1_T965F2m_0iA  https://www.yelp.com/biz/jay-birds-chicken-hun...
# 2  MT5fR6lbW1_T965F2m_0iA  https://www.yelp.com/biz/jay-birds-chicken-hun...
# 3  ia09aCVFnDFwoRweRwhcLQ  https://www.yelp.com/biz/bunz-huntington-beach...
# 4  ia09aCVFnDFwoRweRwhcLQ  https://www.yelp.com/biz/bunz-huntington-beach...
# 5  ia09aCVFnDFwoRweRwhcLQ  https://www.yelp.com/biz/bunz-huntington-beach...
# 6  UgMxuIEzFxFFNzIYGypq1Q  https://www.yelp.com/biz/chick-fil-a-westminst...
# 7  UgMxuIEzFxFFNzIYGypq1Q  https://www.yelp.com/biz/chick-fil-a-westminst...
# 8  UgMxuIEzFxFFNzIYGypq1Q  https://www.yelp.com/biz/chick-fil-a-westminst...
# 9  _eQYxkulx7KfPxxFa-RsZQ  https://www.yelp.com/biz/northside-market-and-...
#
#                                                 text rating  \
# 0  Jay Bird, Jay Bird, Jay Bird it's been over a ...      5
# 1  I saw this new Nashville fried chicken place o...      5
# 2  Lexi was very sweet and patient with taking my...      5
# 3  Delicious food and great prices! There's a cou...      5
# 4  Burger heaven! \n\nThis burger spot is by far ...      5
# 5  11/20/2020\n\nOrdered: Hot Dog with Tator Tots...      5
# 6  My wife was craving chicken strips on our way ...      4
# 7  Excellent customer service at this location! \...      5
# 8  I was too hungry and realized half way through...      4
# 9  Here's the Breakfast Burrito with bacon! Look ...      5
#
#           time_created                                               user  \
# 0  2021-03-14 19:25:06  {'id': 'iyYt7prBddpgzn-Bjvr46w', 'profile_url'...
# 1  2020-09-11 06:06:06  {'id': 'o1_sfJ71nrq5QrF00v3Icw', 'profile_url'...
# 2  2021-04-12 19:01:08  {'id': 'r9XjsmIlut1ESyKcvTFF0g', 'profile_url'...
# 3  2021-06-05 08:35:06  {'id': 'GCcKZJPv5yG-5FDy5j9o5g', 'profile_url'...
# 4  2021-06-02 18:30:31  {'id': 'IBBHLd17cmV1fWMvFQ2oKQ', 'profile_url'...
# 5  2020-11-20 17:10:25  {'id': 'h7PKDxa9gNC8eiG74jNK_g', 'profile_url'...
# 6  2021-06-06 09:54:49  {'id': 'oc-q0gmDavL9VEnVn2kXOw', 'profile_url'...
# 7  2021-03-25 10:14:34  {'id': '6ZESWC8WJPPuvO-iEKg4lQ', 'profile_url'...
# 8  2021-03-04 14:16:44  {'id': 'iC7qs8QxrARe1ZBLMZg52w', 'profile_url'...
# 9  2021-01-24 09:50:20  {'id': 'hbnAt2nZ_ghqKIYCKQ_HBg', 'profile_url'...
#
#                id_reviews
# 0  ivuGEgkInt1n3q_5rSTxmQ
# 1  NkUxPNSJQ7_DU6wqxVWqOQ
# 2  Cml6UwDSnfaiIEYlne_fuA
# 3  rHoDeJS-WAVK9zBIwJUMtw
# 4  iS5meY21vCQCNpUXNPJqqg
# 5  Ktpau5GsrB7lyznuSpbGug
# 6  HGiefi__V1Fo9wpB8Qb9zg
# 7  3HwImM46e8z6Hcg7BtKEZw
# 8  PTsUS1wd3HstR-lQNMVU3A
# 9  eIyRZIu5kkSnZiS8XbnJnw

# %%
#data_reviews_bus_id = data_reviews.iloc[:,0]
#data_reviews_bus_id.head()

# %%
data_reviews_all = data_reviews.iloc[:,1:7]
data_reviews_all.head()
# Out:
#                                                  url  \
# 0  https://www.yelp.com/biz/jay-birds-chicken-hun...
# 1  https://www.yelp.com/biz/jay-birds-chicken-hun...
# 2  https://www.yelp.com/biz/jay-birds-chicken-hun...
# 3  https://www.yelp.com/biz/bunz-huntington-beach...
# 4  https://www.yelp.com/biz/bunz-huntington-beach...
#
#                                                 text rating  \
# 0  Jay Bird, Jay Bird, Jay Bird it's been over a ...      5
# 1  I saw this new Nashville fried chicken place o...      5
# 2  Lexi was very sweet and patient with taking my...      5
# 3  Delicious food and great prices! There's a cou...      5
# 4  Burger heaven! \n\nThis burger spot is by far ...      5
#
#           time_created                                               user  \
# 0  2021-03-14 19:25:06  {'id': 'iyYt7prBddpgzn-Bjvr46w', 'profile_url'...
# 1  2020-09-11 06:06:06  {'id': 'o1_sfJ71nrq5QrF00v3Icw', 'profile_url'...
# 2  2021-04-12 19:01:08  {'id': 'r9XjsmIlut1ESyKcvTFF0g', 'profile_url'...
# 3  2021-06-05 08:35:06  {'id': 'GCcKZJPv5yG-5FDy5j9o5g', 'profile_url'...
# 4  2021-06-02 18:30:31  {'id': 'IBBHLd17cmV1fWMvFQ2oKQ', 'profile_url'...
#
#                id_reviews
# 0  ivuGEgkInt1n3q_5rSTxmQ
# 1  NkUxPNSJQ7_DU6wqxVWqOQ
# 2  Cml6UwDSnfaiIEYlne_fuA
# 3  rHoDeJS-WAVK9zBIwJUMtw
# 4  iS5meY21vCQCNpUXNPJqqg

# %%
key_business = "O111111111111111aaaaaA"


for ind, row in data_reviews.iterrows():
           
    if key_business !=  row['id']:
        key_business =  row['id']
        #print ('---here----')
        #print(key_business)
        dict_reviews_all=dict(data_reviews_all.iloc[ind])
        db.business.update_one(
           { 'id': key_business },
           { '$set': {"reviews_person":[dict_reviews_all]}}
        )
        
    else:
        #print('----2---')
        #print(key_business)
        dict_reviews_all=dict(data_reviews_all.iloc[ind])
        #print(dict_reviews)
        db.business.update_one(
           { 'id': key_business },
           { '$push': {"reviews_person":dict_reviews_all}}
        )
        
        
    
   
print (ind)
# Out:
# 599

# %% [markdown]
# ## Google Retrieve Resturant Information

# %%
# geocoordinates
target_coordinates = "33.69173830884756,  -118.01170349121094"
target_radius = 10000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    'sensor':False,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
places_data = response.json()
# print the response url, avoid doing for public github repos in order to avoid exposing key
#print(response.url)
#print(json.dumps(places_data, indent=4, sort_keys=True))

# %%
 # set up a parameters dictionary
target_next_page_token=response.json()["next_page_token"]
params2 = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    'sensor':False,
    "key": gkey,
    "pagetoken":target_next_page_token
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response2 = requests.get(base_url, params=params2)
places_data2 = response2.json()
#print(response2)
#print(response2.url)

# %%
 # set up a parameters dictionary
target_next_page_token=response2.json()["next_page_token"]
params3 = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    'sensor':False,
    "key": gkey,
    "pagetoken":target_next_page_token
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response3 = requests.get(base_url, params=params3)
places_data3 = response3.json()
#print(response3)
#print(response3.url)

# %%
df=pd.DataFrame(places_data['results'])
df.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 33.7341503, 'lng': -117.9...
# 1     OPERATIONAL  {'location': {'lat': 33.6907124, 'lng': -117.9...
# 2     OPERATIONAL  {'location': {'lat': 33.65664439999999, 'lng':...
# 3     OPERATIONAL  {'location': {'lat': 33.732545, 'lng': -117.99...
# 4     OPERATIONAL  {'location': {'lat': 33.7296127, 'lng': -117.9...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                name       opening_hours  \
# 0  Buca di Beppo Italian Restaurant  {'open_now': True}
# 1             Hooters of Costa Mesa  {'open_now': True}
# 2           Duke's Huntington Beach  {'open_now': True}
# 3            The Cheesecake Factory  {'open_now': True}
# 4       BJ's Restaurant & Brewhouse  {'open_now': True}
#
#                                               photos  \
# 0  [{'height': 3024, 'html_attributions': ['<a hr...
# 1  [{'height': 3024, 'html_attributions': ['<a hr...
# 2                                                NaN
# 3  [{'height': 3024, 'html_attributions': ['<a hr...
# 4  [{'height': 1836, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJP5s8IkIm3YARpSuO--EX3f8
# 1  ChIJ6_qtJVTf3IARdsI3DGEHn_c
# 2  ChIJg6yePEIh3YAR9jvzwIJzPoA
# 3  ChIJaRncL0Mm3YARs9osub8nU1s
# 4  ChIJ2ynLWlsm3YARmvBfFo6_vMQ
#
#                                            plus_code  price_level  rating  \
# 0  {'compound_code': 'P2M4+MV Huntington Beach, C...          2.0     4.1
# 1  {'compound_code': 'M3RH+7H Costa Mesa, CA, USA...          2.0     4.0
# 2  {'compound_code': 'MX4X+M5 Huntington Beach, C...          2.0     4.5
# 3  {'compound_code': 'P2M5+29 Huntington Beach, C...          2.0     4.3
# 4  {'compound_code': 'P2H6+RJ Huntington Beach, C...          2.0     4.1
#
#                      reference   scope  \
# 0  ChIJP5s8IkIm3YARpSuO--EX3f8  GOOGLE
# 1  ChIJ6_qtJVTf3IARdsI3DGEHn_c  GOOGLE
# 2  ChIJg6yePEIh3YAR9jvzwIJzPoA  GOOGLE
# 3  ChIJaRncL0Mm3YARs9osub8nU1s  GOOGLE
# 4  ChIJ2ynLWlsm3YARmvBfFo6_vMQ  GOOGLE
#
#                                                types  user_ratings_total  \
# 0  [restaurant, food, point_of_interest, establis...                1443
# 1  [bar, restaurant, food, point_of_interest, est...                 897
# 2  [bar, restaurant, food, point_of_interest, est...                3389
# 3  [restaurant, meal_takeaway, food, point_of_int...                1826
# 4  [restaurant, bar, food, point_of_interest, est...                1420
#
#                                       vicinity permanently_closed
# 0         7979 Center Avenue, Huntington Beach                NaN
# 1           1507 South Coast Drive, Costa Mesa                NaN
# 2  317 Pacific Coast Highway, Huntington Beach                NaN
# 3        7871 Edinger Avenue, Huntington Beach                NaN
# 4      16060 Beach Boulevard, Huntington Beach                NaN

# %%
df2=pd.DataFrame(places_data2['results'])
df2
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 33.71428, 'lng': -117.989...
# 1          OPERATIONAL  {'location': {'lat': 33.715174, 'lng': -117.99...
# 2          OPERATIONAL  {'location': {'lat': 33.7437675, 'lng': -118.0...
# 3          OPERATIONAL  {'location': {'lat': 33.6718122, 'lng': -117.9...
# 4          OPERATIONAL  {'location': {'lat': 33.658093, 'lng': -118.00...
# 5          OPERATIONAL  {'location': {'lat': 33.6575026, 'lng': -118.0...
# 6          OPERATIONAL  {'location': {'lat': 33.709315, 'lng': -117.98...
# 7          OPERATIONAL  {'location': {'lat': 33.6907053, 'lng': -117.9...
# 8          OPERATIONAL  {'location': {'lat': 33.6857394, 'lng': -118.0...
# 9          OPERATIONAL  {'location': {'lat': 33.71718, 'lng': -117.989...
# 10         OPERATIONAL  {'location': {'lat': 33.6582174, 'lng': -118.0...
# 11         OPERATIONAL  {'location': {'lat': 33.6740969, 'lng': -117.9...
# 12         OPERATIONAL  {'location': {'lat': 33.72684890000001, 'lng':...
# 13         OPERATIONAL  {'location': {'lat': 33.7015927, 'lng': -117.9...
# 14         OPERATIONAL  {'location': {'lat': 33.7557733, 'lng': -117.9...
# 15         OPERATIONAL  {'location': {'lat': 33.6943652, 'lng': -117.9...
# 16  CLOSED_TEMPORARILY  {'location': {'lat': 33.74410390000001, 'lng':...
# 17         OPERATIONAL  {'location': {'lat': 33.7094376, 'lng': -117.9...
# 18         OPERATIONAL  {'location': {'lat': 33.7241669, 'lng': -118.0...
# 19         OPERATIONAL  {'location': {'lat': 33.6864711, 'lng': -117.9...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                              name        opening_hours  \
# 0                  Slater's 50/50   {'open_now': True}
# 1           Gyu-Kaku Japanese BBQ   {'open_now': True}
# 2                       El Torito   {'open_now': True}
# 3       Gina's Pizza and Pastaria   {'open_now': True}
# 4     BJ's Restaurant & Brewhouse   {'open_now': True}
# 5   Fred's Mexican Cafe & Cantina   {'open_now': True}
# 6      Johnny's Saloon & Pizzeria  {'open_now': False}
# 7                 Stonefire Grill   {'open_now': True}
# 8                          Subway   {'open_now': True}
# 9                     SLICE SHABU  {'open_now': False}
# 10         Hurricanes Bar & Grill   {'open_now': True}
# 11                     Maru Sushi   {'open_now': True}
# 12         Chipotle Mexican Grill   {'open_now': True}
# 13                  Panda Express   {'open_now': True}
# 14               The Boiling Crab   {'open_now': True}
# 15                         Subway   {'open_now': True}
# 16                         Subway                  NaN
# 17                  The Donuttery   {'open_now': True}
# 18              Harbor House Café   {'open_now': True}
# 19                         Subway   {'open_now': True}
#
#                                                photos  \
# 0   [{'height': 3464, 'html_attributions': ['<a hr...
# 1   [{'height': 800, 'html_attributions': ['<a hre...
# 2   [{'height': 3024, 'html_attributions': ['<a hr...
# 3   [{'height': 521, 'html_attributions': ['<a hre...
# 4   [{'height': 3024, 'html_attributions': ['<a hr...
# 5   [{'height': 4480, 'html_attributions': ['<a hr...
# 6   [{'height': 2448, 'html_attributions': ['<a hr...
# 7   [{'height': 1080, 'html_attributions': ['<a hr...
# 8   [{'height': 1080, 'html_attributions': ['<a hr...
# 9   [{'height': 661, 'html_attributions': ['<a hre...
# 10  [{'height': 786, 'html_attributions': ['<a hre...
# 11  [{'height': 800, 'html_attributions': ['<a hre...
# 12  [{'height': 3024, 'html_attributions': ['<a hr...
# 13  [{'height': 3264, 'html_attributions': ['<a hr...
# 14  [{'height': 2988, 'html_attributions': ['<a hr...
# 15  [{'height': 5304, 'html_attributions': ['<a hr...
# 16  [{'height': 1067, 'html_attributions': ['<a hr...
# 17  [{'height': 2250, 'html_attributions': ['<a hr...
# 18  [{'height': 3024, 'html_attributions': ['<a hr...
# 19  [{'height': 5304, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJKXnQHDEh3YAR10nVjek6gfg
# 1   ChIJLRBjFPQm3YARBOUllaZN0MQ
# 2   ChIJ0xMQKxAm3YARdZi8wItQNkw
# 3   ChIJ0ShDJWHf3IARtXw9nSMxtYc
# 4   ChIJByqBekEh3YARStLQLPO3SXE
# 5   ChIJf37kMEIh3YAREpvXK228MPw
# 6   ChIJORqoCO4m3YARR8magfqcJ_c
# 7   ChIJzaUQiDMn3YAR0UDIcy6OAIs
# 8   ChIJeX4xz7om3YARzFjhRbnM0-Q
# 9   ChIJI1iKKvQm3YARy1TThY0bOkQ
# 10  ChIJByqBekEh3YARSMA9RIBy5iU
# 11  ChIJC8LEuGDf3IARn7tMgbFFjqs
# 12  ChIJixf2dlwm3YARo1mWv684OHk
# 13  ChIJRQNtE1An3YAR9z5rD7BMCog
# 14  ChIJVzGZCu0n3YARKGwJUX1Szqc
# 15  ChIJU28xJTEn3YARyg3DIdBc5kE
# 16  ChIJvWIvhAgm3YARuEHz4lYYMFw
# 17  ChIJObOlBu4m3YAR-0rVhzIBaVc
# 18  ChIJdy_XAG4l3YARb1xStFRXefU
# 19  ChIJH4KBdyon3YAR5YPiKYgO4i8
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': 'P276+P5 Huntington Beach, C...            2     4.3
# 1   {'compound_code': 'P285+3V Huntington Beach, C...            2     4.6
# 2   {'compound_code': 'PXVV+GC Westminster, CA, US...            2     4.2
# 3   {'compound_code': 'M3CJ+P3 Costa Mesa, CA, USA...            2     4.3
# 4   {'compound_code': 'MX5X+6M Huntington Beach, C...            2     4.2
# 5   {'compound_code': 'MX5X+2C Huntington Beach, C...            2     4.1
# 6   {'compound_code': 'P256+PJ Huntington Beach, C...            1     4.7
# 7   {'compound_code': 'M2RW+75 Fountain Valley, CA...            2     4.3
# 8   {'compound_code': 'MXPR+7M Huntington Beach, C...            1     3.3
# 9   {'compound_code': 'P286+V5 Huntington Beach, C...            2     4.4
# 10  {'compound_code': 'MX5X+7X Huntington Beach, C...            2     4.3
# 11  {'compound_code': 'M3FJ+J4 Costa Mesa, CA, USA...            2     4.2
# 12  {'compound_code': 'P2G6+P4 Huntington Beach, C...            1     4.2
# 13  {'compound_code': 'P327+JR Fountain Valley, CA...            1     4.1
# 14  {'compound_code': 'Q346+8J Garden Grove, CA, U...            2     4.6
# 15  {'compound_code': 'M2VV+PX Fountain Valley, CA...            1     3.8
# 16  {'compound_code': 'PXVM+JR Huntington Beach, C...            1     4.3
# 17  {'compound_code': 'P256+QG Huntington Beach, C...            1     4.6
# 18  {'compound_code': 'PWFC+MW Sunset Beach, Hunti...            2     4.5
# 19  {'compound_code': 'M2PH+H5 Huntington Beach, C...            1     4.5
#
#                       reference   scope  \
# 0   ChIJKXnQHDEh3YAR10nVjek6gfg  GOOGLE
# 1   ChIJLRBjFPQm3YARBOUllaZN0MQ  GOOGLE
# 2   ChIJ0xMQKxAm3YARdZi8wItQNkw  GOOGLE
# 3   ChIJ0ShDJWHf3IARtXw9nSMxtYc  GOOGLE
# 4   ChIJByqBekEh3YARStLQLPO3SXE  GOOGLE
# 5   ChIJf37kMEIh3YAREpvXK228MPw  GOOGLE
# 6   ChIJORqoCO4m3YARR8magfqcJ_c  GOOGLE
# 7   ChIJzaUQiDMn3YAR0UDIcy6OAIs  GOOGLE
# 8   ChIJeX4xz7om3YARzFjhRbnM0-Q  GOOGLE
# 9   ChIJI1iKKvQm3YARy1TThY0bOkQ  GOOGLE
# 10  ChIJByqBekEh3YARSMA9RIBy5iU  GOOGLE
# 11  ChIJC8LEuGDf3IARn7tMgbFFjqs  GOOGLE
# 12  ChIJixf2dlwm3YARo1mWv684OHk  GOOGLE
# 13  ChIJRQNtE1An3YAR9z5rD7BMCog  GOOGLE
# 14  ChIJVzGZCu0n3YARKGwJUX1Szqc  GOOGLE
# 15  ChIJU28xJTEn3YARyg3DIdBc5kE  GOOGLE
# 16  ChIJvWIvhAgm3YARuEHz4lYYMFw  GOOGLE
# 17  ChIJObOlBu4m3YAR-0rVhzIBaVc  GOOGLE
# 18  ChIJdy_XAG4l3YARb1xStFRXefU  GOOGLE
# 19  ChIJH4KBdyon3YAR5YPiKYgO4i8  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [bar, restaurant, food, point_of_interest, est...                1298
# 1   [bar, restaurant, food, point_of_interest, est...                 612
# 2   [restaurant, food, point_of_interest, establis...                 974
# 3   [meal_delivery, restaurant, food, point_of_int...                 172
# 4   [restaurant, bar, food, point_of_interest, est...                1099
# 5   [bar, restaurant, food, point_of_interest, est...                1142
# 6   [bar, restaurant, food, point_of_interest, est...                 623
# 7   [restaurant, food, point_of_interest, establis...                1225
# 8   [meal_takeaway, restaurant, food, point_of_int...                  38
# 9   [restaurant, food, point_of_interest, establis...                 260
# 10  [restaurant, night_club, bar, food, point_of_i...                 812
# 11  [restaurant, food, point_of_interest, establis...                 384
# 12  [restaurant, food, point_of_interest, establis...                 600
# 13  [restaurant, food, point_of_interest, establis...                 284
# 14  [restaurant, food, point_of_interest, establis...                1609
# 15  [meal_takeaway, restaurant, food, point_of_int...                  56
# 16  [meal_takeaway, restaurant, food, point_of_int...                  44
# 17  [bakery, cafe, restaurant, food, point_of_inte...                2123
# 18  [cafe, bar, restaurant, food, point_of_interes...                1742
# 19  [meal_takeaway, restaurant, food, point_of_int...                  30
#
#                                              vicinity permanently_closed
# 0             17071 Beach Boulevard, Huntington Beach                NaN
# 1           7862 Warner Avenue #109, Huntington Beach                NaN
# 2                15042 Goldenwest Street, Westminster                NaN
# 3                   2701 Harbor Boulevard, Costa Mesa                NaN
# 4                   200 Main Street, Huntington Beach                NaN
# 5                  300 California 1, Huntington Beach                NaN
# 6             17428 Beach Boulevard, Huntington Beach                NaN
# 7            18727 Brookhurst Street, Fountain Valley                NaN
# 8   19051 Goldenwest Street Suite 105, Huntington ...                NaN
# 9             16871 Beach Boulevard, Huntington Beach                NaN
# 10             200 Main Street #201, Huntington Beach                NaN
# 11               1500 Adams Avenue # 100B, Costa Mesa                NaN
# 12            16241 Beach Boulevard, Huntington Beach                NaN
# 13    18011 Newhope Street, Suite #a, Fountain Valley                NaN
# 14             14241 Euclid Street c116, Garden Grove                NaN
# 15         9985 Ellis Avenue Suite 5, Fountain Valley                NaN
# 16                6502 Bolsa Avenue, Huntington Beach               True
# 17            17420 Beach Boulevard, Huntington Beach                NaN
# 18                   16341 California 1, Sunset Beach                NaN
# 19  19011 Magnolia Street Suite 102, Huntington Beach                NaN

# %%
df3=pd.DataFrame(places_data3['results'])
df3
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 33.7158811, 'lng': -118.0...
# 1          OPERATIONAL  {'location': {'lat': 33.7160049, 'lng': -117.9...
# 2          OPERATIONAL  {'location': {'lat': 33.7148153, 'lng': -118.0...
# 3          OPERATIONAL  {'location': {'lat': 33.7367674, 'lng': -118.0...
# 4          OPERATIONAL  {'location': {'lat': 33.6811111, 'lng': -117.9...
# 5          OPERATIONAL  {'location': {'lat': 33.6282768, 'lng': -117.9...
# 6          OPERATIONAL  {'location': {'lat': 33.703107, 'lng': -117.95...
# 7   CLOSED_TEMPORARILY  {'location': {'lat': 33.72982820000001, 'lng':...
# 8          OPERATIONAL  {'location': {'lat': 33.6581485, 'lng': -117.9...
# 9          OPERATIONAL  {'location': {'lat': 33.69180729999999, 'lng':...
# 10         OPERATIONAL  {'location': {'lat': 33.7042857, 'lng': -117.9...
# 11         OPERATIONAL  {'location': {'lat': 33.7295905, 'lng': -118.0...
# 12         OPERATIONAL  {'location': {'lat': 33.744907, 'lng': -118.02...
# 13         OPERATIONAL  {'location': {'lat': 33.6947554, 'lng': -117.9...
# 14         OPERATIONAL  {'location': {'lat': 33.758921, 'lng': -118.00...
# 15         OPERATIONAL  {'location': {'lat': 33.72412250000001, 'lng':...
# 16         OPERATIONAL  {'location': {'lat': 33.672638, 'lng': -117.95...
# 17         OPERATIONAL  {'location': {'lat': 33.6731211, 'lng': -117.9...
# 18         OPERATIONAL  {'location': {'lat': 33.6697505, 'lng': -117.9...
# 19         OPERATIONAL  {'location': {'lat': 33.7454803, 'lng': -117.9...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                   name        opening_hours  \
# 0                           Buon Gusto   {'open_now': True}
# 1                               Subway   {'open_now': True}
# 2                               Subway   {'open_now': True}
# 3                      Chuck E. Cheese   {'open_now': True}
# 4                             Wingnuts   {'open_now': True}
# 5                        Cucina Alessá   {'open_now': True}
# 6               Black Angus Steakhouse   {'open_now': True}
# 7                               Subway                  NaN
# 8                               Subway   {'open_now': True}
# 9                            Five Guys   {'open_now': True}
# 10                              Subway   {'open_now': True}
# 11                              Subway   {'open_now': True}
# 12                  Jersey Mike's Subs   {'open_now': True}
# 13                    Kappo Honda 割烹本多  {'open_now': False}
# 14           Popeyes Louisiana Kitchen   {'open_now': True}
# 15  Olive Pit Grill - Huntington Beach   {'open_now': True}
# 16    Polly's Pies Restaurant & Bakery   {'open_now': True}
# 17                              Subway   {'open_now': True}
# 18                           Great Mex   {'open_now': True}
# 19                              Subway   {'open_now': True}
#
#                                                photos  \
# 0   [{'height': 2218, 'html_attributions': ['<a hr...
# 1   [{'height': 5304, 'html_attributions': ['<a hr...
# 2   [{'height': 766, 'html_attributions': ['<a hre...
# 3   [{'height': 1000, 'html_attributions': ['<a hr...
# 4   [{'height': 1152, 'html_attributions': ['<a hr...
# 5   [{'height': 477, 'html_attributions': ['<a hre...
# 6   [{'height': 2250, 'html_attributions': ['<a hr...
# 7   [{'height': 1763, 'html_attributions': ['<a hr...
# 8   [{'height': 608, 'html_attributions': ['<a hre...
# 9   [{'height': 3024, 'html_attributions': ['<a hr...
# 10  [{'height': 3024, 'html_attributions': ['<a hr...
# 11  [{'height': 766, 'html_attributions': ['<a hre...
# 12  [{'height': 3000, 'html_attributions': ['<a hr...
# 13  [{'height': 1108, 'html_attributions': ['<a hr...
# 14  [{'height': 1192, 'html_attributions': ['<a hr...
# 15  [{'height': 1000, 'html_attributions': ['<a hr...
# 16  [{'height': 1000, 'html_attributions': ['<a hr...
# 17  [{'height': 1067, 'html_attributions': ['<a hr...
# 18  [{'height': 1960, 'html_attributions': ['<a hr...
# 19  [{'height': 766, 'html_attributions': ['<a hre...
#
#                        place_id  \
# 0   ChIJSfXF6bcl3YARIZOLKQB-4b4
# 1   ChIJdyovyxMn3YARdCl8sl24yAk
# 2   ChIJh4ZLX30m3YARzbQog51Vslc
# 3   ChIJOahdVwom3YARBmfXZ4i5Sv8
# 4   ChIJw2BZYFnf3IARVZWNZVTaeyA
# 5   ChIJ-9VH-0Ag3YARFDWQuQyEq7E
# 6   ChIJJYpXUzkn3YARSnUAnduKB4c
# 7   ChIJCwitPmgm3YAREqGsw3t_QlU
# 8   ChIJI3Sh1OMg3YAR1Yxu-mMxn0s
# 9   ChIJ65KCLMQm3YARosGxAiwpyIc
# 10  ChIJ9-3-Xlon3YARQBSOlxHbFHg
# 11  ChIJGyMUy3Um3YARNGbGs7cd0-4
# 12  ChIJfdKRi_wl3YARLKqAGzrk-Cg
# 13  ChIJWQCW1DYn3YARlXDgNUAtbPI
# 14  ChIJt-CEYago3YARUgQByD9srjM
# 15  ChIJSdeKm8Al3YARq0f9AFL2jAA
# 16  ChIJOalKR8Qg3YARFVhPWJ6JbM4
# 17  ChIJuyL_GNgg3YAR9hV03ksEQR0
# 18  ChIJQ80AY2Hf3IARUZuE7J_23lU
# 19  ChIJz2Ilqz4m3YARdMJHUCq4qqI
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': 'PX84+9W Huntington Beach, C...            2     4.7
# 1   {'compound_code': 'P28W+CR Fountain Valley, CA...            1     3.9
# 2   {'compound_code': 'PX7R+WP Huntington Beach, C...            1     3.9
# 3   {'compound_code': 'PXPM+P8 Huntington Beach, C...            2     4.1
# 4   {'compound_code': 'M3JJ+CC Costa Mesa, CA, USA...            2     4.3
# 5   {'compound_code': 'J2HX+87 Newport Beach, CA, ...            2     4.6
# 6   {'compound_code': 'P23W+6X Fountain Valley, CA...            2     4.2
# 7   {'compound_code': 'P2H3+WF Huntington Beach, C...            1     2.8
# 8   {'compound_code': 'M25J+75 Huntington Beach, C...            1     3.9
# 9   {'compound_code': 'M2R6+P7 Huntington Beach, C...            2     4.3
# 10  {'compound_code': 'P338+PF Fountain Valley, CA...            1     4.0
# 11  {'compound_code': 'PXHM+RJ Huntington Beach, C...            1     4.4
# 12  {'compound_code': 'PXVG+XQ Huntington Beach, C...            1     4.4
# 13  {'compound_code': 'M2VW+WH Fountain Valley, CA...            2     4.5
# 14  {'compound_code': 'QX5R+HR Westminster, CA, US...            1     3.7
# 15  {'compound_code': 'PXF5+J5 Huntington Beach, C...            2     4.4
# 16  {'compound_code': 'M2FV+35 Huntington Beach, C...            2     4.3
# 17  {'compound_code': 'M2FH+6Q Huntington Beach, C...            1     4.7
# 18  {'compound_code': 'M39H+WJ Costa Mesa, CA, USA...            1     4.1
# 19  {'compound_code': 'P2W6+58 Westminster, CA, US...            1     4.2
#
#                       reference   scope  \
# 0   ChIJSfXF6bcl3YARIZOLKQB-4b4  GOOGLE
# 1   ChIJdyovyxMn3YARdCl8sl24yAk  GOOGLE
# 2   ChIJh4ZLX30m3YARzbQog51Vslc  GOOGLE
# 3   ChIJOahdVwom3YARBmfXZ4i5Sv8  GOOGLE
# 4   ChIJw2BZYFnf3IARVZWNZVTaeyA  GOOGLE
# 5   ChIJ-9VH-0Ag3YARFDWQuQyEq7E  GOOGLE
# 6   ChIJJYpXUzkn3YARSnUAnduKB4c  GOOGLE
# 7   ChIJCwitPmgm3YAREqGsw3t_QlU  GOOGLE
# 8   ChIJI3Sh1OMg3YAR1Yxu-mMxn0s  GOOGLE
# 9   ChIJ65KCLMQm3YARosGxAiwpyIc  GOOGLE
# 10  ChIJ9-3-Xlon3YARQBSOlxHbFHg  GOOGLE
# 11  ChIJGyMUy3Um3YARNGbGs7cd0-4  GOOGLE
# 12  ChIJfdKRi_wl3YARLKqAGzrk-Cg  GOOGLE
# 13  ChIJWQCW1DYn3YARlXDgNUAtbPI  GOOGLE
# 14  ChIJt-CEYago3YARUgQByD9srjM  GOOGLE
# 15  ChIJSdeKm8Al3YARq0f9AFL2jAA  GOOGLE
# 16  ChIJOalKR8Qg3YARFVhPWJ6JbM4  GOOGLE
# 17  ChIJuyL_GNgg3YAR9hV03ksEQR0  GOOGLE
# 18  ChIJQ80AY2Hf3IARUZuE7J_23lU  GOOGLE
# 19  ChIJz2Ilqz4m3YARdMJHUCq4qqI  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [restaurant, food, point_of_interest, establis...                 685
# 1   [meal_takeaway, restaurant, food, point_of_int...                  67
# 2   [meal_takeaway, restaurant, food, point_of_int...                  67
# 3   [restaurant, food, point_of_interest, establis...                 732
# 4   [restaurant, meal_delivery, bar, food, point_o...                 616
# 5   [bar, restaurant, food, point_of_interest, est...                 294
# 6   [bar, restaurant, food, point_of_interest, est...                1045
# 7   [meal_takeaway, restaurant, food, point_of_int...                   5
# 8   [meal_takeaway, restaurant, food, point_of_int...                  51
# 9   [meal_takeaway, restaurant, food, point_of_int...                 369
# 10  [meal_takeaway, restaurant, food, point_of_int...                  98
# 11  [meal_takeaway, restaurant, food, point_of_int...                  58
# 12  [meal_takeaway, restaurant, food, point_of_int...                 179
# 13  [restaurant, food, point_of_interest, establis...                 443
# 14  [restaurant, food, point_of_interest, establis...                 492
# 15  [restaurant, food, point_of_interest, establis...                 676
# 16  [bakery, restaurant, food, point_of_interest, ...                 786
# 17  [meal_takeaway, restaurant, food, point_of_int...                  65
# 18  [meal_takeaway, restaurant, food, point_of_int...                 142
# 19  [meal_takeaway, restaurant, food, point_of_int...                 170
#
#                                         vicinity permanently_closed
# 0      4911 Warner Avenue #109, Huntington Beach                NaN
# 1   10100 Warner Avenue Suite A, Fountain Valley                NaN
# 2           6918 Warner Avenue, Huntington Beach                NaN
# 3         15511 Edwards Street, Huntington Beach                NaN
# 4      3030 Harbor Boulevard Ste H-3, Costa Mesa                NaN
# 5         6700 West Coast Highway, Newport Beach                NaN
# 6       17920 Brookhurst Street, Fountain Valley                NaN
# 7          7596 Edinger Avenue, Huntington Beach               True
# 8          9115 Atlanta Avenue, Huntington Beach                NaN
# 9        18645 Beach Boulevard, Huntington Beach                NaN
# 10    17860 Newhope Street #101, Fountain Valley                NaN
# 11         6490 Edinger Avenue, Huntington Beach                NaN
# 12    6041 Bolsa Avenue Unit 5, Huntington Beach                NaN
# 13      18450 Brookhurst Street, Fountain Valley                NaN
# 14       6948 Westminster Boulevard, Westminster                NaN
# 15    16365 Bolsa Chica Street, Huntington Beach                NaN
# 16           9791 Adams Avenue, Huntington Beach                NaN
# 17           9025 Adams Avenue, Huntington Beach                NaN
# 18   1525 Mesa Verde Drive East #117, Costa Mesa                NaN
# 19            14920 Beach Boulevard, Westminster                NaN

# %%
df_row=pd.concat([df,df2,df3])

# %%
df_row
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 33.7341503, 'lng': -117.9...
# 1          OPERATIONAL  {'location': {'lat': 33.6907124, 'lng': -117.9...
# 2          OPERATIONAL  {'location': {'lat': 33.65664439999999, 'lng':...
# 3          OPERATIONAL  {'location': {'lat': 33.732545, 'lng': -117.99...
# 4          OPERATIONAL  {'location': {'lat': 33.7296127, 'lng': -117.9...
# 5          OPERATIONAL  {'location': {'lat': 33.7586417, 'lng': -118.0...
# 6          OPERATIONAL  {'location': {'lat': 33.69599830000001, 'lng':...
# 7          OPERATIONAL  {'location': {'lat': 33.73047, 'lng': -117.995...
# 8          OPERATIONAL  {'location': {'lat': 33.6839637, 'lng': -117.9...
# 9          OPERATIONAL  {'location': {'lat': 33.71207810000001, 'lng':...
# 10         OPERATIONAL  {'location': {'lat': 33.69607999999999, 'lng':...
# 11         OPERATIONAL  {'location': {'lat': 33.71803930000001, 'lng':...
# 12         OPERATIONAL  {'location': {'lat': 33.6944092, 'lng': -117.9...
# 13  CLOSED_TEMPORARILY  {'location': {'lat': 33.6570995, 'lng': -118.0...
# 14         OPERATIONAL  {'location': {'lat': 33.69482000000001, 'lng':...
# 15         OPERATIONAL  {'location': {'lat': 33.7224162, 'lng': -117.9...
# 16         OPERATIONAL  {'location': {'lat': 33.7344453, 'lng': -117.9...
# 17         OPERATIONAL  {'location': {'lat': 33.7449139, 'lng': -118.0...
# 18         OPERATIONAL  {'location': {'lat': 33.6585159, 'lng': -118.0...
# 18         OPERATIONAL  {'location': {'lat': 33.6697505, 'lng': -117.9...
# 19         OPERATIONAL  {'location': {'lat': 33.7454803, 'lng': -117.9...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                             name        opening_hours  \
# 0               Buca di Beppo Italian Restaurant   {'open_now': True}
# 1                          Hooters of Costa Mesa   {'open_now': True}
# 2                        Duke's Huntington Beach   {'open_now': True}
# 3                         The Cheesecake Factory   {'open_now': True}
# 4                    BJ's Restaurant & Brewhouse   {'open_now': True}
# 5                                         Subway   {'open_now': True}
# 6   Shin-Sen-Gumi Hakata Ramen - Fountain Valley   {'open_now': True}
# 7                                  Corner Bakery   {'open_now': True}
# 8                         Fitzgerald's Irish Pub   {'open_now': True}
# 9                                         Subway   {'open_now': True}
# 10                                 Corner Bakery   {'open_now': True}
# 11               Olive Garden Italian Restaurant   {'open_now': True}
# 12                         Birdie Bowl & Juicery   {'open_now': True}
# 13                                        Subway                  NaN
# 14                                   Mimi's Cafe   {'open_now': True}
# 15                                        Âu Lạc   {'open_now': True}
# 16                     Biergarten @ Old World HB   {'open_now': True}
# 17                                  Harry's Cafe   {'open_now': True}
# 18                                 Baja Sharkeez   {'open_now': True}
# 19                               Brodard Chateau   {'open_now': True}
# 0                                 Slater's 50/50   {'open_now': True}
# 1                          Gyu-Kaku Japanese BBQ   {'open_now': True}
# 2                                      El Torito   {'open_now': True}
# 3                      Gina's Pizza and Pastaria   {'open_now': True}
# 4                    BJ's Restaurant & Brewhouse   {'open_now': True}
# 5                  Fred's Mexican Cafe & Cantina   {'open_now': True}
# 6                     Johnny's Saloon & Pizzeria  {'open_now': False}
# 7                                Stonefire Grill   {'open_now': True}
# 8                                         Subway   {'open_now': True}
# 9                                    SLICE SHABU  {'open_now': False}
# 10                        Hurricanes Bar & Grill   {'open_now': True}
# 11                                    Maru Sushi   {'open_now': True}
# 12                        Chipotle Mexican Grill   {'open_now': True}
# 13                                 Panda Express   {'open_now': True}
# 14                              The Boiling Crab   {'open_now': True}
# 15                                        Subway   {'open_now': True}
# 16                                        Subway                  NaN
# 17                                 The Donuttery   {'open_now': True}
# 18                             Harbor House Café   {'open_now': True}
# 19                                        Subway   {'open_now': True}
# 0                                     Buon Gusto   {'open_now': True}
# 1                                         Subway   {'open_now': True}
# 2                                         Subway   {'open_now': True}
# 3                                Chuck E. Cheese   {'open_now': True}
# 4                                       Wingnuts   {'open_now': True}
# 5                                  Cucina Alessá   {'open_now': True}
# 6                         Black Angus Steakhouse   {'open_now': True}
# 7                                         Subway                  NaN
# 8                                         Subway   {'open_now': True}
# 9                                      Five Guys   {'open_now': True}
# 10                                        Subway   {'open_now': True}
# 11                                        Subway   {'open_now': True}
# 12                            Jersey Mike's Subs   {'open_now': True}
# 13                              Kappo Honda 割烹本多  {'open_now': False}
# 14                     Popeyes Louisiana Kitchen   {'open_now': True}
# 15            Olive Pit Grill - Huntington Beach   {'open_now': True}
# 16              Polly's Pies Restaurant & Bakery   {'open_now': True}
# 17                                        Subway   {'open_now': True}
# 18                                     Great Mex   {'open_now': True}
# 19                                        Subway   {'open_now': True}
#
#                                                photos  \
# 0   [{'height': 3024, 'html_attributions': ['<a hr...
# 1   [{'height': 3024, 'html_attributions': ['<a hr...
# 2                                                 NaN
# 3   [{'height': 3024, 'html_attributions': ['<a hr...
# 4   [{'height': 1836, 'html_attributions': ['<a hr...
# 5   [{'height': 766, 'html_attributions': ['<a hre...
# 6   [{'height': 270, 'html_attributions': ['<a hre...
# 7   [{'height': 3024, 'html_attributions': ['<a hr...
# 8   [{'height': 2080, 'html_attributions': ['<a hr...
# 9   [{'height': 949, 'html_attributions': ['<a hre...
# 10  [{'height': 3024, 'html_attributions': ['<a hr...
# 11  [{'height': 2952, 'html_attributions': ['<a hr...
# 12  [{'height': 3024, 'html_attributions': ['<a hr...
# 13  [{'height': 766, 'html_attributions': ['<a hre...
# 14  [{'height': 3264, 'html_attributions': ['<a hr...
# 15  [{'height': 333, 'html_attributions': ['<a hre...
# 16  [{'height': 1192, 'html_attributions': ['<a hr...
# 17  [{'height': 2448, 'html_attributions': ['<a hr...
# 18  [{'height': 2160, 'html_attributions': ['<a hr...
# 19  [{'height': 1000, 'html_attributions': ['<a hr...
# 0   [{'height': 3464, 'html_attributions': ['<a hr...
# 1   [{'height': 800, 'html_attributions': ['<a hre...
# 2   [{'height': 3024, 'html_attributions': ['<a hr...
# 3   [{'height': 521, 'html_attributions': ['<a hre...
# 4   [{'height': 3024, 'html_attributions': ['<a hr...
# 5   [{'height': 4480, 'html_attributions': ['<a hr...
# 6   [{'height': 2448, 'html_attributions': ['<a hr...
# 7   [{'height': 1080, 'html_attributions': ['<a hr...
# 8   [{'height': 1080, 'html_attributions': ['<a hr...
# 9   [{'height': 661, 'html_attributions': ['<a hre...
# 10  [{'height': 786, 'html_attributions': ['<a hre...
# 11  [{'height': 800, 'html_attributions': ['<a hre...
# 12  [{'height': 3024, 'html_attributions': ['<a hr...
# 13  [{'height': 3264, 'html_attributions': ['<a hr...
# 14  [{'height': 2988, 'html_attributions': ['<a hr...
# 15  [{'height': 5304, 'html_attributions': ['<a hr...
# 16  [{'height': 1067, 'html_attributions': ['<a hr...
# 17  [{'height': 2250, 'html_attributions': ['<a hr...
# 18  [{'height': 3024, 'html_attributions': ['<a hr...
# 19  [{'height': 5304, 'html_attributions': ['<a hr...
# 0   [{'height': 2218, 'html_attributions': ['<a hr...
# 1   [{'height': 5304, 'html_attributions': ['<a hr...
# 2   [{'height': 766, 'html_attributions': ['<a hre...
# 3   [{'height': 1000, 'html_attributions': ['<a hr...
# 4   [{'height': 1152, 'html_attributions': ['<a hr...
# 5   [{'height': 477, 'html_attributions': ['<a hre...
# 6   [{'height': 2250, 'html_attributions': ['<a hr...
# 7   [{'height': 1763, 'html_attributions': ['<a hr...
# 8   [{'height': 608, 'html_attributions': ['<a hre...
# 9   [{'height': 3024, 'html_attributions': ['<a hr...
# 10  [{'height': 3024, 'html_attributions': ['<a hr...
# 11  [{'height': 766, 'html_attributions': ['<a hre...
# 12  [{'height': 3000, 'html_attributions': ['<a hr...
# 13  [{'height': 1108, 'html_attributions': ['<a hr...
# 14  [{'height': 1192, 'html_attributions': ['<a hr...
# 15  [{'height': 1000, 'html_attributions': ['<a hr...
# 16  [{'height': 1000, 'html_attributions': ['<a hr...
# 17  [{'height': 1067, 'html_attributions': ['<a hr...
# 18  [{'height': 1960, 'html_attributions': ['<a hr...
# 19  [{'height': 766, 'html_attributions': ['<a hre...
#
#                        place_id  \
# 0   ChIJP5s8IkIm3YARpSuO--EX3f8
# 1   ChIJ6_qtJVTf3IARdsI3DGEHn_c
# 2   ChIJg6yePEIh3YAR9jvzwIJzPoA
# 3   ChIJaRncL0Mm3YARs9osub8nU1s
# 4   ChIJ2ynLWlsm3YARmvBfFo6_vMQ
# 5   ChIJEdix5FMv3YAR1UxsY09VCj0
# 6   ChIJ93pCsTAn3YARYnvc3DKUUkk
# 7   ChIJQZuhI2gm3YAR7c1JCv3cwJU
# 8   ChIJ71mZpion3YARs_yxBkAyBt8
# 9   ChIJi6vlhqgl3YARrdnVxV5EvtQ
# 10  ChIJ93pCsTAn3YARc63Z3c2LHNc
# 11  ChIJr0-_xPUm3YARWbBbkcPzahU
# 12  ChIJeRMRSlUn3YAR1tLnXcoP6kA
# 13  ChIJf37kMEIh3YARxY4IidVhOfw
# 14  ChIJsfm0LDEn3YAR6dCdiyhVfiY
# 15  ChIJqRagpg4n3YARgvO_ptZm7Pk
# 16  ChIJ5cuORWom3YARPTjxELrS3ng
# 17  ChIJz_6Qi_wl3YARHgbNp1plmp8
# 18  ChIJk8K8YkEh3YAR-kcQuHsIvEQ
# 19  ChIJOc7x8X8o3YARWGA4DUL8-5U
# 0   ChIJKXnQHDEh3YAR10nVjek6gfg
# 1   ChIJLRBjFPQm3YARBOUllaZN0MQ
# 2   ChIJ0xMQKxAm3YARdZi8wItQNkw
# 3   ChIJ0ShDJWHf3IARtXw9nSMxtYc
# 4   ChIJByqBekEh3YARStLQLPO3SXE
# 5   ChIJf37kMEIh3YAREpvXK228MPw
# 6   ChIJORqoCO4m3YARR8magfqcJ_c
# 7   ChIJzaUQiDMn3YAR0UDIcy6OAIs
# 8   ChIJeX4xz7om3YARzFjhRbnM0-Q
# 9   ChIJI1iKKvQm3YARy1TThY0bOkQ
# 10  ChIJByqBekEh3YARSMA9RIBy5iU
# 11  ChIJC8LEuGDf3IARn7tMgbFFjqs
# 12  ChIJixf2dlwm3YARo1mWv684OHk
# 13  ChIJRQNtE1An3YAR9z5rD7BMCog
# 14  ChIJVzGZCu0n3YARKGwJUX1Szqc
# 15  ChIJU28xJTEn3YARyg3DIdBc5kE
# 16  ChIJvWIvhAgm3YARuEHz4lYYMFw
# 17  ChIJObOlBu4m3YAR-0rVhzIBaVc
# 18  ChIJdy_XAG4l3YARb1xStFRXefU
# 19  ChIJH4KBdyon3YAR5YPiKYgO4i8
# 0   ChIJSfXF6bcl3YARIZOLKQB-4b4
# 1   ChIJdyovyxMn3YARdCl8sl24yAk
# 2   ChIJh4ZLX30m3YARzbQog51Vslc
# 3   ChIJOahdVwom3YARBmfXZ4i5Sv8
# 4   ChIJw2BZYFnf3IARVZWNZVTaeyA
# 5   ChIJ-9VH-0Ag3YARFDWQuQyEq7E
# 6   ChIJJYpXUzkn3YARSnUAnduKB4c
# 7   ChIJCwitPmgm3YAREqGsw3t_QlU
# 8   ChIJI3Sh1OMg3YAR1Yxu-mMxn0s
# 9   ChIJ65KCLMQm3YARosGxAiwpyIc
# 10  ChIJ9-3-Xlon3YARQBSOlxHbFHg
# 11  ChIJGyMUy3Um3YARNGbGs7cd0-4
# 12  ChIJfdKRi_wl3YARLKqAGzrk-Cg
# 13  ChIJWQCW1DYn3YARlXDgNUAtbPI
# 14  ChIJt-CEYago3YARUgQByD9srjM
# 15  ChIJSdeKm8Al3YARq0f9AFL2jAA
# 16  ChIJOalKR8Qg3YARFVhPWJ6JbM4
# 17  ChIJuyL_GNgg3YAR9hV03ksEQR0
# 18  ChIJQ80AY2Hf3IARUZuE7J_23lU
# 19  ChIJz2Ilqz4m3YARdMJHUCq4qqI
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': 'P2M4+MV Huntington Beach, C...          2.0     4.1
# 1   {'compound_code': 'M3RH+7H Costa Mesa, CA, USA...          2.0     4.0
# 2   {'compound_code': 'MX4X+M5 Huntington Beach, C...          2.0     4.5
# 3   {'compound_code': 'P2M5+29 Huntington Beach, C...          2.0     4.3
# 4   {'compound_code': 'P2H6+RJ Huntington Beach, C...          2.0     4.1
# 5   {'compound_code': 'QX5G+FC Westminster, CA, US...          1.0     3.8
# 6   {'compound_code': 'M2WW+93 Fountain Valley, CA...          1.0     4.6
# 7   {'compound_code': 'P2J3+5J Huntington Beach, C...          1.0     4.3
# 8   {'compound_code': 'M2MG+HW Huntington Beach, C...          1.0     4.4
# 9   {'compound_code': 'PW6Q+R2 Huntington Beach, C...          1.0     3.7
# 10  {'compound_code': 'M2WW+C5 Fountain Valley, CA...          1.0     4.2
# 11  {'compound_code': 'P296+64 Huntington Beach, C...          2.0     4.3
# 12  {'compound_code': 'M3VF+QJ Costa Mesa, CA, USA...          NaN     4.6
# 13  {'compound_code': 'MX4X+RC Huntington Beach, C...          1.0     3.7
# 14  {'compound_code': 'M2VW+W5 Fountain Valley, CA...          2.0     4.1
# 15  {'compound_code': 'P2CV+XR Fountain Valley, CA...          2.0     4.6
# 16  {'compound_code': 'P2M3+Q9 Huntington Beach, C...          2.0     4.5
# 17  {'compound_code': 'PXVG+XM Huntington Beach, C...          1.0     4.2
# 18  {'compound_code': 'MX5X+CJ Huntington Beach, C...          2.0     4.2
# 19  {'compound_code': 'Q28H+GQ Garden Grove, CA, U...          2.0     4.4
# 0   {'compound_code': 'P276+P5 Huntington Beach, C...          2.0     4.3
# 1   {'compound_code': 'P285+3V Huntington Beach, C...          2.0     4.6
# 2   {'compound_code': 'PXVV+GC Westminster, CA, US...          2.0     4.2
# 3   {'compound_code': 'M3CJ+P3 Costa Mesa, CA, USA...          2.0     4.3
# 4   {'compound_code': 'MX5X+6M Huntington Beach, C...          2.0     4.2
# 5   {'compound_code': 'MX5X+2C Huntington Beach, C...          2.0     4.1
# 6   {'compound_code': 'P256+PJ Huntington Beach, C...          1.0     4.7
# 7   {'compound_code': 'M2RW+75 Fountain Valley, CA...          2.0     4.3
# 8   {'compound_code': 'MXPR+7M Huntington Beach, C...          1.0     3.3
# 9   {'compound_code': 'P286+V5 Huntington Beach, C...          2.0     4.4
# 10  {'compound_code': 'MX5X+7X Huntington Beach, C...          2.0     4.3
# 11  {'compound_code': 'M3FJ+J4 Costa Mesa, CA, USA...          2.0     4.2
# 12  {'compound_code': 'P2G6+P4 Huntington Beach, C...          1.0     4.2
# 13  {'compound_code': 'P327+JR Fountain Valley, CA...          1.0     4.1
# 14  {'compound_code': 'Q346+8J Garden Grove, CA, U...          2.0     4.6
# 15  {'compound_code': 'M2VV+PX Fountain Valley, CA...          1.0     3.8
# 16  {'compound_code': 'PXVM+JR Huntington Beach, C...          1.0     4.3
# 17  {'compound_code': 'P256+QG Huntington Beach, C...          1.0     4.6
# 18  {'compound_code': 'PWFC+MW Sunset Beach, Hunti...          2.0     4.5
# 19  {'compound_code': 'M2PH+H5 Huntington Beach, C...          1.0     4.5
# 0   {'compound_code': 'PX84+9W Huntington Beach, C...          2.0     4.7
# 1   {'compound_code': 'P28W+CR Fountain Valley, CA...          1.0     3.9
# 2   {'compound_code': 'PX7R+WP Huntington Beach, C...          1.0     3.9
# 3   {'compound_code': 'PXPM+P8 Huntington Beach, C...          2.0     4.1
# 4   {'compound_code': 'M3JJ+CC Costa Mesa, CA, USA...          2.0     4.3
# 5   {'compound_code': 'J2HX+87 Newport Beach, CA, ...          2.0     4.6
# 6   {'compound_code': 'P23W+6X Fountain Valley, CA...          2.0     4.2
# 7   {'compound_code': 'P2H3+WF Huntington Beach, C...          1.0     2.8
# 8   {'compound_code': 'M25J+75 Huntington Beach, C...          1.0     3.9
# 9   {'compound_code': 'M2R6+P7 Huntington Beach, C...          2.0     4.3
# 10  {'compound_code': 'P338+PF Fountain Valley, CA...          1.0     4.0
# 11  {'compound_code': 'PXHM+RJ Huntington Beach, C...          1.0     4.4
# 12  {'compound_code': 'PXVG+XQ Huntington Beach, C...          1.0     4.4
# 13  {'compound_code': 'M2VW+WH Fountain Valley, CA...          2.0     4.5
# 14  {'compound_code': 'QX5R+HR Westminster, CA, US...          1.0     3.7
# 15  {'compound_code': 'PXF5+J5 Huntington Beach, C...          2.0     4.4
# 16  {'compound_code': 'M2FV+35 Huntington Beach, C...          2.0     4.3
# 17  {'compound_code': 'M2FH+6Q Huntington Beach, C...          1.0     4.7
# 18  ChIJdy_XAG4l3YARb1xStFRXefU  GOOGLE
# 19  ChIJH4KBdyon3YAR5YPiKYgO4i8  GOOGLE
# 0   ChIJSfXF6bcl3YARIZOLKQB-4b4  GOOGLE
# 1   ChIJdyovyxMn3YARdCl8sl24yAk  GOOGLE
# 2   ChIJh4ZLX30m3YARzbQog51Vslc  GOOGLE
# 3   ChIJOahdVwom3YARBmfXZ4i5Sv8  GOOGLE
# 4   ChIJw2BZYFnf3IARVZWNZVTaeyA  GOOGLE
# 5   ChIJ-9VH-0Ag3YARFDWQuQyEq7E  GOOGLE
# 6   ChIJJYpXUzkn3YARSnUAnduKB4c  GOOGLE
# 7   ChIJCwitPmgm3YAREqGsw3t_QlU  GOOGLE
# 8   ChIJI3Sh1OMg3YAR1Yxu-mMxn0s  GOOGLE
# 9   ChIJ65KCLMQm3YARosGxAiwpyIc  GOOGLE
# 10  ChIJ9-3-Xlon3YARQBSOlxHbFHg  GOOGLE
# 11  ChIJGyMUy3Um3YARNGbGs7cd0-4  GOOGLE
# 12  ChIJfdKRi_wl3YARLKqAGzrk-Cg  GOOGLE
# 13  ChIJWQCW1DYn3YARlXDgNUAtbPI  GOOGLE
# 14  ChIJt-CEYago3YARUgQByD9srjM  GOOGLE
# 15  ChIJSdeKm8Al3YARq0f9AFL2jAA  GOOGLE
# 16  ChIJOalKR8Qg3YARFVhPWJ6JbM4  GOOGLE
# 17  ChIJuyL_GNgg3YAR9hV03ksEQR0  GOOGLE
# 18  ChIJQ80AY2Hf3IARUZuE7J_23lU  GOOGLE
# 19  ChIJz2Ilqz4m3YARdMJHUCq4qqI  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [restaurant, food, point_of_interest, establis...                1443
# 1   [bar, restaurant, food, point_of_interest, est...                 897
# 2   [bar, restaurant, food, point_of_interest, est...                3389
# 3   [restaurant, meal_takeaway, food, point_of_int...                1826
# 4   [restaurant, bar, food, point_of_interest, est...                1420
# 5   [meal_takeaway, restaurant, food, point_of_int...                  59
# 6   [restaurant, food, point_of_interest, establis...                1152
# 7   [bakery, cafe, restaurant, food, point_of_inte...                 399
# 8   [bar, restaurant, food, point_of_interest, est...                 211
# 9   [meal_takeaway, restaurant, food, point_of_int...                  58
# 10  [bakery, cafe, restaurant, food, point_of_inte...                 413
# 11  [meal_takeaway, bar, restaurant, food, point_o...                1966
# 12  [restaurant, food, point_of_interest, establis...                  63
# 13  [meal_takeaway, restaurant, food, point_of_int...                  62
# 14  [bakery, meal_takeaway, cafe, bar, restaurant,...                 823
# 15  [restaurant, food, point_of_interest, establis...                 486
# 16  [night_club, bar, restaurant, food, point_of_i...                 776
# 17  [restaurant, food, point_of_interest, establis...                 324
# 18  [bar, restaurant, food, point_of_interest, est...                 877
# 19  [restaurant, food, point_of_interest, establis...                 787
# 0   [bar, restaurant, food, point_of_interest, est...                1298
# 1   [bar, restaurant, food, point_of_interest, est...                 612
# 2   [restaurant, food, point_of_interest, establis...                 974
# 3   [meal_delivery, restaurant, food, point_of_int...                 172
# 4   [restaurant, bar, food, point_of_interest, est...                1099
# 5   [bar, restaurant, food, point_of_interest, est...                1142
# 6   [bar, restaurant, food, point_of_interest, est...                 623
# 7   [restaurant, food, point_of_interest, establis...                1225
# 8   [meal_takeaway, restaurant, food, point_of_int...                  38
# 9   [restaurant, food, point_of_interest, establis...                 260
# 10  [restaurant, night_club, bar, food, point_of_i...                 812
# 11  [restaurant, food, point_of_interest, establis...                 384
# 12  [restaurant, food, point_of_interest, establis...                 600
# 13  [restaurant, food, point_of_interest, establis...                 284
# 14  [restaurant, food, point_of_interest, establis...                1609
# 15  [meal_takeaway, restaurant, food, point_of_int...                  56
# 16  [meal_takeaway, restaurant, food, point_of_int...                  44
# 17  [bakery, cafe, restaurant, food, point_of_inte...                2123
# 18  [cafe, bar, restaurant, food, point_of_interes...                1742
# 19  [meal_takeaway, restaurant, food, point_of_int...                  30
# 0   [restaurant, food, point_of_interest, establis...                 685
# 1   [meal_takeaway, restaurant, food, point_of_int...                  67
# 2   [meal_takeaway, restaurant, food, point_of_int...                  67
# 3   [restaurant, food, point_of_interest, establis...                 732
# 4   [restaurant, meal_delivery, bar, food, point_o...                 616
# 5   [bar, restaurant, food, point_of_interest, est...                 294
# 6   [bar, restaurant, food, point_of_interest, est...                1045
# 7   [meal_takeaway, restaurant, food, point_of_int...                   5
# 8   [meal_takeaway, restaurant, food, point_of_int...                  51
# 9   [meal_takeaway, restaurant, food, point_of_int...                 369
# 10  [meal_takeaway, restaurant, food, point_of_int...                  98
# 11  [meal_takeaway, restaurant, food, point_of_int...                  58
# 12  [meal_takeaway, restaurant, food, point_of_int...                 179
# 13  [restaurant, food, point_of_interest, establis...                 443
# 14  [restaurant, food, point_of_interest, establis...                 492
# 15  [restaurant, food, point_of_interest, establis...                 676
# 16  [bakery, restaurant, food, point_of_interest, ...                 786
# 17  [meal_takeaway, restaurant, food, point_of_int...                  65
# 18  [meal_takeaway, restaurant, food, point_of_int...                 142
# 19  [meal_takeaway, restaurant, food, point_of_int...                 170
#
#                                              vicinity permanently_closed
# 0                7979 Center Avenue, Huntington Beach                NaN
# 1                  1507 South Coast Drive, Costa Mesa                NaN
# 2         317 Pacific Coast Highway, Huntington Beach                NaN
# 3               7871 Edinger Avenue, Huntington Beach                NaN
# 4             16060 Beach Boulevard, Huntington Beach                NaN
# 5                14022 Springdale Street, Westminster                NaN
# 6         18315 Brookhurst Street #1, Fountain Valley                NaN
# 7       7621 Edinger Avenue Ste 110, Huntington Beach                NaN
# 8         19171 Magnolia Street #12, Huntington Beach                NaN
# 9         3801 Warner Avenue Unit D, Huntington Beach                NaN
# 10     18315 Brookhurst Street Ste 2, Fountain Valley                NaN
# 11            16811 Beach Boulevard, Huntington Beach                NaN
# 12             3313 Hyland Avenue STE A17, Costa Mesa                NaN
# 13  300 Pacific Coast Highway Suite 106 B, Hunting...               True
# 14           18461 Brookhurst Street, Fountain Valley                NaN
# 15           16563 Brookhurst Street, Fountain Valley                NaN
# 16           7561 Center Avenue #49, Huntington Beach                NaN
# 17                6041 Bolsa Avenue, Huntington Beach                NaN
# 18                  211 Main Street, Huntington Beach                NaN
# 19                    9100 Trask Avenue, Garden Grove                NaN
# 0             17071 Beach Boulevard, Huntington Beach                NaN
# 1           7862 Warner Avenue #109, Huntington Beach                NaN
# 2                15042 Goldenwest Street, Westminster                NaN
# 3                   2701 Harbor Boulevard, Costa Mesa                NaN
# 4                   200 Main Street, Huntington Beach                NaN
# 5                  300 California 1, Huntington Beach                NaN
# 6             17428 Beach Boulevard, Huntington Beach                NaN
# 7            18727 Brookhurst Street, Fountain Valley                NaN
# 8   19051 Goldenwest Street Suite 105, Huntington ...                NaN
# 9             16871 Beach Boulevard, Huntington Beach                NaN
# 10             200 Main Street #201, Huntington Beach                NaN
# 11               1500 Adams Avenue # 100B, Costa Mesa                NaN
# 12            16241 Beach Boulevard, Huntington Beach                NaN
# 13    18011 Newhope Street, Suite #a, Fountain Valley                NaN
# 14             14241 Euclid Street c116, Garden Grove                NaN
# 15         9985 Ellis Avenue Suite 5, Fountain Valley                NaN
# 16                6502 Bolsa Avenue, Huntington Beach               True
# 17            17420 Beach Boulevard, Huntington Beach                NaN
# 18                   16341 California 1, Sunset Beach                NaN
# 19  19011 Magnolia Street Suite 102, Huntington Beach                NaN
# 0           4911 Warner Avenue #109, Huntington Beach                NaN
# 1        10100 Warner Avenue Suite A, Fountain Valley                NaN
# 2                6918 Warner Avenue, Huntington Beach                NaN
# 3              15511 Edwards Street, Huntington Beach                NaN
# 4           3030 Harbor Boulevard Ste H-3, Costa Mesa                NaN
# 5              6700 West Coast Highway, Newport Beach                NaN
# 6            17920 Brookhurst Street, Fountain Valley                NaN
# 7               7596 Edinger Avenue, Huntington Beach               True
# 8               9115 Atlanta Avenue, Huntington Beach                NaN
# 9             18645 Beach Boulevard, Huntington Beach                NaN
# 10         17860 Newhope Street #101, Fountain Valley                NaN
# 11              6490 Edinger Avenue, Huntington Beach                NaN
# 12         6041 Bolsa Avenue Unit 5, Huntington Beach                NaN
# 13           18450 Brookhurst Street, Fountain Valley                NaN
# 14            6948 Westminster Boulevard, Westminster                NaN
# 15         16365 Bolsa Chica Street, Huntington Beach                NaN
# 16                9791 Adams Avenue, Huntington Beach                NaN
# 17                9025 Adams Avenue, Huntington Beach                NaN
# 18        1525 Mesa Verde Drive East #117, Costa Mesa                NaN
# 19                 14920 Beach Boulevard, Westminster                NaN

# %%
df_row.count()
# Out:
# business_status       60
# geometry              60
# icon                  60
# name                  60
# opening_hours         57
# photos                59
# place_id              60
# plus_code             60
# price_level           59
# rating                60
# reference             60
# scope                 60
# types                 60
# user_ratings_total    60
# vicinity              60
# permanently_closed     3
# dtype: int64

# %%
df_google_combine = df_row.iloc[:,[3,6]]
df_google_combine = df_google_combine.reset_index(drop=True)

# %%
df_google_combine
# Out:
#                                             name                     place_id
# 0               Buca di Beppo Italian Restaurant  ChIJP5s8IkIm3YARpSuO--EX3f8
# 1                          Hooters of Costa Mesa  ChIJ6_qtJVTf3IARdsI3DGEHn_c
# 2                        Duke's Huntington Beach  ChIJg6yePEIh3YAR9jvzwIJzPoA
# 39                                        Subway  ChIJH4KBdyon3YAR5YPiKYgO4i8
# 40                                    Buon Gusto  ChIJSfXF6bcl3YARIZOLKQB-4b4
# 41                                        Subway  ChIJdyovyxMn3YARdCl8sl24yAk
# 42                                        Subway  ChIJh4ZLX30m3YARzbQog51Vslc
# 43                               Chuck E. Cheese  ChIJOahdVwom3YARBmfXZ4i5Sv8
# 44                                      Wingnuts  ChIJw2BZYFnf3IARVZWNZVTaeyA
# 45                                 Cucina Alessá  ChIJ-9VH-0Ag3YARFDWQuQyEq7E
# 46                        Black Angus Steakhouse  ChIJJYpXUzkn3YARSnUAnduKB4c
# 47                                        Subway  ChIJCwitPmgm3YAREqGsw3t_QlU
# 48                                        Subway  ChIJI3Sh1OMg3YAR1Yxu-mMxn0s
# 49                                     Five Guys  ChIJ65KCLMQm3YARosGxAiwpyIc
# 50                                        Subway  ChIJ9-3-Xlon3YARQBSOlxHbFHg
# 51                                        Subway  ChIJGyMUy3Um3YARNGbGs7cd0-4
# 52                            Jersey Mike's Subs  ChIJfdKRi_wl3YARLKqAGzrk-Cg
# 53                              Kappo Honda 割烹本多  ChIJWQCW1DYn3YARlXDgNUAtbPI
# 54                     Popeyes Louisiana Kitchen  ChIJt-CEYago3YARUgQByD9srjM
# 55            Olive Pit Grill - Huntington Beach  ChIJSdeKm8Al3YARq0f9AFL2jAA
# 56              Polly's Pies Restaurant & Bakery  ChIJOalKR8Qg3YARFVhPWJ6JbM4
# 57                                        Subway  ChIJuyL_GNgg3YAR9hV03ksEQR0
# 58                                     Great Mex  ChIJQ80AY2Hf3IARUZuE7J_23lU
# 59                                        Subway  ChIJz2Ilqz4m3YARdMJHUCq4qqI

# %%
#df_google_combine.to_csv("restaurants7.csv")

# %% [markdown]
# # Google Reviews

# %%
#restaurants = pd.read_csv("restaurants7.csv")
#restaurants_df=pd.DataFrame(restaurants)
#restaurants_df= df_google_combine.copy()
# Out:
#    Unnamed: 0                              name                     place_id
# 0           0  Buca di Beppo Italian Restaurant  ChIJP5s8IkIm3YARpSuO--EX3f8
# 1           1             Hooters of Costa Mesa  ChIJ6_qtJVTf3IARdsI3DGEHn_c
# 2           2           Duke's Huntington Beach  ChIJg6yePEIh3YAR9jvzwIJzPoA
# 3           3            The Cheesecake Factory  ChIJaRncL0Mm3YARs9osub8nU1s
# 4           4       BJ's Restaurant & Brewhouse  ChIJ2ynLWlsm3YARmvBfFo6_vMQ

# %%
cols = ['name', 'place_id']
restaurants_df = pd.DataFrame(columns=cols)
for ind, row in df_google_combine.iterrows():
    #Search MondoDB to see if the restaurant name exist
    return_data = db.business.find_one({"name":row['name']})
    if return_data != None:
        my_row = {"name":row['name'],"place_id":row['place_id']}
        restaurants_df=restaurants_df.append(my_row, ignore_index=True)
        my_row.clear()
        print(f"Found Business:{ row['name']}")
# Out:
# Found Business:Chipotle Mexican Grill
# Found Business:Panda Express
# Found Business:The Donuttery
# Found Business:Five Guys
# Found Business:Jersey Mike's Subs
# Found Business:Popeyes Louisiana Kitchen

# %%
restaurants_df
# Out:
#                         name                     place_id
# 0     Chipotle Mexican Grill  ChIJixf2dlwm3YARo1mWv684OHk
# 1              Panda Express  ChIJRQNtE1An3YAR9z5rD7BMCog
# 2              The Donuttery  ChIJObOlBu4m3YAR-0rVhzIBaVc
# 3                  Five Guys  ChIJ65KCLMQm3YARosGxAiwpyIc
# 4         Jersey Mike's Subs  ChIJfdKRi_wl3YARLKqAGzrk-Cg
# 5  Popeyes Louisiana Kitchen  ChIJt-CEYago3YARUgQByD9srjM

# %%
cols = ['name', 'author_name', 'author_url', 'rating','relative_time_description','text','time']
data_google = pd.DataFrame(columns=cols)


#from config import gkey


for index,row in restaurants_df.iterrows():
    place = row['place_id']
    target_placeid = place
    target_fields = "name,rating,vicinity,reviews"
    #set up a parameters dictionary
    params = {
        "place_id": target_placeid,
        "fields": target_fields,
        "key": gkey}

    #GOOGLE URL for GET requests to retrieve restaurant data
    url="https://maps.googleapis.com/maps/api/place/details/json"
    # run a request using our params dictionary
    response = requests.get(url, params=params)
    restaurants_data=response.json()
    #print(json.dumps(restaurants_data, indent=4, sort_keys=True))
 
    name = restaurants_data['result']['name']
    #print(name)
    try:
        for resp in restaurants_data['result']['reviews']:
            my_row = {"name": name,
                      "author_name":resp['author_name'],
                      "author_url":resp['author_url'],
                      "rating":resp['rating'],
                      "relative_time_description":resp['relative_time_description'],
                      "text":resp['text'],
                      "time":resp['time']}
            data_google=data_google.append(my_row, ignore_index=True)
            my_row.clear()

    except (KeyError, IndexError):
            print("Missing field/reviews... skipping.")

# %%
data_google
# Out:
#                          name         author_name  \
# 0      Chipotle Mexican Grill     Manuel Phillips
# 1      Chipotle Mexican Grill           Carl Moss
# 2      Chipotle Mexican Grill        Craig Keller
# 3      Chipotle Mexican Grill    Anthony Caparula
# 4      Chipotle Mexican Grill           Shaz Umer
# 5               Panda Express           daimici R
# 6               Panda Express              Deby K
# 7               Panda Express        Owen Shannen
# 8               Panda Express         Marc Tailor
# 9               Panda Express       Cayden Morton
# 10              The Donuttery   Cassandra Eguiluz
# 11              The Donuttery           Red Curls
# 12              The Donuttery       Jacqui Foster
# 13              The Donuttery        Gina Hermosa
# 14              The Donuttery           Ruby Raze
# 15                  Five Guys  Alejandra Cardenas
# 16                  Five Guys       Cynthia Cerda
# 17                  Five Guys    J Aka “JULEZ” JP
# 18                  Five Guys        Michael Fulp
# 19                  Five Guys    Bogan’s King Que
# 20         Jersey Mike's Subs          Phisher 13
# 21         Jersey Mike's Subs        Bob E Castro
# 22         Jersey Mike's Subs     Darrell Bergman
# 23         Jersey Mike's Subs     Haley Kostszewa
# 24         Jersey Mike's Subs        Matt Millard
# 25  Popeyes Louisiana Kitchen          danh luong
# 26  Popeyes Louisiana Kitchen        Kathy Hebert
# 27  Popeyes Louisiana Kitchen            Gui Ewwy
# 28  Popeyes Louisiana Kitchen      S “Scheckey” H
# 29  Popeyes Louisiana Kitchen                G xo
#
#                                            author_url rating  \
# 0   https://www.google.com/maps/contrib/1150019359...      5
# 1   https://www.google.com/maps/contrib/1094602349...      3
# 17  Came to this place for the first time,the Caju...  1620828955
# 18  I have an asthma disability and am not suppose...  1617926938
# 19  I stop her on occasion just for Fries as a sna...  1618288469
# 20  Who doesn’t love Jersey Mike’s especially the ...  1613329183
# 21  Always good food, service is always the best, ...  1611294910
# 22                           Really good, great staff  1612300314
# 23  I like going to Jersey Mike's because their su...  1599419411
# 24  I've been several times and each time it's bee...  1618112939
# 25                 Alway take 25min for a small order  1599960258
# 26  My husband loves Popeye's so we went to pick u...  1619593795
# 27  Cute girl with the tattoos hooked it up thank ...  1622137587
# 28  The best fish sandwich anywhere especially at ...  1619741063
# 29  Their chicken sandwich is the best. Place is s...  1623123164

# %%
data_google.count()
# Out:
# name                         30
# author_name                  30
# author_url                   30
# rating                       30
# relative_time_description    30
# text                         30
# time                         30
# dtype: int64

# %%
data_google_all = data_google.iloc[:,1:7]

# %%
data_google_all.tail(10)
# Out:
#         author_name                                         author_url rating  \
# 20       Phisher 13  https://www.google.com/maps/contrib/1179432769...      5
# 21     Bob E Castro  https://www.google.com/maps/contrib/1020781334...      4
# 22  Darrell Bergman  https://www.google.com/maps/contrib/1108412094...      4
# 23  Haley Kostszewa  https://www.google.com/maps/contrib/1044608233...      5
# 24     Matt Millard  https://www.google.com/maps/contrib/1059153004...      2
# 25       danh luong  https://www.google.com/maps/contrib/1000639925...      1
# 26     Kathy Hebert  https://www.google.com/maps/contrib/1161220256...      3
# 27         Gui Ewwy  https://www.google.com/maps/contrib/1034361245...      5
# 28   S “Scheckey” H  https://www.google.com/maps/contrib/1148484869...      5
# 29             G xo  https://www.google.com/maps/contrib/1119016844...      4
#
#    relative_time_description  \
# 20              3 months ago
# 21              4 months ago
# 22              4 months ago
# 23              9 months ago
# 24              2 months ago
# 25              9 months ago
# 26               a month ago
# 27               2 weeks ago
# 28               a month ago
# 29          in the last week
#
#                                                  text        time
# 20  Who doesn’t love Jersey Mike’s especially the ...  1613329183
# 21  Always good food, service is always the best, ...  1611294910
# 22                           Really good, great staff  1612300314
# 23  I like going to Jersey Mike's because their su...  1599419411
# 24  I've been several times and each time it's bee...  1618112939
# 25                 Alway take 25min for a small order  1599960258
# 26  My husband loves Popeye's so we went to pick u...  1619593795
# 27  Cute girl with the tattoos hooked it up thank ...  1622137587
# 28  The best fish sandwich anywhere especially at ...  1619741063
# 29  Their chicken sandwich is the best. Place is s...  1623123164

# %%
name_business = "A11111111111aaaaaA"


for ind, row in data_google.iterrows():
    if name_business !=  row['name']:
        name_business =  row['name']
        print(f"Found Business: {name_business} ")
        dict_google_all=dict(data_google_all.iloc[ind])
        db.business.update_one(
            { 'name': name_business },
            { '$set': {"reviews_google":[dict_google_all]}}
        )
        
    else:
        dict_google_all=dict(data_google_all.iloc[ind])
        db.business.update_one(
            { 'name': name_business },
            { '$push': {"reviews_google":dict_google_all}}
        )
        
        
    
   
print (ind)
# Out:
# Found Business: Chipotle Mexican Grill
# Found Business: Panda Express
# Found Business: The Donuttery
# Found Business: Five Guys
# Found Business: Jersey Mike's Subs
# Found Business: Popeyes Louisiana Kitchen
# 29
