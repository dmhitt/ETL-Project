# %%
import pymongo
import requests
import json
import pandas as pd

from config import api_key

from yelpapi import YelpAPI
yelp_api = YelpAPI(api_key)


# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
#term = 'Mexican restaurant bar'
#location = 'Astoria, NY'
term = 'restaurant'
#location = 'Huntington Beach, CA'
search_limit = 50
latitude = 33.669445
longitude = -117.823059
radius = 10000
responses = yelp_api.search_query(term = term,
                                 limit = search_limit,
                                 latitude = latitude,
                                 longitude = longitude,
                                 radius = radius
                                )

# %%
responses
# Out:
# {'businesses': [{'id': 'NVB2X8t5Rie8S5AnzOnWJg',
#    'alias': 'north-italia-irvine',
#    'name': 'North Italia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hWa52yLwUAtiZh-xPYXGxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/north-italia-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 3658,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.67173395544756,
#     'longitude': -117.84513856994657},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2957 Michelson Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2957 Michelson Dr', 'Irvine, CA 92612']},
#    'phone': '+19496297060',
#    'display_phone': '(949) 629-7060',
#    'distance': 2059.0485682854655},
#   {'id': 'ObCj8Y3KAdk4bgc8oSxNcA',
#    'alias': 'bosscat-kitchen-and-libations-newport-beach-2',
#    'name': 'Bosscat Kitchen and Libations',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vwGSRka4NtUmHnIUt1OxzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-newport-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 3880,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.66985, 'longitude': -117.86526},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4647 MacArthur Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Newport Beach',
#     'zip_code': '92660',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4647 MacArthur Blvd', 'Newport Beach, CA 92660']},
#    'phone': '+19493330917',
#    'display_phone': '(949) 333-0917',
#    'distance': 3920.7532356741162},
#   {'id': 'H_1KkfGbwvlX2b-81ZJpoQ',
#    'alias': 'habana-costa-mesa-3',
#    'name': 'Habana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FbOA0SzkENESSE_7Jd2cVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/habana-costa-mesa-3?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 4348,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.677473708454,
#     'longitude': -117.885754645894},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2930 Bristol St',
#     'address2': 'Ste A110',
#     'address3': '',
#     'city': 'Costa Mesa',
#     'zip_code': '92626',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2930 Bristol St',
#      'Ste A110',
#      'Costa Mesa, CA 92626']},
#    'phone': '+17145560176',
#    'display_phone': '(714) 556-0176',
#    'distance': 5869.986204494037},
#   {'id': '_2OXzcN2j108hfsNGpXxtQ',
#    'alias': 'yup-dduk-irvine-irvine',
#    'name': 'Yup Dduk Irvine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nvGE8vENrXLAu3hXQ1f1XA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yup-dduk-irvine-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 81,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.649303, 'longitude': -117.832382},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4515A Campus Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4515A Campus Dr', 'Irvine, CA 92612']},
#    'phone': '+19496175620',
#    'display_phone': '(949) 617-5620',
#    'distance': 2400.1530595644017},
#   {'id': 'DGy688y4F0WAj2-CpxRALw',
#    'alias': 'the-cut-irvine-10',
#    'name': 'The Cut',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_BUb_3oXmhOjn2ITJeIxNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cut-irvine-10?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1351,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.683263, 'longitude': -117.813121},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3831 Alton Pkwy',
#     'address2': '',
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92606',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3831 Alton Pkwy', 'Irvine, CA 92606']},
#    'phone': '+19493333434',
#    'display_phone': '(949) 333-3434',
#    'distance': 1802.3767732524911},
#   {'id': 'pfDH8xb2O6cAFqou-U9lsg',
#    'alias': 'porch-and-swing-irvine',
#    'name': 'Porch & Swing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aocCj7c8dlveBgwSIRwZKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/porch-and-swing-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 162,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.68433, 'longitude': -117.851474},
#    'transactions': [],
#    'location': {'address1': '2010 Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92614',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2010 Main St', 'Irvine, CA 92614']},
#    'phone': '+18885734407',
#    'display_phone': '(888) 573-4407',
#    'distance': 3106.919581920608},
#   {'id': 'lOsQGtTweIN78TW_44bsIA',
#    'alias': 'yuk-dae-jang-irvine-irvine',
#    'name': 'Yuk Dae Jang - Irvine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g5YZvdlDLGwrG8GSe-KKtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuk-dae-jang-irvine-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 133,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.683226, 'longitude': -117.812889},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3851-A Alton Pkwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92606',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3851-A Alton Pkwy', 'Irvine, CA 92606']},
#    'phone': '+19499320911',
#    'display_phone': '(949) 932-0911',
#    'distance': 1793.4157726616304},
#   {'id': 'cvRh0PtxYgPSsEzqL2lpGg',
#    'alias': 'little-sister-irvine',
#    'name': 'Little Sister',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T_PUdaU1AYfwCvlqjGluLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-sister-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 198,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.649101628302724,
#     'longitude': -117.74096788080205},
#    'transactions': [],
#    'location': {'address1': '896 Spectrum Ctr Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92618',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['896 Spectrum Ctr Dr', 'Irvine, CA 92618']},
#    'phone': '+19498008798',
#    'display_phone': '(949) 800-8798',
#    'distance': 7927.357560246605},
#   {'id': '8d3gXfkt3DE81qRxranyUA',
#    'alias': 'súp-noodle-bar-irvine-irvine-5',
#    'name': 'Súp Noodle Bar - Irvine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tFVNb6smvDgC73EpYMQl0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/s%C3%BAp-noodle-bar-irvine-irvine-5?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 406,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.705149, 'longitude': -117.784881},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '14370 Culver Dr',
#     'address2': 'Unit 2H',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92604',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['14370 Culver Dr', 'Unit 2H', 'Irvine, CA 92604']},
#    'phone': '+16573008420',
#    'display_phone': '(657) 300-8420',
#    'distance': 5283.802274850347},
#   {'id': '_QdDPfAoJg5k3_Y6d-Rd5Q',
#    'alias': 'breakfast-republic-irvine-2',
#    'name': 'Breakfast Republic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NFKeKm5pJuOLu1x4BHNn8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/breakfast-republic-irvine-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 616,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.650451, 'longitude': -117.837774},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4213 Campus Dr',
#     'address2': 'Ste P166B',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4213 Campus Dr', 'Ste P166B', 'Irvine, CA 92612']},
#    'phone': '+19493797177',
#    'display_phone': '(949) 379-7177',
#    'distance': 2498.7806530591074},
#   {'id': '781F5q3N17g-gzJWtgJxUg',
#    'alias': 'the-lighthouse-cafe-newport-beach-2',
#    'name': 'The Lighthouse Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HnhXCqxu9rPBvoTN-o0a0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lighthouse-cafe-newport-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1809,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.608054, 'longitude': -117.922632},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1600 W Balboa Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Newport Beach',
#     'zip_code': '92663',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1600 W Balboa Blvd', 'Newport Beach, CA 92663']},
#    'phone': '+19499331001',
#    'display_phone': '(949) 933-1001',
#    'distance': 11470.39320931995},
#   {'id': 'k-IM_-OHDZLH40SEVkRuTQ',
#    'alias': 'poached-kitchen-irvine-2',
#    'name': 'Poached Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/thW7XXYAsC6jRCiI0GFk6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poached-kitchen-irvine-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 258,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.677445, 'longitude': -117.832893},
#    'transactions': [],
#    'location': {'address1': '17595 Harvard Ave',
#     'address2': 'Unit A',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92614',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['17595 Harvard Ave', 'Unit A', 'Irvine, CA 92614']},
#    'phone': '+19498601573',
#    'display_phone': '(949) 860-1573',
#    'distance': 1286.5378610486048},
#   {'id': 'lC0lp4vL-nfLRDaJU0dXRA',
#    'alias': 'cluck-kitchen-irvine',
#    'name': 'Cluck Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QHkZ4jJUPB9oNSvIfTKPzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cluck-kitchen-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 360,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.6870455, 'longitude': -117.85547267},
#    'transactions': [],
#    'location': {'address1': '17915 MacArthur Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92614',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['17915 MacArthur Blvd', 'Irvine, CA 92614']},
#    'phone': '+19494189393',
#    'display_phone': '(949) 418-9393',
#    'distance': 3581.6591084740594},
#   {'id': 'eKawmqiJVKcs0f2qrd6N2g',
#    'alias': 'tiffanys-blue-box-cafe-costa-mesa',
#    'name': 'Tiffanys Blue Box Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vJ3qhl4Z3DpKj2F2VauYIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tiffanys-blue-box-cafe-costa-mesa?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 5,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.69088014249728,
#     'longitude': -117.8890434040471},
#    'transactions': [],
#    'location': {'address1': '3333 Bristol St',
#     'address2': 'Ste 1236',
#     'address3': None,
#     'city': 'Costa Mesa',
#     'zip_code': '92626',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3333 Bristol St',
#      'Ste 1236',
#      'Costa Mesa, CA 92626']},
#    'phone': '+17145405330',
#    'display_phone': '(714) 540-5330',
#    'distance': 6554.296664348908},
#   {'id': '4Vmq51yYzlDEzCQ03zPsGg',
#    'alias': 'hironori-craft-ramen-irvine-3',
#    'name': 'HiroNori Craft Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zMlMh3bufK9prGSZMrFowQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hironori-craft-ramen-irvine-3?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 3313,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.676153, 'longitude': -117.855475},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2222 Michelson Dr',
#     'address2': 'Ste 234',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2222 Michelson Dr', 'Ste 234', 'Irvine, CA 92612']},
#    'phone': '+19495365800',
#    'display_phone': '(949) 536-5800',
#    'distance': 3091.0644257151303},
#   {'id': '8lY9YNuAQtP3Yhx7LEO9_Q',
#    'alias': 'krave-asian-fusion-restaurant-irvine',
#    'name': 'Krave Asian Fusion Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1Y2eSBXVBeyMta1ErPT9dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krave-asian-fusion-restaurant-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 641,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6802527, 'longitude': -117.8379407},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2819 Main St',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2819 Main St', 'Irvine, CA 92612']},
#    'phone': '+19493796075',
#    'display_phone': '(949) 379-6075',
#    'distance': 1860.6348206935975},
#   {'id': 'q7HDZ_et7352pRtU5Ii_Bw',
#    'alias': 'kettlebar-steam-cooking-tustin',
#    'name': 'Kettlebar Steam Cooking',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-YyT06c2BhwYI88LFRxMzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kettlebar-steam-cooking-tustin?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 734,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.69778820453633,
#     'longitude': -117.82774717819906},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2493 Park Ave',
#     'address2': 'Ste 41',
#     'address3': '',
#     'city': 'Tustin',
#     'zip_code': '92782',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2493 Park Ave', 'Ste 41', 'Tustin, CA 92782']},
#    'phone': '+17142588160',
#    'display_phone': '(714) 258-8160',
#    'distance': 3181.3293159883856},
#   {'id': 'iTEuGrVLdCRMpczd93P6fg',
#    'alias': 'furiwa-togo-irvine',
#    'name': 'Furiwa Togo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BOfQGayILMZ4oA3BCgbwbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/furiwa-togo-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 82,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.659471, 'longitude': -117.86017},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '19530 Jamboree Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['19530 Jamboree Rd', 'Irvine, CA 92612']},
#    'phone': '+19493961136',
#    'display_phone': '(949) 396-1136',
#    'distance': 3605.8021530707274},
#   {'id': 'BFWhbX6dPxKXRnXoz8MSyQ',
#    'alias': 'houstons-restaurant-irvine-3',
#    'name': "Houston's Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fhij7ZXvQCYCfE3yeOus3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/houstons-restaurant-irvine-3?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1977,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6737451506685,
#     'longitude': -117.845990918577},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '2991 Michelson Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2991 Michelson Dr', 'Irvine, CA 92612']},
#    'phone': '+19498330977',
#    'display_phone': '(949) 833-0977',
#    'distance': 2175.3114763170106},
#   {'id': '3XbjISn4xYarvoQZGxpjXg',
#    'alias': 'dun-huang-irvine-2',
#    'name': 'Dun Huang',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nVXBqOGYDasRQyRlhp6Ndw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dun-huang-irvine-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 41,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6879, 'longitude': -117.8341804},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2710 Alton Pkwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92606',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2710 Alton Pkwy', 'Irvine, CA 92606']},
#    'phone': '+19499320972',
#    'display_phone': '(949) 932-0972',
#    'distance': 2295.6763698587765},
#   {'id': '17G67GkODedOfTM5QTGCwQ',
#    'alias': 'taquiero-taco-patio-irvine',
#    'name': 'Taquiero Taco Patio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BOOhxIf8_DbzZ1WSLVBcYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taquiero-taco-patio-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 857,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6494036670827,
#     'longitude': -117.832385413349},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4517 Campus Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4517 Campus Dr', 'Irvine, CA 92612']},
#    'phone': '+19493331671',
#    'display_phone': '(949) 333-1671',
#    'distance': 2389.8250722764287},
#   {'id': 'LGstBypD7XDMm-_Q5E2cuw',
#    'alias': 'mr-french-crepe-irvine-4',
#    'name': 'Mr French Crepe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Frwxi-ldWwYpgUnxdPlRgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-french-crepe-irvine-4?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 264,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.66430683, 'longitude': -117.82493033},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '18040 Culver Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['18040 Culver Dr', 'Irvine, CA 92612']},
#    'phone': '+19492448818',
#    'display_phone': '(949) 244-8818',
#    'distance': 623.1442556294023},
#   {'id': 'r8KgB8eKHjKp-XldaXarEw',
#    'alias': 'habana-irvine-7',
#    'name': 'Habana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n9wWftenb3wsodyTzu1unw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/habana-irvine-7?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 2368,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6497611, 'longitude': -117.7453404},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '708 Spectrum Center Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92618',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['708 Spectrum Center Dr', 'Irvine, CA 92618']},
#    'phone': '+19494190100',
#    'display_phone': '(949) 419-0100',
#    'distance': 7784.378013579549},
#   {'id': 'YY0CIOpvLKTFt0wbAZ6HFw',
#    'alias': 'little-pan-fried-bun-santa-ana-2',
#    'name': 'Little Pan-Fried Bun',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cQzwWZEO353SYh0c3261MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-pan-fried-bun-santa-ana-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 117,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.6996526, 'longitude': -117.8650713},
#    'transactions': ['delivery'],
#    'location': {'address1': '2 Hutton Centre Dr',
#     'address2': 'Unit 204',
#     'address3': '',
#     'city': 'Santa Ana',
#     'zip_code': '92707',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2 Hutton Centre Dr',
#      'Unit 204',
#      'Santa Ana, CA 92707']},
#    'phone': '+16572320154',
#    'display_phone': '(657) 232-0154',
#    'distance': 5137.394988161023},
#   {'id': '-cIVY3MjLEx72BE7mnPqnQ',
#    'alias': 'vegd-costa-mesa-2',
#    'name': "VEG'D",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xyQdcLGhNtuTOcY5NcGpew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vegd-costa-mesa-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 55,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.667659, 'longitude': -117.882592},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '280 Bristol St',
#     'address2': '',
#     'address3': None,
#     'city': 'Costa Mesa',
#     'zip_code': '92626',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['280 Bristol St', 'Costa Mesa, CA 92626']},
#    'phone': '+17147604026',
#    'display_phone': '(714) 760-4026',
#    'distance': 5516.366552678711},
#   {'id': 'bjDWkmAAwkLiasMH2r0tfQ',
#    'alias': 'cava-irvine',
#    'name': 'CAVA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2IRttIbzHyN71OMaszfWkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cava-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 847,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.685125, 'longitude': -117.8106676},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3972 Barranca Pkwy',
#     'address2': '',
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92606',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3972 Barranca Pkwy', 'Irvine, CA 92606']},
#    'phone': '+19492007998',
#    'display_phone': '(949) 200-7998',
#    'distance': 2086.77910930362},
#   {'id': 'dOYLSWRRPtwQqy0ha5gi-w',
#    'alias': 'farmhouse-at-rogers-gardens-corona-del-mar',
#    'name': "Farmhouse at Roger's Gardens",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c_tuy1_YdDujC8IptVTEQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmhouse-at-rogers-gardens-corona-del-mar?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1119,
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.613306, 'longitude': -117.867218},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2301 San Joaquin Hills Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Corona del Mar',
#     'zip_code': '92625',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2301 San Joaquin Hills Rd',
#      'Corona del Mar, CA 92625']},
#    'phone': '+19496401415',
#    'display_phone': '(949) 640-1415',
#    'distance': 7461.766352356556},
#   {'id': 'LLCi9b26fUo3R4OiyQMENw',
#    'alias': 'urban-seoul-irvine-7',
#    'name': 'Urban Seoul',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vamaVIb7eRDesKt0XARMOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-seoul-irvine-7?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1552,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6881806042405,
#     'longitude': -117.833038724157},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2750 Alton Pkwy',
#     'address2': 'Ste 131',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92606',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2750 Alton Pkwy', 'Ste 131', 'Irvine, CA 92606']},
#    'phone': '+19495530188',
#    'display_phone': '(949) 553-0188',
#    'distance': 2278.791567311693},
#   {'id': 'V8KXkj4sDhRlS5G6z8-79g',
#    'alias': 'fukada-irvine',
#    'name': 'Fukada',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j8TswkrypuPeKDrWb7SEEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fukada-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 2667,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6441211395679,
#     'longitude': -117.743128531307},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '8683 Irvine Center Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92618',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8683 Irvine Center Dr', 'Irvine, CA 92618']},
#    'phone': '+19493410111',
#    'display_phone': '(949) 341-0111',
#    'distance': 7915.784038337163},
#   {'id': 'GWtMn0uGwhmrdATwvXdOig',
#    'alias': 'puesto-park-place-irvine-irvine-2',
#    'name': 'Puesto Park Place Irvine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TJ0yt7uS58WL09XHO4trEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/puesto-park-place-irvine-irvine-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 898,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.67243897019374,
#     'longitude': -117.84470967975923},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3311 Michelson Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3311 Michelson Dr', 'Irvine, CA 92612']},
#    'phone': '+19496087272',
#    'display_phone': '(949) 608-7272',
#    'distance': 2031.0297465761932},
#   {'id': 'MRLaK1Xf9RXC7vwBdt-t2Q',
#    'alias': 'lagu-cafe-irvine',
#    'name': 'Lagu Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2jhNJqQKBYC8k889wfb59g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lagu-cafe-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 82,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.687098, 'longitude': -117.8582203},
#    'transactions': [],
#    'location': {'address1': '17779 Main St',
#     'address2': 'Ste J',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92614',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['17779 Main St', 'Ste J', 'Irvine, CA 92614']},
#    'phone': '+19494187023',
#    'display_phone': '(949) 418-7023',
#    'distance': 3799.8293786747686},
#   {'id': 'eIL07_zmZa4-rh84EAtnwg',
#    'alias': 'haidilao-hot-pot-irvine',
#    'name': 'Haidilao Hot Pot',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zBsJz4jKNYcaHVvGnRraWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/haidilao-hot-pot-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 804,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.6877019718328,
#     'longitude': -117.834180481732},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '2710 Alton Pkwy',
#     'address2': 'Ste 215',
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92606',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2710 Alton Pkwy', 'Ste 215', 'Irvine, CA 92606']},
#    'phone': '+19495661766',
#    'display_phone': '(949) 566-1766',
#    'distance': 2276.0183650375825},
#   {'id': 'yZQ07EM9MxZcKhz2hBRs9w',
#    'alias': 'the-kebab-shop-irvine-4',
#    'name': 'The Kebab Shop',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2tS-dYnrLJvkx3KwULNThw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-kebab-shop-irvine-4?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 303,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.67611, 'longitude': -117.83279},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '17655-G Harvard Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92614',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['17655-G Harvard Ave', 'Irvine, CA 92614']},
#    'phone': '+19492580858',
#    'display_phone': '(949) 258-0858',
#    'distance': 1148.2270696224316},
#   {'id': 'jTyfj3e8PIkc4KTVh3sAqw',
#    'alias': 'mendocino-farms-irvine',
#    'name': 'Mendocino Farms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K75XnHTj8fH4z3xXcvyHrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mendocino-farms-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 621,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.6508949, 'longitude': -117.8391509},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4175 Campus Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4175 Campus Dr', 'Irvine, CA 92612']},
#    'phone': '+19497832900',
#    'display_phone': '(949) 783-2900',
#    'distance': 2544.1591202421832},
#   {'id': 'VG49sqWkv_FU_x8g4wFL4w',
#    'alias': 'everyday-eatery-irvine',
#    'name': 'Everyday Eatery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tmVMaU3HRST6m3v0TY3Dww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/everyday-eatery-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 532,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.6686484281849,
#     'longitude': -117.764629460871},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6634 Irvine Ctr Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92618',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6634 Irvine Ctr Dr', 'Irvine, CA 92618']},
#    'phone': '+19494187172',
#    'display_phone': '(949) 418-7172',
#    'distance': 5407.928805076735},
#   {'id': 'LGhB09xPiHd2M_D9y8N_rA',
#    'alias': 'champion-s-curry-irvine-irvine',
#    'name': 'Champion’s Curry Irvine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/55qA513AYDkOZNSqX-vSjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/champion-s-curry-irvine-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 28,
#    'categories': [{'alias': 'japacurry', 'title': 'Japanese Curry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.676164, 'longitude': -117.855446},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2222 Michelson Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2222 Michelson Dr', 'Irvine, CA 92612']},
#    'phone': '+19494189315',
#    'display_phone': '(949) 418-9315',
#    'distance': 3077.257591182794},
#   {'id': 'Ewuh4AQEbjGMR0r8lVtrXw',
#    'alias': 'hanuman-thai-eatery-costa-mesa',
#    'name': 'Hanuman Thai Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/86aH6gku0c-eSq1ISCBurg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hanuman-thai-eatery-costa-mesa?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 254,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.664666, 'longitude': -117.880608},
#    'transactions': [],
#    'location': {'address1': '355 Bristol St',
#     'address2': 'Ste U',
#     'address3': '',
#     'city': 'Costa Mesa',
#     'zip_code': '92626',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['355 Bristol St', 'Ste U', 'Costa Mesa, CA 92626']},
#    'phone': '+16576993123',
#    'display_phone': '(657) 699-3123',
#    'distance': 5343.073440651181},
#   {'id': 'pzIlvsAitnIYcR244HmsgA',
#    'alias': 'curry-house-coco-ichibanya-irvine',
#    'name': 'Curry House CoCo Ichibanya',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gsQot36RdLHk25fd7vHNLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/curry-house-coco-ichibanya-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 2165,
#    'categories': [{'alias': 'japacurry', 'title': 'Japanese Curry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6877021, 'longitude': -117.8341804},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2710 Alton Pkwy',
#     'address2': 'Ste 115',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92606',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2710 Alton Pkwy', 'Ste 115', 'Irvine, CA 92606']},
#    'phone': '+19495531082',
#    'display_phone': '(949) 553-1082',
#    'distance': 2276.0276567834367},
#   {'id': 'NjWQGZckP21rq7Ok7zqyHA',
#    'alias': 'all-that-shabu-irvine-3',
#    'name': 'All That Shabu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TCAbfljMWKLOOSEx0L2nww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/all-that-shabu-irvine-3?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 324,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.697191, 'longitude': -117.799793},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '15315 Culver Dr',
#     'address2': 'Ste 145',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92604',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['15315 Culver Dr', 'Ste 145', 'Irvine, CA 92604']},
#    'phone': '+19493335222',
#    'display_phone': '(949) 333-5222',
#    'distance': 3750.0531792658317},
#   {'id': 'ZwkABJ3bpYwirX_WPUSpGQ',
#    'alias': 'vaca-costa-mesa',
#    'name': 'Vaca',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YtmYCuCDDLSWfoIx5TdUaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vaca-costa-mesa?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1328,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6920504459841,
#     'longitude': -117.884018211482},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '695 Town Center Dr',
#     'address2': 'Ste 170',
#     'address3': '',
#     'city': 'Costa Mesa',
#     'zip_code': '92626',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['695 Town Center Dr',
#      'Ste 170',
#      'Costa Mesa, CA 92626']},
#    'phone': '+17144636060',
#    'display_phone': '(714) 463-6060',
#    'distance': 6175.264213861546},
#   {'id': 'XzwtHlfm09aXM6ujqQ53xA',
#    'alias': 'ky-sushi-irvine',
#    'name': 'KY Sushi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ISpit4Aqyt04hobjno9hIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ky-sushi-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 41,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.649667, 'longitude': -117.832246},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'location': {'address1': '4527 Campus Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4527 Campus Dr', 'Irvine, CA 92612']},
#    'phone': '+19493333951',
#    'display_phone': '(949) 333-3951',
#    'distance': 2382.665699081622},
#   {'id': 'uxp3aLctj-EeEQcoN7QNmw',
#    'alias': 'wagyu-meat-and-grill-irvine-6',
#    'name': 'Wagyu Meat And Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qqFVlS6jq4c4rr9GvmNmSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wagyu-meat-and-grill-irvine-6?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 159,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'butcher', 'title': 'Butcher'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.6954847228179,
#     'longitude': -117.799217216671},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '15333 Culver Dr',
#     'address2': 'Ste 440',
#     'address3': None,
#     'city': 'Irvine ',
#     'zip_code': '92604',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['15333 Culver Dr', 'Ste 440', 'Irvine , CA 92604']},
#    'phone': '+19494187493',
#    'display_phone': '(949) 418-7493',
#    'distance': 3640.106997886754},
#   {'id': 'bZw7XsPXY3lfdluCFNxLtQ',
#    'alias': 'oo-toro-sushi-irvine',
#    'name': 'Oo Toro Sushi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nO2BDLaX0p4xRUtkR5WGPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oo-toro-sushi-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 566,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.67634, 'longitude': -117.85524},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '2222 Michelson Dr',
#     'address2': 'Ste 246',
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2222 Michelson Dr', 'Ste 246', 'Irvine, CA 92612']},
#    'phone': '+19492220688',
#    'display_phone': '(949) 222-0688',
#    'distance': 3077.257591182794},
#   {'id': '0fzkGamJANELt48Abp7fQg',
#    'alias': 'tavos-cocina-irvine',
#    'name': "Tavo's Cocina",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WjnZwzPRA3G0g34nigIwWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tavos-cocina-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 50,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.676164, 'longitude': -117.855446},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2222 Michelson Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2222 Michelson Dr', 'Irvine, CA 92612']},
#    'phone': '+19494188063',
#    'display_phone': '(949) 418-8063',
#    'distance': 3077.257591182794},
#   {'id': '7NYhG0KCJM2c_UkwoPDgVQ',
#    'alias': 'yigah-restaurant-irvine-2',
#    'name': 'Yigah Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d_wFjCL91UVm3Sg8ibRVYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yigah-restaurant-irvine-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 586,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6881858, 'longitude': -117.8328273},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2750 Alton Pkwy',
#     'address2': 'Ste 105',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92606',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2750 Alton Pkwy', 'Ste 105', 'Irvine, CA 92606']},
#    'phone': '+19494750011',
#    'display_phone': '(949) 475-0011',
#    'distance': 2271.464246524818},
#   {'id': 'QzJxZ67PVrqy6Z_5gKfxyw',
#    'alias': 'le-diplomate-cafe-irvine',
#    'name': 'Le Diplomate Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qPt7kLwXFkuGv-aA8pGuVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-diplomate-cafe-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1808,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.650408, 'longitude': -117.838442},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '4237 Campus Dr',
#     'address2': 'Ste B161',
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4237 Campus Dr', 'Ste B161', 'Irvine, CA 92612']},
#    'phone': '+19498545161',
#    'display_phone': '(949) 854-5161',
#    'distance': 2551.060949868766},
#   {'id': 'f36479FQOOMrOVm0fH_Mog',
#    'alias': 'dpot-irvine-2',
#    'name': 'dPot',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/222gUiqYsdBidw8x2O7dsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dpot-irvine-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 35,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.67721580285927,
#     'longitude': -117.79981999050655},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4636 Barranca Pkwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92604',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4636 Barranca Pkwy', 'Irvine, CA 92604']},
#    'phone': '+19494187993',
#    'display_phone': '(949) 418-7993',
#    'distance': 2317.585755784781},
#   {'id': 'Z33F5KGv0eMLiz2_8zU5KA',
#    'alias': 'urban-plates-irvine',
#    'name': 'Urban Plates',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mjCWB-15U3EZb-t2rKnsmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-plates-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1835,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.684886, 'longitude': -117.810632},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3972 Barranca Pkwy',
#     'address2': 'N',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92606',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3972 Barranca Pkwy', 'N', 'Irvine, CA 92606']},
#    'phone': '+19493872600',
#    'display_phone': '(949) 387-2600',
#    'distance': 2050.009806113717},
#   {'id': 'euzs-7Rv8BqYBYGYuh2O-Q',
#    'alias': 'ellies-table-at-the-boardwalk-irvine',
#    'name': "Ellie's Table at The Boardwalk",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_bMouTmkfbQ74kMpLEBlRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ellies-table-at-the-boardwalk-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 9,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.669928, 'longitude': -117.851080666584},
#    'transactions': [],
#    'location': {'address1': '18565 Jamboree Rd',
#     'address2': 'Ste 175',
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['18565 Jamboree Rd', 'Ste 175', 'Irvine, CA 92612']},
#    'phone': '+17145402303',
#    'display_phone': '(714) 540-2303',
#    'distance': 2593.726052958513},
#   {'id': 'SF5MW5Qg3cmiww7BV4NK1w',
#    'alias': 'broken-rice-irvine-2',
#    'name': 'Broken Rice',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YQBOWbS2YpzjwGnmEc9sZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/broken-rice-irvine-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 53,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.67634, 'longitude': -117.85524},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2222 Michelson Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2222 Michelson Dr', 'Irvine, CA 92612']},
#    'phone': '+19494189208',
#    'display_phone': '(949) 418-9208',
#    'distance': 3077.257591182794}],
#  'total': 2400,
#  'region': {'center': {'longitude': -117.823059, 'latitude': 33.669445}}}

# %%
responses.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
responses['businesses'][0].keys()
# Out:
# dict_keys(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'price', 'location', 'phone', 'display_phone', 'distance'])

# %%
total = responses['total']
print (total)
# Out:
# 2400

# %%
responses['region']
# Out:
# {'center': {'longitude': -117.823059, 'latitude': 33.669445}}

# %%
#for biz in response['businesses']:
#    print(biz['name'])
#    print(biz['url'])
#    print(biz['location']['address1'])
#    print(biz['location']['city'])
#    #print(biz['categories'][0]['title'])
#    for cat in biz['categories']:
#        print (cat)
#        print(cat['title'])
#    print ('-------')

# %%
cols = list(responses['businesses'][0].keys())
data_businesses = pd.DataFrame(columns=cols)
for biz in responses['businesses']:
    data_businesses = data_businesses.append(biz, ignore_index=True)

# %%
data_businesses.head()
# Out:
#                        id                                          alias  \
# 0  NVB2X8t5Rie8S5AnzOnWJg                            north-italia-irvine
# 1  ObCj8Y3KAdk4bgc8oSxNcA  bosscat-kitchen-and-libations-newport-beach-2
# 2  H_1KkfGbwvlX2b-81ZJpoQ                            habana-costa-mesa-3
# 3  _2OXzcN2j108hfsNGpXxtQ                         yup-dduk-irvine-irvine
# 4  DGy688y4F0WAj2-CpxRALw                              the-cut-irvine-10
#
#                             name  \
# 0                   North Italia
# 1  Bosscat Kitchen and Libations
# 2                         Habana
# 3                Yup Dduk Irvine
# 4                        The Cut
#
#                                            image_url is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/hWa52y...     False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/vwGSRk...     False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/FbOA0S...     False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/nvGE8v...     False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/_BUb_3...     False
#
#                                                  url review_count  \
# 0  https://www.yelp.com/biz/north-italia-irvine?a...         3658
# 1  https://www.yelp.com/biz/bosscat-kitchen-and-l...         3880
# 2  https://www.yelp.com/biz/habana-costa-mesa-3?a...         4348
# 3  https://www.yelp.com/biz/yup-dduk-irvine-irvin...           81
# 4  https://www.yelp.com/biz/the-cut-irvine-10?adj...         1351
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 2  [{'alias': 'cuban', 'title': 'Cuban'}, {'alias...     4.0
# 3  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 4  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
#
#                                          coordinates  \
# 0  {'latitude': 33.67173395544756, 'longitude': -...
# 1    {'latitude': 33.66985, 'longitude': -117.86526}
# 2  {'latitude': 33.677473708454, 'longitude': -11...
# 3  {'latitude': 33.649303, 'longitude': -117.832382}
# 4  {'latitude': 33.683263, 'longitude': -117.813121}
#
#                                  transactions price  \
# 0                                  [delivery]    $$
# 1  [restaurant_reservation, pickup, delivery]    $$
# 2                          [delivery, pickup]    $$
# 3                          [delivery, pickup]   NaN
# 4                          [delivery, pickup]    $$
#
#                                             location         phone  \
# 0  {'address1': '2957 Michelson Dr', 'address2': ...  +19496297060
# 1  {'address1': '4647 MacArthur Blvd', 'address2'...  +19493330917
# 2  {'address1': '2930 Bristol St', 'address2': 'S...  +17145560176
# 3  {'address1': '4515A Campus Dr', 'address2': No...  +19496175620
# 4  {'address1': '3831 Alton Pkwy', 'address2': ''...  +19493333434
#
#     display_phone     distance
# 0  (949) 629-7060  2059.048568
# 1  (949) 333-0917  3920.753236
# 2  (714) 556-0176  5869.986204
# 3  (949) 617-5620  2400.153060
# 4  (949) 333-3434  1802.376773

# %%
data_businesses.count()
# Out:
# id               50
# alias            50
# name             50
# image_url        50
# is_closed        50
# url              50
# review_count     50
# categories       50
# rating           50
# coordinates      50
# transactions     50
# price            30
# location         50
# phone            50
# display_phone    50
# distance         50
# dtype: int64

# %%
print(data_businesses.location[0])
# Out:
# {'address1': '4647 MacArthur Blvd', 'address2': None, 'address3': '', 'city': 'Newport Beach', 'zip_code': '92660', 'country': 'US', 'state': 'CA', 'display_address': ['4647 MacArthur Blvd', 'Newport Beach, CA 92660']}

# %%
count_retrive = 50
while count_retrive < total :
    term = 'restaurant'
    search_limit = 50
    latitude = 33.669445
    longitude = -117.823059
    radius = 10000
    offset = 50
    responses = yelp_api.search_query(term = term,
                                 limit = search_limit,
                                 latitude = latitude,
                                 longitude = longitude,
                                 radius = radius,
                                 offset = offset
                                )

    for biz in responses['businesses']:
        data_businesses = data_businesses.append(biz, ignore_index=True)

    count_retrive += 50

# %%
data_businesses.count()
# Out:
# id               2400
# alias            2400
# name             2400
# image_url        2400
# is_closed        2400
# url              2400
# review_count     2400
# categories       2400
# rating           2400
# coordinates      2400
# transactions     2400
# price            1958
# location         2400
# phone            2400
# display_phone    2400
# distance         2400
# dtype: int64

# %%
data_businesses.tail(9)
# Out:
#                           id                                        alias  \
# 2391  Ho-O2ZQe7Hx-7WS4cACI6Q                     kona-loa-coffee-irvine-4
# 2392  cS2xArTtv4PhbivpQkNQpg        bello-by-sandro-nardone-newport-beach
# 2393  yWn2EnP3IKnp_IfdGuPCUQ  the-winery-restaurant-and-wine-bar-tustin-2
# 2394  PnSBjfeLhz8YY9G87smvpA                             noodology-irvine
# 2395  sx6PqyCieC48Mr1Q6j41WA                    portside-fish-co-irvine-4
# 2396  GSyJHTnCMIndZE4OhS39OQ  panini-kabob-grill-irvine-park-place-irvine
# 2397  -TS_adp_nEbBFXxBMc8qUg                            tim-ho-wan-irvine
# 2398  2cecrkpqCRRTeUpE8M_VRA                          utopia-caffe-tustin
# 2399  SDOF4LT65dgU2e5RX3dgzg        la-boulangerie-san-francisco-irvine-2
#
#                                         name  \
# 2391                         Kona Loa Coffee
# 2392                 Bello by Sandro Nardone
# 2393        The Winery Restaurant & Wine Bar
# 2394                               Noodology
# 2395                        Portside Fish Co
# 2396  Panini Kabob Grill - Irvine Park Place
# 2397                              Tim Ho Wan
# 2398                            Utopia Caffe
# 2399            La Boulangerie San Francisco
#
#                                               image_url is_closed  \
# 2391  https://s3-media3.fl.yelpcdn.com/bphoto/dsDVyt...     False
# 2392  https://s3-media2.fl.yelpcdn.com/bphoto/FPUJTA...     False
# 2393  https://s3-media4.fl.yelpcdn.com/bphoto/NXV_pM...     False
# 2394  https://s3-media1.fl.yelpcdn.com/bphoto/BAQzhZ...     False
# 2395  https://s3-media3.fl.yelpcdn.com/bphoto/a24KKk...     False
# 2396  https://s3-media1.fl.yelpcdn.com/bphoto/szz2cZ...     False
# 2397  https://s3-media1.fl.yelpcdn.com/bphoto/ZdeR-J...     False
# 2398  https://s3-media2.fl.yelpcdn.com/bphoto/Vv5XXI...     False
# 2399  https://s3-media4.fl.yelpcdn.com/bphoto/fakrgI...     False
#
#                                                     url review_count  \
# 2391  https://www.yelp.com/biz/kona-loa-coffee-irvin...          486
# 2392  https://www.yelp.com/biz/bello-by-sandro-nardo...          248
# 2393  https://www.yelp.com/biz/the-winery-restaurant...         1119
# 2394  https://www.yelp.com/biz/noodology-irvine?adju...          851
# 2395  https://www.yelp.com/biz/portside-fish-co-irvi...          420
# 2396  https://www.yelp.com/biz/panini-kabob-grill-ir...         1306
# 2397  https://www.yelp.com/biz/tim-ho-wan-irvine?adj...         1154
# 2398  https://www.yelp.com/biz/utopia-caffe-tustin?a...          533
# 2399  https://www.yelp.com/biz/la-boulangerie-san-fr...           74
#
#                                              categories  rating  \
# 2391  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 2392  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 2393  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     4.0
# 2394  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
# 2395  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 2396  [{'alias': 'mediterranean', 'title': 'Mediterr...     4.0
# 2397          [{'alias': 'dimsum', 'title': 'Dim Sum'}]     3.0
# 2398  [{'alias': 'modern_european', 'title': 'Modern...     4.0
# 2399  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.0
#
#                                             coordinates        transactions  \
# 2391  {'latitude': 33.688173, 'longitude': -117.832973}  [pickup, delivery]
# 2392    {'latitude': 33.63812, 'longitude': -117.86334}  [pickup, delivery]
# 2393  {'latitude': 33.6979801, 'longitude': -117.825...  [pickup, delivery]
# 2394  {'latitude': 33.680544, 'longitude': -117.778729}  [pickup, delivery]
# 2395  {'latitude': 33.676164, 'longitude': -117.855446}  [pickup, delivery]
# 2396   {'latitude': 33.673485, 'longitude': -117.84537}  [pickup, delivery]
# 2397  {'latitude': 33.68829074250044, 'longitude': -...  [pickup, delivery]
# 2398  {'latitude': 33.6974555, 'longitude': -117.827...  [pickup, delivery]
# 2399  {'latitude': 33.6714678, 'longitude': -117.788...  [pickup, delivery]
#
#      price                                           location         phone  \
# 2391     $  {'address1': '2750 Alton Pkwy', 'address2': 'S...  +19498612611
# 2392   $$$  {'address1': '1200 Bison Ave', 'address2': '',...  +19495207191
# 2393   $$$  {'address1': '2647 Park Ave', 'address2': '', ...  +17142587600
# 2394    $$  {'address1': '15455 Jeffrey Rd', 'address2': '...  +19493367338
# 2395    $$  {'address1': '2222 Michelson Dr', 'address2': ...  +19495365660
# 2396    $$  {'address1': '3041 Michelson Dr', 'address2': ...  +19492609800
# 2397    $$  {'address1': '2700 Alton Pkwy', 'address2': 'S...  +12628888828
# 2398    $$  {'address1': '2489 Park Ave', 'address2': None...  +17143525789
# 2399   NaN  {'address1': '5365 Alton Pkwy', 'address2': 'S...  +19495014588
#
#        display_phone     distance
# 2391  (949) 861-2611  2272.658222
# 2392  (949) 520-7191  5111.982019
# 2393  (714) 258-7600  3090.961412
# 2394  (949) 336-7338  4276.449679
# 2395  (949) 536-5660  3077.257591
# 2396  (949) 260-9800  2112.959294
# 2397  (262) 888-8828  2325.931032
# 2398  (714) 352-5789  3146.942711
# 2399  (949) 501-4588  3163.212413

# %% [markdown]
# # Insert Business into MongoDB

# %%
# Define the 'restaurantes_db' database in Mongo
db = client.restaurants_db

# Declare the collections
business = db.business
reviews = db.reviews

records = json.loads(data_businesses.T.to_json()).values()
db.business.insert_many(records)

#records = json.loads(data_review.T.to_json()).values()
#db.reviews.insert_many(records)

# %%
responses_review = yelp_api.reviews_query(id = 'ObCj8Y3KAdk4bgc8oSxNcA')
       
responses_review
# Out:
# {'reviews': [{'id': 'Dg4yBmkmwQy_pFYJo_BDzw',
#    'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-newport-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&hrid=Dg4yBmkmwQy_pFYJo_BDzw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'text': 'I am not much of a "yelper" but I just had to because:  this place is amazing!! \n\nI came here for cocktails and appetizers with some girlfriends after...',
#    'rating': 5,
#    'time_created': '2021-05-12 06:00:58',
#    'user': {'id': '7yDT2Ut-ue87feaS6IXUVA',
#     'profile_url': 'https://www.yelp.com/user_details?userid=7yDT2Ut-ue87feaS6IXUVA',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/FPTFrIp-jzWKfXuqe78cag/o.jpg',
#     'name': 'Connie R.'}},
#   {'id': 'rk9fCVX6anEgJfKFOcNiUw',
#    'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-newport-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&hrid=rk9fCVX6anEgJfKFOcNiUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'text': 'Fantastic place for food and drinks. Our waiter Morgan was awesome and very nice. He suggested the brick chicken and fried apple pie! Both were very...',
#    'rating': 5,
#    'time_created': '2021-04-26 21:49:30',
#    'user': {'id': '6zkyg1QGnXeLGDsC0hRXiw',
#     'profile_url': 'https://www.yelp.com/user_details?userid=6zkyg1QGnXeLGDsC0hRXiw',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/yIE0T80LGjG-T-KvB-OJCQ/o.jpg',
#     'name': 'Dan R.'}},
#   {'id': 'uL_XJIHn4qgSf3dsf12zZg',
#    'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-newport-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&hrid=uL_XJIHn4qgSf3dsf12zZg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'text': "This place is so good! Great food, great service, great atmosphere. What more could you want?! Definitely the best place we've had dinner in the circle.",
#    'rating': 5,
#    'time_created': '2021-05-19 18:17:01',
#    'user': {'id': 'RTNsjstRIa9xVY2-QFPeSw',
#     'profile_url': 'https://www.yelp.com/user_details?userid=RTNsjstRIa9xVY2-QFPeSw',
#     'image_url': None,
#     'name': 'Alex B.'}}],
#  'total': 3880,
#  'possible_languages': ['en', 'ja']}

# %% [markdown]
# # New API Call to Retrieve the Reviews

# %%
first_time = True

for index, row in data_businesses.iterrows():
    
    id_business =  row['id']
    responses_review = yelp_api.reviews_query(id = id_business)
    if first_time:
        print (f'index = {index}')
        cols = list(responses_review['reviews'][0].keys())
        cols.append('id_reviews')
        print(cols)
        data_reviews = pd.DataFrame(columns=cols)
        first_time = False

    
    for resp in responses_review['reviews']:
        #print (f"resp = {resp}")
        my_row = {"id":id_business, 
                "url":resp['url'],
                "text":resp['text'],
                "rating":resp['rating'],
                "time_created":resp['time_created'],
                "user":resp['user'],
                "id_reviews":resp['id']}                    
        #my_row.append(id_business)
        #print (f"my_row = {my_row}")
        #print ('----')
        data_reviews=data_reviews.append(my_row, ignore_index=True)
        my_row.clear()
        
     
print (f'index = {index}')
# Out:
# index = 0
# ['id', 'url', 'text', 'rating', 'time_created', 'user', 'id_reviews']
# index = 49

# %%
data_reviews.count()
total_reviews=(len(data_reviews))

# %%
data_reviews.tail(5)
# Out:
#                          id  \
# 145  euzs-7Rv8BqYBYGYuh2O-Q
# 146  euzs-7Rv8BqYBYGYuh2O-Q
# 147  SF5MW5Qg3cmiww7BV4NK1w
# 148  SF5MW5Qg3cmiww7BV4NK1w
# 149  SF5MW5Qg3cmiww7BV4NK1w
#
#                                                    url  \
# 145  https://www.yelp.com/biz/ellies-table-at-the-b...
# 146  https://www.yelp.com/biz/ellies-table-at-the-b...
# 147  https://www.yelp.com/biz/broken-rice-irvine-2?...
# 148  https://www.yelp.com/biz/broken-rice-irvine-2?...
# 149  https://www.yelp.com/biz/broken-rice-irvine-2?...
#
#                                                   text rating  \
# 145  Not worth the drive if you are from South Oran...      3
# 146  They have a good variety of light lunch items ...      4
# 147  This morning I was craving something healthy a...      5
# 148  I am a big fan of Broken Rice! I have been wan...      4
# 149  It's really good! I love that they have vegan ...      5
#
#             time_created                                               user  \
# 145  2019-12-27 10:59:29  {'id': 'b0pGpdBx44T-6FgalyYGHQ', 'profile_url'...
# 146  2020-02-14 20:03:25  {'id': 'TIxSXbZMNgyLxO-QqBSNOA', 'profile_url'...
# 147  2021-06-02 11:35:14  {'id': 'bQHfJWanwxFqW0E2VexuBg', 'profile_url'...
# 148  2021-03-25 18:17:50  {'id': 'uQHaTxwIf8y2fglDVQLYuQ', 'profile_url'...
# 149  2021-03-28 18:28:14  {'id': 'lWrKhhn7SnaGejxok6qy5g', 'profile_url'...
#
#                  id_reviews
# 145  nrCauYfEXid-M-EEix__Fw
# 146  ZA__5mn1vC8Y2AGMbVONCA
# 147  et7gsk8N-CggAfSY5CY1EQ
# 148  sliUGjMmN_rBkvgjixZE-g
# 149  a2bs1Ilxord_XpHPxAjNtw

# %%
key_business=str(data_reviews.iloc[0:0,0:0])
print(key_business)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data_reviews_bus_id = data_reviews.iloc[:,0]
data_reviews_bus_id.head()
# Out:
# 0    NVB2X8t5Rie8S5AnzOnWJg
# 1    NVB2X8t5Rie8S5AnzOnWJg
# 2    NVB2X8t5Rie8S5AnzOnWJg
# 3    ObCj8Y3KAdk4bgc8oSxNcA
# 4    ObCj8Y3KAdk4bgc8oSxNcA
# Name: id, dtype: object

# %%
data_reviews_all = data_reviews.iloc[:,1:7]
data_reviews_all.head()
# Out:
#                                                  url  \
# 0  https://www.yelp.com/biz/north-italia-irvine?a...
# 1  https://www.yelp.com/biz/north-italia-irvine?a...
# 2  https://www.yelp.com/biz/north-italia-irvine?a...
# 3  https://www.yelp.com/biz/bosscat-kitchen-and-l...
# 4  https://www.yelp.com/biz/bosscat-kitchen-and-l...
#
#                                                 text rating  \
# 0  Fresh, open and delicious!\nGreat big windows ...      5
# 1  My boyfriend and I went here this past sunday ...      5
# 2  We've dined with North Italia a few times now ...      5
# 3  I am not much of a "yelper" but I just had to ...      5
# 4  Fantastic place for food and drinks. Our waite...      5
#
#           time_created                                               user  \
# 0  2021-05-17 10:07:45  {'id': 'h83-F-dq81PWxla8ILg79w', 'profile_url'...
# 1  2021-05-07 19:45:35  {'id': '5gATwBk53RvEGvE5mbI0Tg', 'profile_url'...
# 2  2021-05-30 19:40:40  {'id': 'wkdlOcDPaGM_EPnrqvqY-Q', 'profile_url'...
# 3  2021-05-12 06:00:58  {'id': '7yDT2Ut-ue87feaS6IXUVA', 'profile_url'...
# 4  2021-04-26 21:49:30  {'id': '6zkyg1QGnXeLGDsC0hRXiw', 'profile_url'...
#
#                id_reviews
# 0  VYCX2yQnkNFmibLTmR1Btw
# 1  IuKaRtXRPdISHKwrV6EQ7g
# 2  Knl-TrrtXYu5Dtwz2VXr-A
# 3  Dg4yBmkmwQy_pFYJo_BDzw
# 4  rk9fCVX6anEgJfKFOcNiUw

# %%
key_business = "O111111111111111aaaaaA"


for ind, row in data_reviews.iterrows():
           
    if key_business !=  row['id']:
        key_business =  row['id']
        print ('---here----')
        print(key_business)
        dict_reviews_all=dict(data_reviews_all.iloc[ind])
        db.business.update_one(
           { 'id': key_business },
           { '$set': {"reviews_person":[dict_reviews_all]}}
        )
        
    else:
        print('----2---')
        print(key_business)
        dict_reviews_all=dict(data_reviews_all.iloc[ind])
        #print(dict_reviews)
        db.business.update_one(
           { 'id': key_business },
           { '$push': {"reviews_person":dict_reviews_all}}
        )
        
        
    
   
print (ind)
# Out:
# ---here----
# NVB2X8t5Rie8S5AnzOnWJg
# ----2---
# NVB2X8t5Rie8S5AnzOnWJg
# ----2---
# NVB2X8t5Rie8S5AnzOnWJg
# ---here----
# ObCj8Y3KAdk4bgc8oSxNcA
# ----2---
# ObCj8Y3KAdk4bgc8oSxNcA
# ----2---
# ObCj8Y3KAdk4bgc8oSxNcA
# ---here----
# H_1KkfGbwvlX2b-81ZJpoQ
# ----2---
# H_1KkfGbwvlX2b-81ZJpoQ
# ----2---
# H_1KkfGbwvlX2b-81ZJpoQ
# ---here----
# _2OXzcN2j108hfsNGpXxtQ
# ----2---
# _2OXzcN2j108hfsNGpXxtQ
# ----2---
# _2OXzcN2j108hfsNGpXxtQ
# ---here----
# DGy688y4F0WAj2-CpxRALw
# ----2---
# DGy688y4F0WAj2-CpxRALw
# ----2---
# DGy688y4F0WAj2-CpxRALw
# ---here----
# pfDH8xb2O6cAFqou-U9lsg
# ----2---
# pfDH8xb2O6cAFqou-U9lsg
# ----2---
# pfDH8xb2O6cAFqou-U9lsg
# ---here----
# lOsQGtTweIN78TW_44bsIA
# ----2---
# lOsQGtTweIN78TW_44bsIA
# ----2---
# lOsQGtTweIN78TW_44bsIA
# ---here----
# cvRh0PtxYgPSsEzqL2lpGg
# ----2---
# cvRh0PtxYgPSsEzqL2lpGg
# ----2---
# cvRh0PtxYgPSsEzqL2lpGg
# ---here----
# 8d3gXfkt3DE81qRxranyUA
# ----2---
# 8d3gXfkt3DE81qRxranyUA
# ----2---
# 8d3gXfkt3DE81qRxranyUA
# ---here----
# _QdDPfAoJg5k3_Y6d-Rd5Q
# ----2---
# _QdDPfAoJg5k3_Y6d-Rd5Q
# ----2---
# _QdDPfAoJg5k3_Y6d-Rd5Q
# ---here----
# 781F5q3N17g-gzJWtgJxUg
# ----2---
# 781F5q3N17g-gzJWtgJxUg
# ----2---
# 781F5q3N17g-gzJWtgJxUg
# ---here----
# k-IM_-OHDZLH40SEVkRuTQ
# ----2---
# k-IM_-OHDZLH40SEVkRuTQ
# ----2---
# k-IM_-OHDZLH40SEVkRuTQ
# ---here----
# lC0lp4vL-nfLRDaJU0dXRA
# ----2---
# lC0lp4vL-nfLRDaJU0dXRA
# ----2---
# lC0lp4vL-nfLRDaJU0dXRA
# ---here----
# eKawmqiJVKcs0f2qrd6N2g
# ----2---
# eKawmqiJVKcs0f2qrd6N2g
# ----2---
# eKawmqiJVKcs0f2qrd6N2g
# ---here----
# 4Vmq51yYzlDEzCQ03zPsGg
# ----2---
# 4Vmq51yYzlDEzCQ03zPsGg
# ----2---
# 4Vmq51yYzlDEzCQ03zPsGg
# ---here----
# 8lY9YNuAQtP3Yhx7LEO9_Q
# ----2---
# 8lY9YNuAQtP3Yhx7LEO9_Q
# ----2---
# 8lY9YNuAQtP3Yhx7LEO9_Q
# ---here----
# q7HDZ_et7352pRtU5Ii_Bw
# ----2---
# q7HDZ_et7352pRtU5Ii_Bw
# ----2---
# q7HDZ_et7352pRtU5Ii_Bw
# ---here----
# iTEuGrVLdCRMpczd93P6fg
# ----2---
# iTEuGrVLdCRMpczd93P6fg
# ----2---
# iTEuGrVLdCRMpczd93P6fg
# ---here----
# BFWhbX6dPxKXRnXoz8MSyQ
# ----2---
# BFWhbX6dPxKXRnXoz8MSyQ
# ----2---
# BFWhbX6dPxKXRnXoz8MSyQ
# ---here----
# 3XbjISn4xYarvoQZGxpjXg
# ----2---
# 3XbjISn4xYarvoQZGxpjXg
# ----2---
# 3XbjISn4xYarvoQZGxpjXg
# ---here----
# 17G67GkODedOfTM5QTGCwQ
# ----2---
# 17G67GkODedOfTM5QTGCwQ
# ----2---
# 17G67GkODedOfTM5QTGCwQ
# ---here----
# LGstBypD7XDMm-_Q5E2cuw
# ----2---
# LGstBypD7XDMm-_Q5E2cuw
# ----2---
# LGstBypD7XDMm-_Q5E2cuw
# ---here----
# r8KgB8eKHjKp-XldaXarEw
# ----2---
# r8KgB8eKHjKp-XldaXarEw
# ----2---
# r8KgB8eKHjKp-XldaXarEw
# ---here----
# YY0CIOpvLKTFt0wbAZ6HFw
# ----2---
# YY0CIOpvLKTFt0wbAZ6HFw
# ----2---
# YY0CIOpvLKTFt0wbAZ6HFw
# ---here----
# -cIVY3MjLEx72BE7mnPqnQ
# ----2---
# -cIVY3MjLEx72BE7mnPqnQ
# ----2---
# -cIVY3MjLEx72BE7mnPqnQ
# ---here----
# bjDWkmAAwkLiasMH2r0tfQ
# ----2---
# bjDWkmAAwkLiasMH2r0tfQ
# ----2---
# bjDWkmAAwkLiasMH2r0tfQ
# ---here----
# dOYLSWRRPtwQqy0ha5gi-w
# ----2---
# dOYLSWRRPtwQqy0ha5gi-w
# ----2---
# dOYLSWRRPtwQqy0ha5gi-w
# ---here----
# LLCi9b26fUo3R4OiyQMENw
# ----2---
# LLCi9b26fUo3R4OiyQMENw
# ----2---
# LLCi9b26fUo3R4OiyQMENw
# ---here----
# V8KXkj4sDhRlS5G6z8-79g
# ----2---
# V8KXkj4sDhRlS5G6z8-79g
# ----2---
# V8KXkj4sDhRlS5G6z8-79g
# ---here----
# GWtMn0uGwhmrdATwvXdOig
# ----2---
# GWtMn0uGwhmrdATwvXdOig
# ----2---
# GWtMn0uGwhmrdATwvXdOig
# ---here----
# MRLaK1Xf9RXC7vwBdt-t2Q
# ----2---
# MRLaK1Xf9RXC7vwBdt-t2Q
# ----2---
# MRLaK1Xf9RXC7vwBdt-t2Q
# ---here----
# eIL07_zmZa4-rh84EAtnwg
# ----2---
# eIL07_zmZa4-rh84EAtnwg
# ----2---
# eIL07_zmZa4-rh84EAtnwg
# ---here----
# yZQ07EM9MxZcKhz2hBRs9w
# ----2---
# yZQ07EM9MxZcKhz2hBRs9w
# ----2---
# yZQ07EM9MxZcKhz2hBRs9w
# ---here----
# jTyfj3e8PIkc4KTVh3sAqw
# ----2---
# jTyfj3e8PIkc4KTVh3sAqw
# ----2---
# jTyfj3e8PIkc4KTVh3sAqw
# ---here----
# VG49sqWkv_FU_x8g4wFL4w
# ----2---
# VG49sqWkv_FU_x8g4wFL4w
# ----2---
# VG49sqWkv_FU_x8g4wFL4w
# ---here----
# LGhB09xPiHd2M_D9y8N_rA
# ----2---
# LGhB09xPiHd2M_D9y8N_rA
# ----2---
# LGhB09xPiHd2M_D9y8N_rA
# ---here----
# Ewuh4AQEbjGMR0r8lVtrXw
# ----2---
# Ewuh4AQEbjGMR0r8lVtrXw
# ----2---
# Ewuh4AQEbjGMR0r8lVtrXw
# ---here----
# pzIlvsAitnIYcR244HmsgA
# ----2---
# pzIlvsAitnIYcR244HmsgA
# ----2---
# pzIlvsAitnIYcR244HmsgA
# ---here----
# NjWQGZckP21rq7Ok7zqyHA
# ----2---
# NjWQGZckP21rq7Ok7zqyHA
# ----2---
# NjWQGZckP21rq7Ok7zqyHA
# ---here----
# ZwkABJ3bpYwirX_WPUSpGQ
# ----2---
# ZwkABJ3bpYwirX_WPUSpGQ
# ----2---
# ZwkABJ3bpYwirX_WPUSpGQ
# ---here----
# XzwtHlfm09aXM6ujqQ53xA
# ----2---
# XzwtHlfm09aXM6ujqQ53xA
# ----2---
# XzwtHlfm09aXM6ujqQ53xA
# ---here----
# uxp3aLctj-EeEQcoN7QNmw
# ----2---
# uxp3aLctj-EeEQcoN7QNmw
# ----2---
# uxp3aLctj-EeEQcoN7QNmw
# ---here----
# bZw7XsPXY3lfdluCFNxLtQ
# ----2---
# bZw7XsPXY3lfdluCFNxLtQ
# ----2---
# bZw7XsPXY3lfdluCFNxLtQ
# ---here----
# 0fzkGamJANELt48Abp7fQg
# ----2---
# 0fzkGamJANELt48Abp7fQg
# ----2---
# 0fzkGamJANELt48Abp7fQg
# ---here----
# 7NYhG0KCJM2c_UkwoPDgVQ
# ----2---
# 7NYhG0KCJM2c_UkwoPDgVQ
# ----2---
# 7NYhG0KCJM2c_UkwoPDgVQ
# ---here----
# QzJxZ67PVrqy6Z_5gKfxyw
# ----2---
# QzJxZ67PVrqy6Z_5gKfxyw
# ----2---
# QzJxZ67PVrqy6Z_5gKfxyw
# ---here----
# f36479FQOOMrOVm0fH_Mog
# ----2---
# f36479FQOOMrOVm0fH_Mog
# ----2---
# f36479FQOOMrOVm0fH_Mog
# ---here----
# Z33F5KGv0eMLiz2_8zU5KA
# ----2---
# Z33F5KGv0eMLiz2_8zU5KA
# ----2---
# Z33F5KGv0eMLiz2_8zU5KA
# ---here----
# euzs-7Rv8BqYBYGYuh2O-Q
# ----2---
# euzs-7Rv8BqYBYGYuh2O-Q
# ----2---
# euzs-7Rv8BqYBYGYuh2O-Q
# ---here----
# SF5MW5Qg3cmiww7BV4NK1w
# ----2---
# SF5MW5Qg3cmiww7BV4NK1w
# ----2---
# SF5MW5Qg3cmiww7BV4NK1w
# 149

# %%
key_business=str(data_reviews_bus_id.iloc[0])
print(key_business)

# %%
dict_reviews=dict(data_reviews_all.iloc[0])
print(dict_reviews)
# Out:
# {'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-newport-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&hrid=Dg4yBmkmwQy_pFYJo_BDzw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=uWoa2sVIXxFlCSqOB-sCdg', 'text': 'I am not much of a "yelper" but I just had to because:  this place is amazing!! \n\nI came here for cocktails and appetizers with some girlfriends after...', 'rating': 5, 'time_created': '2021-05-12 06:00:58', 'user': {'id': '7yDT2Ut-ue87feaS6IXUVA', 'profile_url': 'https://www.yelp.com/user_details?userid=7yDT2Ut-ue87feaS6IXUVA', 'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/FPTFrIp-jzWKfXuqe78cag/o.jpg', 'name': 'Connie R.'}, 'id_reviews': 'Dg4yBmkmwQy_pFYJo_BDzw'}

# %%
dict_reviews=dict(data_reviews_all.iloc[0])
print(dict_review)
db.business.update_one(
   { 'id': key_business },
   { '$set': {"reviews_person_2":[dict_reviews]}}
    )
# Out:
# {'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-newport-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&hrid=Dg4yBmkmwQy_pFYJo_BDzw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=uWoa2sVIXxFlCSqOB-sCdg', 'text': 'I am not much of a "yelper" but I just had to because:  this place is amazing!! \n\nI came here for cocktails and appetizers with some girlfriends after...', 'rating': 5, 'time_created': '2021-05-12 06:00:58', 'user': {'id': '7yDT2Ut-ue87feaS6IXUVA', 'profile_url': 'https://www.yelp.com/user_details?userid=7yDT2Ut-ue87feaS6IXUVA', 'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/FPTFrIp-jzWKfXuqe78cag/o.jpg', 'name': 'Connie R.'}, 'id_reviews': 'Dg4yBmkmwQy_pFYJo_BDzw'}

# %%
dict_reviews=dict(data_reviews_all.iloc[1])
print(dict_reviews)
db.business.update_one(
   { 'id': key_business },
   { '$push': {"reviews_person_2":dict_reviews}}
    )
# Out:
# {'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-newport-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&hrid=rk9fCVX6anEgJfKFOcNiUw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=uWoa2sVIXxFlCSqOB-sCdg', 'text': 'Fantastic place for food and drinks. Our waiter Morgan was awesome and very nice. He suggested the brick chicken and fried apple pie! Both were very...', 'rating': 5, 'time_created': '2021-04-26 21:49:30', 'user': {'id': '6zkyg1QGnXeLGDsC0hRXiw', 'profile_url': 'https://www.yelp.com/user_details?userid=6zkyg1QGnXeLGDsC0hRXiw', 'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/yIE0T80LGjG-T-KvB-OJCQ/o.jpg', 'name': 'Dan R.'}, 'id_reviews': 'rk9fCVX6anEgJfKFOcNiUw'}

# %%
dict_reviews=dict(data_reviews_all.iloc[2])
print(dict_reviews)
db.business.update_one(
   { 'id': key_business },
   { '$push': {"reviews_person_2":dict_reviews}}
    )
# Out:
# {'url': 'https://www.yelp.com/biz/bosscat-kitchen-and-libations-newport-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&hrid=uL_XJIHn4qgSf3dsf12zZg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=uWoa2sVIXxFlCSqOB-sCdg', 'text': "This place is so good! Great food, great service, great atmosphere. What more could you want?! Definitely the best place we've had dinner in the circle.", 'rating': 5, 'time_created': '2021-05-19 18:17:01', 'user': {'id': 'RTNsjstRIa9xVY2-QFPeSw', 'profile_url': 'https://www.yelp.com/user_details?userid=RTNsjstRIa9xVY2-QFPeSw', 'image_url': None, 'name': 'Alex B.'}, 'id_reviews': 'uL_XJIHn4qgSf3dsf12zZg'}

# %%
#merge_df = pd.merge(data_businesses, data_review, on="id")
# Out:
#                          id                                          alias  \
# 0    ObCj8Y3KAdk4bgc8oSxNcA  bosscat-kitchen-and-libations-newport-beach-2
# 1    ObCj8Y3KAdk4bgc8oSxNcA  bosscat-kitchen-and-libations-newport-beach-2
# 2    ObCj8Y3KAdk4bgc8oSxNcA  bosscat-kitchen-and-libations-newport-beach-2
# 3    NVB2X8t5Rie8S5AnzOnWJg                            north-italia-irvine
# 4    NVB2X8t5Rie8S5AnzOnWJg                            north-italia-irvine
# ..                      ...                                            ...
# 145  NjWQGZckP21rq7Ok7zqyHA                        all-that-shabu-irvine-3
# 146  NjWQGZckP21rq7Ok7zqyHA                        all-that-shabu-irvine-3
# 147  WqHPB51wrjn1exIs-s9UXw                               the-stand-irvine
# 148  WqHPB51wrjn1exIs-s9UXw                               the-stand-irvine
# 149  WqHPB51wrjn1exIs-s9UXw                               the-stand-irvine
#
#                               name  \
# 0    Bosscat Kitchen and Libations
# 1    Bosscat Kitchen and Libations
# 2    Bosscat Kitchen and Libations
# 3                     North Italia
# 4                     North Italia
# ..                             ...
# 145                 All That Shabu
# 146                 All That Shabu
# 147                      The Stand
# 148                      The Stand
# 149                      The Stand
#
#                                              image_url is_closed  \
# 0    https://s3-media1.fl.yelpcdn.com/bphoto/vwGSRk...     False
# 1    https://s3-media1.fl.yelpcdn.com/bphoto/vwGSRk...     False
# 2    https://s3-media1.fl.yelpcdn.com/bphoto/vwGSRk...     False
# 3    https://s3-media1.fl.yelpcdn.com/bphoto/hWa52y...     False
# 4    https://s3-media1.fl.yelpcdn.com/bphoto/hWa52y...     False
# ..                                                 ...       ...
# 145  https://s3-media3.fl.yelpcdn.com/bphoto/TCAbfl...     False
# 146  https://s3-media3.fl.yelpcdn.com/bphoto/TCAbfl...     False
# 147  https://s3-media2.fl.yelpcdn.com/bphoto/tdr5Sb...     False
# 148  https://s3-media2.fl.yelpcdn.com/bphoto/tdr5Sb...     False
# 149  https://s3-media2.fl.yelpcdn.com/bphoto/tdr5Sb...     False
#
#                                                  url_x review_count  \
# 0    https://www.yelp.com/biz/bosscat-kitchen-and-l...         3880
# 1    https://www.yelp.com/biz/bosscat-kitchen-and-l...         3880
# 2    https://www.yelp.com/biz/bosscat-kitchen-and-l...         3880
# 3    https://www.yelp.com/biz/north-italia-irvine?a...         3658
# 4    https://www.yelp.com/biz/north-italia-irvine?a...         3658
# ..                                                 ...          ...
# 145  https://www.yelp.com/biz/all-that-shabu-irvine...          324
# 146  https://www.yelp.com/biz/all-that-shabu-irvine...          324
# 147  https://www.yelp.com/biz/the-stand-irvine?adju...          776
# 148  https://www.yelp.com/biz/the-stand-irvine?adju...          776
# 149  https://www.yelp.com/biz/the-stand-irvine?adju...          776
#
#                                             categories  rating_x  \
# 0    [{'alias': 'newamerican', 'title': 'American (...       4.5
# 1    [{'alias': 'newamerican', 'title': 'American (...       4.5
# 2    [{'alias': 'newamerican', 'title': 'American (...       4.5
# 3    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...       4.5
# 4    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...       4.5
# ..                                                 ...       ...
# 145  [{'alias': 'hotpot', 'title': 'Hot Pot'}, {'al...       4.5
# 146  [{'alias': 'hotpot', 'title': 'Hot Pot'}, {'al...       4.5
# 147  [{'alias': 'newamerican', 'title': 'American (...       4.5
# 148  [{'alias': 'newamerican', 'title': 'American (...       4.5
# 149  [{'alias': 'newamerican', 'title': 'American (...       4.5
#
#                                            coordinates  ...  \
# 0      {'latitude': 33.66985, 'longitude': -117.86526}  ...
# 1      {'latitude': 33.66985, 'longitude': -117.86526}  ...
# 2      {'latitude': 33.66985, 'longitude': -117.86526}  ...
# 3    {'latitude': 33.67173395544756, 'longitude': -...  ...
# 4    {'latitude': 33.67173395544756, 'longitude': -...  ...
# ..                                                 ...  ...
# 145  {'latitude': 33.697191, 'longitude': -117.799793}  ...
# 146  {'latitude': 33.697191, 'longitude': -117.799793}  ...
# 147  {'latitude': 33.6687986, 'longitude': -117.786...  ...
# 148  {'latitude': 33.6687986, 'longitude': -117.786...  ...
# 149  {'latitude': 33.6687986, 'longitude': -117.786...  ...
#
#                                               location         phone  \
# 0    {'address1': '4647 MacArthur Blvd', 'address2'...  +19493330917
# 1    {'address1': '4647 MacArthur Blvd', 'address2'...  +19493330917
# 2    {'address1': '4647 MacArthur Blvd', 'address2'...  +19493330917
# 3    {'address1': '2957 Michelson Dr', 'address2': ...  +19496297060
# 4    {'address1': '2957 Michelson Dr', 'address2': ...  +19496297060
# ..                                                 ...           ...
# 145  {'address1': '15315 Culver Dr', 'address2': 'S...  +19493335222
# 146  {'address1': '15315 Culver Dr', 'address2': 'S...  +19493335222
# 147  {'address1': '5633 Alton Pkwy', 'address2': 'B...  +19492629090
# 148  {'address1': '5633 Alton Pkwy', 'address2': 'B...  +19492629090
# 149  {'address1': '5633 Alton Pkwy', 'address2': 'B...  +19492629090
#
#       display_phone     distance  \
# 0    (949) 333-0917  3920.753236
# 1    (949) 333-0917  3920.753236
# 2    (949) 333-0917  3920.753236
# 3    (949) 629-7060  2059.048568
# 4    (949) 629-7060  2059.048568
# ..              ...          ...
# 145  (949) 333-5222  3750.053179
# 146  (949) 333-5222  3750.053179
# 147  (949) 262-9090  3408.187160
# 148  (949) 262-9090  3408.187160
# 149  (949) 262-9090  3408.187160
#
#                                                  url_y  \
# 0    https://www.yelp.com/biz/bosscat-kitchen-and-l...
# 1    https://www.yelp.com/biz/bosscat-kitchen-and-l...
# 2    https://www.yelp.com/biz/bosscat-kitchen-and-l...
# 3    https://www.yelp.com/biz/north-italia-irvine?a...
# 4    https://www.yelp.com/biz/north-italia-irvine?a...
# ..                                                 ...
# 145  https://www.yelp.com/biz/all-that-shabu-irvine...
# 146  https://www.yelp.com/biz/all-that-shabu-irvine...
# 147  https://www.yelp.com/biz/the-stand-irvine?adju...
# 148  https://www.yelp.com/biz/the-stand-irvine?adju...
# 149  https://www.yelp.com/biz/the-stand-irvine?adju...
#
#                                                   text rating_y  \
# 0    I am not much of a "yelper" but I just had to ...        5
# 1    Fantastic place for food and drinks. Our waite...        5
# 2    This place is so good! Great food, great servi...        5
# 3    Fresh, open and delicious!\nGreat big windows ...        5
# 4    My boyfriend and I went here this past sunday ...        5
# ..                                                 ...      ...
# 145  One of our favorite places to go. We began goi...        5
# 146  Only a table for 2 and so much food!\nMy frien...        5
# 147  Ordered the Falafel wrap, sat in the patio wit...        5
# 148  Juicy, high-quality meat and a hearty but fluf...        5
# 149  I am not into burgers but wow the Stand burger...        5
#
#             time_created                                               user  \
# 0    2021-05-12 06:00:58  {'id': '7yDT2Ut-ue87feaS6IXUVA', 'profile_url'...
# 1    2021-04-26 21:49:30  {'id': '6zkyg1QGnXeLGDsC0hRXiw', 'profile_url'...
# 2    2021-05-19 18:17:01  {'id': 'RTNsjstRIa9xVY2-QFPeSw', 'profile_url'...
# 3    2021-05-17 10:07:45  {'id': 'h83-F-dq81PWxla8ILg79w', 'profile_url'...
# 4    2021-05-07 19:45:35  {'id': '5gATwBk53RvEGvE5mbI0Tg', 'profile_url'...
# ..                   ...                                                ...
# 145  2021-06-02 17:36:33  {'id': 'mebdGvBfRMX26TFD9KAhHg', 'profile_url'...
# 146  2021-05-19 19:27:11  {'id': '-PPrhQ9OCano7pf2Q_6mDA', 'profile_url'...
# 147  2021-05-18 15:20:44  {'id': 'nfTZi0glD7LtXHseKfDRcg', 'profile_url'...
# 148  2020-07-06 09:25:27  {'id': 'gZHCbDOkHdHIk2d02FN3kw', 'profile_url'...
# 149  2020-12-01 18:09:38  {'id': '5gCJfx13t0B8WUrtssJLUA', 'profile_url'...
#
#                  id_reviews
# 0    Dg4yBmkmwQy_pFYJo_BDzw
# 1    rk9fCVX6anEgJfKFOcNiUw
# 2    uL_XJIHn4qgSf3dsf12zZg
# 3    VYCX2yQnkNFmibLTmR1Btw
# 4    IuKaRtXRPdISHKwrV6EQ7g
# ..                      ...
# 145  2XnyHsfasv-vhStCA5mXCw
# 146  cbfbz32wng-EbRM-41U6Ow
# 147  WjDup3Xik1lR5A6WBsdGlA
# 148  rwNYuPEXTXWXZIThSPHEGQ
# 149  0xtm3F7TaC9sYkpePfF5nw
#
# [150 rows x 22 columns]

# %%
merge_df.head()
# Out:
#                        id                                          alias  \
# 0  ObCj8Y3KAdk4bgc8oSxNcA  bosscat-kitchen-and-libations-newport-beach-2
# 1  ObCj8Y3KAdk4bgc8oSxNcA  bosscat-kitchen-and-libations-newport-beach-2
# 2  ObCj8Y3KAdk4bgc8oSxNcA  bosscat-kitchen-and-libations-newport-beach-2
# 3  NVB2X8t5Rie8S5AnzOnWJg                            north-italia-irvine
# 4  NVB2X8t5Rie8S5AnzOnWJg                            north-italia-irvine
#
#                             name  \
# 0  Bosscat Kitchen and Libations
# 1  Bosscat Kitchen and Libations
# 2  Bosscat Kitchen and Libations
# 3                   North Italia
# 4                   North Italia
#
#                                            image_url is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/vwGSRk...     False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/vwGSRk...     False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/vwGSRk...     False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/hWa52y...     False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/hWa52y...     False
#
#                                                url_x review_count  \
# 0  https://www.yelp.com/biz/bosscat-kitchen-and-l...         3880
# 1  https://www.yelp.com/biz/bosscat-kitchen-and-l...         3880
# 2  https://www.yelp.com/biz/bosscat-kitchen-and-l...         3880
# 3  https://www.yelp.com/biz/north-italia-irvine?a...         3658
# 4  https://www.yelp.com/biz/north-italia-irvine?a...         3658
#
#                                           categories  rating_x  \
# 0  [{'alias': 'newamerican', 'title': 'American (...       4.5
# 1  [{'alias': 'newamerican', 'title': 'American (...       4.5
# 2  [{'alias': 'newamerican', 'title': 'American (...       4.5
# 3  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...       4.5
# 4  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...       4.5
#
#                                          coordinates  ...  \
# 0    {'latitude': 33.66985, 'longitude': -117.86526}  ...
# 1    {'latitude': 33.66985, 'longitude': -117.86526}  ...
# 2    {'latitude': 33.66985, 'longitude': -117.86526}  ...
# 3  {'latitude': 33.67173395544756, 'longitude': -...  ...
# 4  {'latitude': 33.67173395544756, 'longitude': -...  ...
#
#                                             location         phone  \
# 0  {'address1': '4647 MacArthur Blvd', 'address2'...  +19493330917
# 1  {'address1': '4647 MacArthur Blvd', 'address2'...  +19493330917
# 2  {'address1': '4647 MacArthur Blvd', 'address2'...  +19493330917
# 3  {'address1': '2957 Michelson Dr', 'address2': ...  +19496297060
# 4  {'address1': '2957 Michelson Dr', 'address2': ...  +19496297060
#
#     display_phone     distance  \
# 0  (949) 333-0917  3920.753236
# 1  (949) 333-0917  3920.753236
# 2  (949) 333-0917  3920.753236
# 3  (949) 629-7060  2059.048568
# 4  (949) 629-7060  2059.048568
#
#                                                url_y  \
# 0  https://www.yelp.com/biz/bosscat-kitchen-and-l...
# 1  https://www.yelp.com/biz/bosscat-kitchen-and-l...
# 2  https://www.yelp.com/biz/bosscat-kitchen-and-l...
# 3  https://www.yelp.com/biz/north-italia-irvine?a...
# 4  https://www.yelp.com/biz/north-italia-irvine?a...
#
#                                                 text rating_y  \
# 0  I am not much of a "yelper" but I just had to ...        5
# 1  Fantastic place for food and drinks. Our waite...        5
# 2  This place is so good! Great food, great servi...        5
# 3  Fresh, open and delicious!\nGreat big windows ...        5
# 4  My boyfriend and I went here this past sunday ...        5
#
#           time_created                                               user  \
# 0  2021-05-12 06:00:58  {'id': '7yDT2Ut-ue87feaS6IXUVA', 'profile_url'...
# 1  2021-04-26 21:49:30  {'id': '6zkyg1QGnXeLGDsC0hRXiw', 'profile_url'...
# 2  2021-05-19 18:17:01  {'id': 'RTNsjstRIa9xVY2-QFPeSw', 'profile_url'...
# 3  2021-05-17 10:07:45  {'id': 'h83-F-dq81PWxla8ILg79w', 'profile_url'...
# 4  2021-05-07 19:45:35  {'id': '5gATwBk53RvEGvE5mbI0Tg', 'profile_url'...
#
#                id_reviews
# 0  Dg4yBmkmwQy_pFYJo_BDzw
# 1  rk9fCVX6anEgJfKFOcNiUw
# 2  uL_XJIHn4qgSf3dsf12zZg
# 3  VYCX2yQnkNFmibLTmR1Btw
# 4  IuKaRtXRPdISHKwrV6EQ7g
#
# [5 rows x 22 columns]
