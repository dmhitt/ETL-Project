# %%
#!pip install yelpapi
# Out:
# Collecting yelpapi
#   Downloading yelpapi-2.4.0-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from yelpapi) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->yelpapi) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->yelpapi) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->yelpapi) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->yelpapi) (4.0.0)
# Installing collected packages: yelpapi
# Successfully installed yelpapi-2.4.0

# %%
# Dependencies

import requests
import json
import pandas as pd


from config import api_key



from yelpapi import YelpAPI
yelp_api = YelpAPI(api_key)

# %%
#term = 'Mexican restaurant bar'
#location = 'Astoria, NY'
term = 'restaurant'
location = 'Huntington Beach, CA'
search_limit = 50
response = yelp_api.search_query(term = term,
                                 location = location,
                                 limit = search_limit)
type(response)
# Out:
# dict

# %%
response
# Out:
# {'businesses': [{'id': 'Z0aogEeyM9iXI6lz-Wo_Fg',
#    'alias': 'dukes-huntington-beach-huntington-beach-2',
#    'name': "Duke's Huntington Beach",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_KInBrpOYs3tLzCrQxO25A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dukes-huntington-beach-huntington-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1930,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.656629, 'longitude': -118.002219},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '317 Pacific Coast Hwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['317 Pacific Coast Hwy',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17143746446',
#    'display_phone': '(714) 374-6446',
#    'distance': 4004.4631585236934},
#   {'id': 'TqhuzJxO3A6jgf7JHGbBng',
#    'alias': 'mamas-on-39-huntington-beach',
#    'name': "Mama's On 39",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4PK-bwmX7DB7UliMIAlSRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamas-on-39-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 3454,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.65734, 'longitude': -117.98711},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '21022 Beach Blvd',
#     'address2': 'Ste 101',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['21022 Beach Blvd',
#      'Ste 101',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17143741166',
#    'display_phone': '(714) 374-1166',
#    'distance': 4453.139520349138},
#   {'id': 'ElvZ-9U8y_LtJvVQ3oUibg',
#    'alias': 'heirloom-a-modern-farmhouse-huntington-beach',
#    'name': 'Heirloom a Modern Farmhouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jam7veIK1Jz55ehOlq7KpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heirloom-a-modern-farmhouse-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 242,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.69601, 'longitude': -117.98834},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '18344 Beach Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['18344 Beach Blvd', 'Huntington Beach, CA 92648']},
#    'phone': '+17143756543',
#    'display_phone': '(714) 375-6543',
#    'distance': 2231.854979159048},
#   {'id': 'swJs0EEKdj3JF6XzccG0Nw',
#    'alias': 'offshore-9-rooftop-lounge-huntington-beach',
#    'name': 'Offshore 9 Rooftop Lounge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gsaRYX4ULJIRjqQnN7louw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/offshore-9-rooftop-lounge-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 109,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6523, 'longitude': -117.99353},
#    'transactions': ['delivery'],
#    'location': {'address1': '21100 Pacific Coast Hwy',
#     'address2': '',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['21100 Pacific Coast Hwy',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17148458000',
#    'display_phone': '(714) 845-8000',
#    'distance': 4696.751439501015},
#   {'id': 'HtS8m3k06JEXHbjdGLZAkQ',
#    'alias': 'watertable-huntington-beach',
#    'name': 'Watertable',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jbtPm-oEpbR0Q4bXGFwqYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/watertable-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 609,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.651300643275626,
#     'longitude': -117.99073387519343},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '21500 Pacific Coast Hwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['21500 Pacific Coast Hwy',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17148454776',
#    'display_phone': '(714) 845-4776',
#    'distance': 4897.321363431022},
#   {'id': 'Vl2p51a3uMnWkrpo1IaF2A',
#    'alias': 'the-black-trumpet-bistro-tapas-and-wine-bar-huntington-beach',
#    'name': 'The Black Trumpet Bistro Tapas & Wine Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FL74C_t8XRwqhXBxLK3GbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-black-trumpet-bistro-tapas-and-wine-bar-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 961,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.680305, 'longitude': -118.005161},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '7041 Yorktown Ave',
#     'address2': 'Ste 104',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7041 Yorktown Ave',
#      'Ste 104',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17148421122',
#    'display_phone': '(714) 842-1122',
#    'distance': 1408.0836910670398},
#   {'id': '-iQLD6KqtbfNrPGgXu0IYA',
#    'alias': 'ola-mexican-kitchen-huntington-beach',
#    'name': 'Ola Mexican Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fs55CqDCKtanaN1HVgT6sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ola-mexican-kitchen-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1866,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6544387, 'longitude': -117.9975675},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '21040 Pacific Coast Hwy',
#     'address2': 'Ste F200',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['21040 Pacific Coast Hwy',
#      'Ste F200',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17149697300',
#    'display_phone': '(714) 969-7300',
#    'distance': 4323.404913961623},
#   {'id': 'GbLbzM5kECZVECdqT6Acgw',
#    'alias': 'social-huntington-beach-huntington-beach',
#    'name': 'SOCIAL Huntington Beach',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZwQ-K8QhMdggSWQv-eMlgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/social-huntington-beach-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 342,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.65495, 'longitude': -117.98796},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '21214 Beach Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['21214 Beach Blvd', 'Huntington Beach, CA 92648']},
#    'phone': '+17143747715',
#    'display_phone': '(714) 374-7715',
#    'distance': 4641.764800261541},
#   {'id': 'JehNQp0QSzPIElvbdTj4nw',
#    'alias': 'pacific-hideaway-huntington-beach',
#    'name': 'Pacific Hideaway',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u8_e_I0TE1xebmVwrRwBPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pacific-hideaway-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 431,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.65816560863984,
#     'longitude': -118.00285109060252},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '500 Pacific Coast Hwy',
#     'address2': None,
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['500 Pacific Coast Hwy',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17149654448',
#    'display_phone': '(714) 965-4448',
#    'distance': 3821.928874064472},
#   {'id': '3qUgMKlIlpXQjhKyOcEqSA',
#    'alias': 'bluegold-huntington-beach-2',
#    'name': 'Bluegold',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D6gaNw4e_7hNn2yysx4U5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluegold-huntington-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 935,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6551945, 'longitude': -117.9988738},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '21016 Pacific Coast Hwy',
#     'address2': 'Ste D200',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['21016 Pacific Coast Hwy',
#      'Ste D200',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17143740038',
#    'display_phone': '(714) 374-0038',
#    'distance': 4239.182567683338},
#   {'id': 'f6__ZkORVNPvAsrXJcYjXw',
#    'alias': 'blk-earth-sea-spirits-huntington-beach',
#    'name': 'BLK Earth Sea Spirits',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4TH43Noc-FD46fQuWhLoxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blk-earth-sea-spirits-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1126,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.657525, 'longitude': -118.000788},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '300 Pacific Coast Hwy',
#     'address2': 'Ste 202',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92646',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['300 Pacific Coast Hwy',
#      'Ste 202',
#      'Huntington Beach, CA 92646']},
#    'phone': '+17149600996',
#    'display_phone': '(714) 960-0996',
#    'distance': 3936.1502320735485},
#   {'id': 'EdSoL8W1lTgiAPz3QmGbaQ',
#    'alias': 'beales-texas-bbq-huntington-beach-2',
#    'name': "Beale's Texas BBQ",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Wdj_nNb7u5UQ81CfZv5Gyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beales-texas-bbq-huntington-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1039,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.724337, 'longitude': -118.076162673533},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '16400 Pacific Coast Hwy',
#     'address2': 'Ste 117',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92649',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['16400 Pacific Coast Hwy',
#      'Ste 117',
#      'Huntington Beach, CA 92649']},
#    'phone': '+15625883070',
#    'display_phone': '(562) 588-3070',
#    'distance': 6977.861717394481},
#   {'id': 'bz_HG0-t2jkWSw-dKUZCbA',
#    'alias': 'henrys-ocean-view-dining-huntington-beach',
#    'name': "Henry's Ocean View Dining",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JC_cOyaAts4kU6aJEaC-qQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/henrys-ocean-view-dining-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 60,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.65308494655343, 'longitude': -117.9943667},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '21100 Pacific Coast Hwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['21100 Pacific Coast Hwy',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17148458450',
#    'display_phone': '(714) 845-8450',
#    'distance': 4587.713351765347},
#   {'id': 'sCyuXfwAMZl0kjz81-NoAw',
#    'alias': 'capones-italian-cucina-huntington-beach-2',
#    'name': 'Capones Italian Cucina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yzoUKnJ9Ax9MIW5rR0ZKSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/capones-italian-cucina-huntington-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 767,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.6767621, 'longitude': -117.9883751},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '19688 Beach Blvd',
#     'address2': 'Ste 10',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['19688 Beach Blvd',
#      'Ste 10',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17145932888',
#    'display_phone': '(714) 593-2888',
#    'distance': 2854.055511418586},
#   {'id': 'O10xKtr061MnS6tsoUyQBw',
#    'alias': 'point-11-grill-huntington-beach',
#    'name': 'Point 11 Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gYN4Vs2kQCTcOOoQdILGcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/point-11-grill-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 92,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.663790333, 'longitude': -118.00526966},
#    'transactions': ['delivery'],
#    'location': {'address1': '327 11th St',
#     'address2': 'Ste 101',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['327 11th St',
#      'Ste 101',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17149160027',
#    'display_phone': '(714) 916-0027',
#    'distance': 3159.2637450525517},
#   {'id': 'WxUI7srzbXKgtWNlBCoiJw',
#    'alias': 'simmzys-huntington-beach-huntington-beach-3',
#    'name': "Simmzy's - Huntington Beach",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ec-fjEIyPbJAJXm1F7OwWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simmzys-huntington-beach-huntington-beach-3?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 787,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6547675, 'longitude': -117.9981428},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '21028 Pacific Coast Hwy',
#     'address2': 'Ste E-100',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92647',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['21028 Pacific Coast Hwy',
#      'Ste E-100',
#      'Huntington Beach, CA 92647']},
#    'phone': '+17148311240',
#    'display_phone': '(714) 831-1240',
#    'distance': 4292.867488984929},
#   {'id': 'mtn4uojv4aXT5-WfTKnxow',
#    'alias': 'the-vox-kitchen-fountain-valley-2',
#    'name': 'The Vox Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DHupe_OX0KP9Bja6SdKYHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-vox-kitchen-fountain-valley-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 4311,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.72744, 'longitude': -117.95568},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '16161 Brookhurst St',
#     'address2': None,
#     'address3': '',
#     'city': 'Fountain Valley',
#     'zip_code': '92708',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['16161 Brookhurst St', 'Fountain Valley, CA 92708']},
#    'phone': '+16572316493',
#    'display_phone': '(657) 231-6493',
#    'distance': 6504.805500609345},
#   {'id': 'Bb5v4AD4gAR5qcMKIOZV0g',
#    'alias': 'hq-gastropub-huntington-beach-huntington-beach',
#    'name': 'HQ Gastropub - Huntington Beach',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vmvq_HmAqKYcVt82lcrBZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hq-gastropub-huntington-beach-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 587,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6580881372787,
#     'longitude': -118.002746908598},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '155 5th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['155 5th St', 'Huntington Beach, CA 92648']},
#    'phone': '+17143692155',
#    'display_phone': '(714) 369-2155',
#    'distance': 3832.416944500527},
#   {'id': 'h7GxqIoQjldZEsB0TwwrTg',
#    'alias': 'zankou-chicken-huntington-beach-2',
#    'name': 'Zankou Chicken',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/toCIoRRWvZP9yg7YPtLDaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zankou-chicken-huntington-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 148,
#    'categories': [{'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.69316, 'longitude': -117.98926},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '18541 Beach Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['18541 Beach Blvd', 'Huntington Beach, CA 92648']},
#    'phone': '+17145158960',
#    'display_phone': '(714) 515-8960',
#    'distance': 2085.279537403139},
#   {'id': 'wfbK2yJ9hh8v4NlDCUb0eg',
#    'alias': 'puesto-huntington-beach-huntington-beach',
#    'name': 'Puesto- Huntington Beach',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RdsY3uNUMa5s4WydG5wRjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/puesto-huntington-beach-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 128,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.732558, 'longitude': -117.992236},
#    'transactions': [],
#    'location': {'address1': '7821 Edinger Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92647',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7821 Edinger Ave', 'Huntington Beach, CA 92647']},
#    'phone': '+17143160151',
#    'display_phone': '(714) 316-0151',
#    'distance': 4890.998865158099},
#   {'id': 'She8LwmCUNuLiAvuISK1Xg',
#    'alias': 'sandys-beach-shack-huntington-beach',
#    'name': "Sandy's Beach Shack",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AQB_Fk-k5nAXhYscGJXwqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sandys-beach-shack-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 844,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.65596, 'longitude': -118.00135},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '315 Pacific Coast Hwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['315 Pacific Coast Hwy',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17143747273',
#    'display_phone': '(714) 374-7273',
#    'distance': 4016.0409735108947},
#   {'id': 'TvGpCBd4QpaZSrWRuBqPVQ',
#    'alias': 'slapfish-huntington-beach',
#    'name': 'Slapfish',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9sJ87HHL3556P_H99SnhiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slapfish-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 2476,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6767007, 'longitude': -117.9883751},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '19696 Beach Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['19696 Beach Blvd', 'Huntington Beach, CA 92648']},
#    'phone': '+17149633900',
#    'display_phone': '(714) 963-3900',
#    'distance': 2862.203326696508},
#   {'id': 'fktFWbil7gxfdjTp1FtUEw',
#    'alias': '25-degrees-huntington-beach',
#    'name': '25 Degrees',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/49CZYT_t6z2nERoEgqjgRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/25-degrees-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1503,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.658492, 'longitude': -118.001519},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '412 Walnut Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['412 Walnut Ave', 'Huntington Beach, CA 92648']},
#    'phone': '+17149602525',
#    'display_phone': '(714) 960-2525',
#    'distance': 3815.052798295766},
#   {'id': '-dgMUMCHx7LsLEJNwYHl_w',
#    'alias': 'bread-crumb-ohana-cafe-huntington-beach',
#    'name': 'Bread Crumb Ohana Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qAI9jwa-mHQPqTDt6ltw2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-crumb-ohana-cafe-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1269,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6853215981096,
#     'longitude': -117.990534177944},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '19079 Beach Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['19079 Beach Blvd', 'Huntington Beach, CA 92648']},
#    'phone': '+17149605051',
#    'display_phone': '(714) 960-5051',
#    'distance': 2084.5272038774056},
#   {'id': 'MFmYTmAsQl6aAfIXuJKKjg',
#    'alias': 'wet-dog-tavern-huntington-beach',
#    'name': 'Wet Dog Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ITcjpUvM2tWcWPOI8iemtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wet-dog-tavern-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 104,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.658935, 'longitude': -118.000613},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '221 Main St',
#     'address2': 'Ste B',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['221 Main St', 'Ste B', 'Huntington Beach, CA 92648']},
#    'phone': '+17145362234',
#    'display_phone': '(714) 536-2234',
#    'distance': 3790.7045296251263},
#   {'id': 'o_5L4Hbe9E_8u3hI6FB-EA',
#    'alias': 'hanki-everyday-korean-huntington-beach-4',
#    'name': 'Hanki Everyday Korean',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xiLWAjTV-EQL1B0trx0cow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hanki-everyday-korean-huntington-beach-4?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 223,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.7305421, 'longitude': -117.99952},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7451 Edinger Ave',
#     'address2': 'Unit 102',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92647',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7451 Edinger Ave',
#      'Unit 102',
#      'Huntington Beach, CA 92647']},
#    'phone': '+17146224073',
#    'display_phone': '(714) 622-4073',
#    'distance': 4459.519109709829},
#   {'id': 'Yx4xqTaak-fP0vKfIziDVw',
#    'alias': 'the-boathouse-on-the-bay-long-beach',
#    'name': 'The Boathouse on the Bay',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KReXydFxeZGohp4a0CkGuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-boathouse-on-the-bay-long-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1567,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.7475314086796,
#     'longitude': -118.113893451428},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '190 N Marina Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Beach',
#     'zip_code': '90803',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['190 N Marina Dr', 'Long Beach, CA 90803']},
#    'phone': '+15624931100',
#    'display_phone': '(562) 493-1100',
#    'distance': 11423.687919522203},
#   {'id': 'MT5fR6lbW1_T965F2m_0iA',
#    'alias': 'jay-birds-chicken-huntington-beach',
#    'name': "Jay Bird's Chicken",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ErcH-ILLErMEJZDQzKtN4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jay-birds-chicken-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 200,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.65868, 'longitude': -117.99952},
#    'transactions': [],
#    'location': {'address1': '303 3rd St',
#     'address2': 'Ste 101',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['303 3rd St',
#      'Ste 101',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17145943233',
#    'display_phone': '(714) 594-3233',
#    'distance': 3842.1342543048777},
#   {'id': '6IDXE3rFWcsiuy0eYsEZzA',
#    'alias': 'sushi-on-fire-huntington-beach',
#    'name': 'Sushi On Fire',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/59HuWRarDPCajkqL_Slvow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-on-fire-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 2099,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6594426, 'longitude': -117.9998605},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '301 Main St',
#     'address2': 'Ste 103',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['301 Main St',
#      'Ste 103',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17143748885',
#    'display_phone': '(714) 374-8885',
#    'distance': 3754.6092780018867},
#   {'id': '1YgvpICKqq5wOHv0A5kJ8g',
#    'alias': 'the-american-dream-huntington-beach',
#    'name': 'The American Dream',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z4fAd98MGU68EoF3uOdMbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-american-dream-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 700,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6541672717691,
#     'longitude': -117.996923411114},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '21058 Pacific Coast Hwy',
#     'address2': 'Ste M130',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['21058 Pacific Coast Hwy',
#      'Ste M130',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17143741330',
#    'display_phone': '(714) 374-1330',
#    'distance': 4395.892424722057},
#   {'id': '5i6DJqQo8IPZeJc7fGXR0Q',
#    'alias': 'habachihana-grill-huntington-beach-2',
#    'name': 'Habachihana Grill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GOBLIXXKyP2FBL3wFEP8HQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/habachihana-grill-huntington-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 68,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.712248, 'longitude': -117.989534},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '17221 Beach Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92647',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['17221 Beach Blvd', 'Huntington Beach, CA 92647']},
#    'phone': '+17145890214',
#    'display_phone': '(714) 589-0214',
#    'distance': 3066.2249320393616},
#   {'id': 'H_1KkfGbwvlX2b-81ZJpoQ',
#    'alias': 'habana-costa-mesa-3',
#    'name': 'Habana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FbOA0SzkENESSE_7Jd2cVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/habana-costa-mesa-3?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 4342,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.677473708454,
#     'longitude': -117.885754645894},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2930 Bristol St',
#     'address2': 'Ste A110',
#     'address3': '',
#     'city': 'Costa Mesa',
#     'zip_code': '92626',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2930 Bristol St',
#      'Ste A110',
#      'Costa Mesa, CA 92626']},
#    'phone': '+17145560176',
#    'display_phone': '(714) 556-0176',
#    'distance': 11760.934717165508},
#   {'id': 'yogzL6V3_LohxFFCjyJtwg',
#    'alias': 'triple-crown-tavern-huntington-beach',
#    'name': 'Triple Crown Tavern',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uMHEvYdWrx9uGZ2m9V0byQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/triple-crown-tavern-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 138,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.6719751, 'longitude': -117.9905885},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '714 Adams Ave',
#     'address2': 'Ste 101',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['714 Adams Ave',
#      'Ste 101',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17144659041',
#    'display_phone': '(714) 465-9041',
#    'distance': 2986.28360055496},
#   {'id': '4rWmTgxh34kL738irQWJaQ',
#    'alias': 'matiki-island-bbq-huntington-beach-2',
#    'name': 'Matiki Island BBQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qoeWEKouhDVgmv14iRAvUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/matiki-island-bbq-huntington-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 116,
#    'categories': [{'alias': 'polynesian', 'title': 'Polynesian'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.721553, 'longitude': -118.0423026},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '16561 Bolsa Chica St',
#     'address2': 'Ste 108',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92649',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['16561 Bolsa Chica St',
#      'Ste 108',
#      'Huntington Beach, CA 92649']},
#    'phone': '+17146988225',
#    'display_phone': '(714) 698-8225',
#    'distance': 4359.172608790339},
#   {'id': '781F5q3N17g-gzJWtgJxUg',
#    'alias': 'the-lighthouse-cafe-newport-beach-2',
#    'name': 'The Lighthouse Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HnhXCqxu9rPBvoTN-o0a0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lighthouse-cafe-newport-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1802,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.608054, 'longitude': -117.922632},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1600 W Balboa Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Newport Beach',
#     'zip_code': '92663',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1600 W Balboa Blvd', 'Newport Beach, CA 92663']},
#    'phone': '+19499331001',
#    'display_phone': '(949) 933-1001',
#    'distance': 12432.343201992073},
#   {'id': 'ZkU0fHAi5fDHyBr-8ZqP5g',
#    'alias': 'the-recess-room-fountain-valley',
#    'name': 'The Recess Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wBXtlx47-p5M3IuLHjTfJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-recess-room-fountain-valley?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1621,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.695703, 'longitude': -117.953787},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '18380 Brookhurst St',
#     'address2': '',
#     'address3': None,
#     'city': 'Fountain Valley',
#     'zip_code': '92708',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['18380 Brookhurst St', 'Fountain Valley, CA 92708']},
#    'phone': '+17143770398',
#    'display_phone': '(714) 377-0398',
#    'distance': 5376.29208021035},
#   {'id': '8QrvpmpT9JPoUYOIBNLJHA',
#    'alias': 'board-and-brew-huntington-beach-huntington-beach',
#    'name': 'Board & Brew - Huntington Beach',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B96uNxLgDfhBNeGbuu9l4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/board-and-brew-huntington-beach-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 321,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.676057, 'longitude': -117.988082},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '19720 Beach Blvd',
#     'address2': 'Ste 103',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['19720 Beach Blvd',
#      'Ste 103',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17143777100',
#    'display_phone': '(714) 377-7100',
#    'distance': 2793.7720844377654},
#   {'id': 'ky8YQASTxK71JqnDOmX24w',
#    'alias': 'captain-jacks-sunset-beach',
#    'name': "Captain Jack's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/l1lRnL9yg2exy-HNVImB1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/captain-jacks-sunset-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1481,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.71826, 'longitude': -118.070355},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '16812 Pacific Coast Hwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunset Beach',
#     'zip_code': '90742',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['16812 Pacific Coast Hwy', 'Sunset Beach, CA 90742']},
#    'phone': '+15625922514',
#    'display_phone': '(562) 592-2514',
#    'distance': 6173.350938048401},
#   {'id': '-E3RrsOr4QUIr_q-sS1D4g',
#    'alias': 'subculture-extraordinary-sandwiches-huntington-beach',
#    'name': 'Subculture Extraordinary Sandwiches',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0KJmE3tC7EyuAhE_4l4NyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/subculture-extraordinary-sandwiches-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 2011,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.71513, 'longitude': -117.9905},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7862 Warner Ave',
#     'address2': 'Ste E',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92647',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7862 Warner Ave',
#      'Ste E',
#      'Huntington Beach, CA 92647']},
#    'phone': '+17148471113',
#    'display_phone': '(714) 847-1113',
#    'distance': 3255.3385455308917},
#   {'id': 'PUpjlBdeCJNd2Nq8Ocvq3w',
#    'alias': 'hartman-elise-huntington-beach',
#    'name': 'Hartman Elise',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4fD3vRppafjgdLVV_i7x0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hartman-elise-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1,
#    'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.6905, 'longitude': -118.00941},
#    'transactions': [],
#    'location': {'address1': '18722 Jockey Cir',
#     'address2': None,
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['18722 Jockey Cir', 'Huntington Beach, CA 92648']},
#    'phone': '+15625972378',
#    'display_phone': '(562) 597-2378',
#    'distance': 248.15132789941813},
#   {'id': 'bftu1iGPdnjuzlyGV-kKfQ',
#    'alias': 'beach-city-provisions-huntington-beach',
#    'name': 'Beach City Provisions',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Tlgk4b-Y-h_j0qAOPZYqcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beach-city-provisions-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 19,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.69585, 'longitude': -118.04835},
#    'transactions': [],
#    'location': {'address1': '17851 Pacific Coast Hwy',
#     'address2': '',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['17851 Pacific Coast Hwy',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17146984188',
#    'display_phone': '(714) 698-4188',
#    'distance': 3292.016202632629},
#   {'id': 'qAxrJXBEkAlGzDdAJoVZ7g',
#    'alias': 'silverlake-ramen-huntington-beach-huntington-beach',
#    'name': 'Silverlake Ramen - Huntington Beach',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OqqEHGbE60Hk8BD5pecXKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silverlake-ramen-huntington-beach-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 686,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.732551, 'longitude': -117.992236},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '7821 Edinger Ave',
#     'address2': 'Ste 118',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '28203',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['7821 Edinger Ave',
#      'Ste 118',
#      'Huntington Beach, CA 28203']},
#    'phone': '+17149021055',
#    'display_phone': '(714) 902-1055',
#    'distance': 4890.998865158099},
#   {'id': '7Pr41OoEm-T97boJ3dI3nA',
#    'alias': 'good-vibes-from-soul-to-bowl-huntington-beach-3',
#    'name': 'Good Vibes From Soul to Bowl',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vcOS6vFHPI22NH16B64ZyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/good-vibes-from-soul-to-bowl-huntington-beach-3?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 25,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.6613951, 'longitude': -117.99972612883553},
#    'transactions': [],
#    'location': {'address1': '501 Main St',
#     'address2': 'Ste E',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['501 Main St', 'Ste E', 'Huntington Beach, CA 92648']},
#    'phone': '+17145360210',
#    'display_phone': '(714) 536-0210',
#    'distance': 3551.3782795152692},
#   {'id': 'SO1Bn9OYnBx3mQiUnDf3RA',
#    'alias': 'sugar-shack-café-huntington-beach-2',
#    'name': 'Sugar Shack Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hLKTBVb1WQiujNce8Y9RXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sugar-shack-caf%C3%A9-huntington-beach-2?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 1299,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6585809201002,
#     'longitude': -118.00084593808683},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '213 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['213 Main St', 'Huntington Beach, CA 92648']},
#    'phone': '+17145360355',
#    'display_phone': '(714) 536-0355',
#    'distance': 3821.3731578505162},
#   {'id': 'LsZx58-wAIXWlXPK_6ixuw',
#    'alias': 'da-hawaiian-kitchen-huntington-beach',
#    'name': 'Da Hawaiian Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zOUfKjn4GdEhu9PIuTqe1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-hawaiian-kitchen-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 967,
#    'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.6720001, 'longitude': -117.9565333},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9842 Adams Ave',
#     'address2': 'Ste 104',
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92646',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['9842 Adams Ave',
#      'Ste 104',
#      'Huntington Beach, CA 92646']},
#    'phone': '+17149688900',
#    'display_phone': '(714) 968-8900',
#    'distance': 5556.637325891036},
#   {'id': 'Jl_LyKAb_3Iyo32ypIlFNw',
#    'alias': 'burnt-crumbs-huntington-beach',
#    'name': 'Burnt Crumbs',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EzqUb_b2AFLEqk0WmDY9dQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burnt-crumbs-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 610,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.654605, 'longitude': -117.9965},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '21058 Pacific Coast Hwy',
#     'address2': 'Ste M100',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['21058 Pacific Coast Hwy',
#      'Ste M100',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17143740777',
#    'display_phone': '(714) 374-0777',
#    'distance': 4362.139365475475},
#   {'id': 'g_7S2kgE7NCqPGtvcJcBrg',
#    'alias': 'the-beachcomber-newport-coast-4',
#    'name': 'The Beachcomber',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Fr-Qt8yxDU3euWaGjGSkFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-beachcomber-newport-coast-4?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 2506,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.57432392026669,
#     'longitude': -117.84029023717086},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '15 Crystal Cv',
#     'address2': '',
#     'address3': '',
#     'city': 'Newport Coast',
#     'zip_code': '92657',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['15 Crystal Cv', 'Newport Coast, CA 92657']},
#    'phone': '+19493766900',
#    'display_phone': '(949) 376-6900',
#    'distance': 20549.942561244585},
#   {'id': 'rPtjhMAidLbgjzYAkc_0zw',
#    'alias': 'surf-city-ale-house-huntington-beach',
#    'name': 'Surf City Ale House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OpUo0gUHWZJ-KiMerCdCQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/surf-city-ale-house-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 194,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.6591751190573,
#     'longitude': -118.000239413502},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '301 Main St',
#     'address2': 'Ste 101',
#     'address3': None,
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['301 Main St',
#      'Ste 101',
#      'Huntington Beach, CA 92648']},
#    'phone': '+17143692581',
#    'display_phone': '(714) 369-2581',
#    'distance': 3773.0591574565765},
#   {'id': 'NVB2X8t5Rie8S5AnzOnWJg',
#    'alias': 'north-italia-irvine',
#    'name': 'North Italia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hWa52yLwUAtiZh-xPYXGxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/north-italia-irvine?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 3648,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.67173395544756,
#     'longitude': -117.84513856994657},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2957 Michelson Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Irvine',
#     'zip_code': '92612',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2957 Michelson Dr', 'Irvine, CA 92612']},
#    'phone': '+19496297060',
#    'display_phone': '(949) 629-7060',
#    'distance': 15571.715619385715},
#   {'id': '_eQYxkulx7KfPxxFa-RsZQ',
#    'alias': 'northside-market-and-deli-huntington-beach',
#    'name': 'Northside Market and Deli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/307ewGr3ESNnCb91tiw9gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/northside-market-and-deli-huntington-beach?adjust_creative=uWoa2sVIXxFlCSqOB-sCdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uWoa2sVIXxFlCSqOB-sCdg',
#    'review_count': 75,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.66678, 'longitude': -118.01087},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '301 17th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Huntington Beach',
#     'zip_code': '92648',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['301 17th St', 'Huntington Beach, CA 92648']},
#    'phone': '+17149606600',
#    'display_phone': '(714) 960-6600',
#    'distance': 2778.4513184513316}],
#  'total': 7100,
#  'region': {'center': {'longitude': -118.01170349121094,
#    'latitude': 33.69173830884756}}}

# %%
response.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
response['businesses'][0].keys()
# Out:
# dict_keys(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'price', 'location', 'phone', 'display_phone', 'distance'])

# %%
response['total']
# Out:
# 7100

# %%
cols = list(response['businesses'][0].keys())
data = pd.DataFrame(columns=cols)
for biz in response['businesses']:
    data = data.append(biz, ignore_index=True)
# Out:
#                        id                                         alias  \
# 0  Z0aogEeyM9iXI6lz-Wo_Fg     dukes-huntington-beach-huntington-beach-2
# 1  TqhuzJxO3A6jgf7JHGbBng                  mamas-on-39-huntington-beach
# 2  ElvZ-9U8y_LtJvVQ3oUibg  heirloom-a-modern-farmhouse-huntington-beach
# 3  swJs0EEKdj3JF6XzccG0Nw    offshore-9-rooftop-lounge-huntington-beach
# 4  HtS8m3k06JEXHbjdGLZAkQ                   watertable-huntington-beach
#
#                           name  \
# 0      Duke's Huntington Beach
# 1                 Mama's On 39
# 2  Heirloom a Modern Farmhouse
# 3    Offshore 9 Rooftop Lounge
# 4                   Watertable
#
#                                            image_url is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/_KInBr...     False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/4PK-bw...     False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/jam7ve...     False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/gsaRYX...     False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/jbtPm-...     False
#
#                                                  url review_count  \
# 0  https://www.yelp.com/biz/dukes-huntington-beac...         1930
# 1  https://www.yelp.com/biz/mamas-on-39-huntingto...         3454
# 2  https://www.yelp.com/biz/heirloom-a-modern-far...          242
# 3  https://www.yelp.com/biz/offshore-9-rooftop-lo...          109
# 4  https://www.yelp.com/biz/watertable-huntington...          609
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 2  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 3  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.0
# 4  [{'alias': 'newamerican', 'title': 'American (...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 33.656629, 'longitude': -118.002219}  [delivery, pickup]
# 1    {'latitude': 33.65734, 'longitude': -117.98711}  [delivery, pickup]
# 2    {'latitude': 33.69601, 'longitude': -117.98834}          [delivery]
# 3     {'latitude': 33.6523, 'longitude': -117.99353}          [delivery]
# 4  {'latitude': 33.651300643275626, 'longitude': ...          [delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '317 Pacific Coast Hwy', 'address...  +17143746446
# 1    $$  {'address1': '21022 Beach Blvd', 'address2': '...  +17143741166
# 2    $$  {'address1': '18344 Beach Blvd', 'address2': N...  +17143756543
# 3   NaN  {'address1': '21100 Pacific Coast Hwy', 'addre...  +17148458000
# 4   $$$  {'address1': '21500 Pacific Coast Hwy', 'addre...  +17148454776
#
#     display_phone     distance
# 0  (714) 374-6446  4004.463159
# 1  (714) 374-1166  4453.139520
# 2  (714) 375-6543  2231.854979
# 3  (714) 845-8000  4696.751440
# 4  (714) 845-4776  4897.321363

# %%
data.head(49)
# Out:
#                         id                                              alias  \
# 0   Z0aogEeyM9iXI6lz-Wo_Fg          dukes-huntington-beach-huntington-beach-2
# 1   TqhuzJxO3A6jgf7JHGbBng                       mamas-on-39-huntington-beach
# 2   ElvZ-9U8y_LtJvVQ3oUibg       heirloom-a-modern-farmhouse-huntington-beach
# 3   swJs0EEKdj3JF6XzccG0Nw         offshore-9-rooftop-lounge-huntington-beach
# 4   HtS8m3k06JEXHbjdGLZAkQ                        watertable-huntington-beach
# 5   Vl2p51a3uMnWkrpo1IaF2A  the-black-trumpet-bistro-tapas-and-wine-bar-hu...
# 6   -iQLD6KqtbfNrPGgXu0IYA               ola-mexican-kitchen-huntington-beach
# 7   GbLbzM5kECZVECdqT6Acgw           social-huntington-beach-huntington-beach
# 8   JehNQp0QSzPIElvbdTj4nw                  pacific-hideaway-huntington-beach
# 9   3qUgMKlIlpXQjhKyOcEqSA                        bluegold-huntington-beach-2
# 10  f6__ZkORVNPvAsrXJcYjXw             blk-earth-sea-spirits-huntington-beach
# 11  EdSoL8W1lTgiAPz3QmGbaQ                beales-texas-bbq-huntington-beach-2
# 12  bz_HG0-t2jkWSw-dKUZCbA          henrys-ocean-view-dining-huntington-beach
# 13  sCyuXfwAMZl0kjz81-NoAw          capones-italian-cucina-huntington-beach-2
# 14  O10xKtr061MnS6tsoUyQBw                    point-11-grill-huntington-beach
# 15  WxUI7srzbXKgtWNlBCoiJw        simmzys-huntington-beach-huntington-beach-3
# 16  mtn4uojv4aXT5-WfTKnxow                  the-vox-kitchen-fountain-valley-2
# 17  Bb5v4AD4gAR5qcMKIOZV0g     hq-gastropub-huntington-beach-huntington-beach
# 18  h7GxqIoQjldZEsB0TwwrTg                  zankou-chicken-huntington-beach-2
# 19  wfbK2yJ9hh8v4NlDCUb0eg           puesto-huntington-beach-huntington-beach
# 20  She8LwmCUNuLiAvuISK1Xg                sandys-beach-shack-huntington-beach
# 21  TvGpCBd4QpaZSrWRuBqPVQ                          slapfish-huntington-beach
# 22  fktFWbil7gxfdjTp1FtUEw                        25-degrees-huntington-beach
# 23  -dgMUMCHx7LsLEJNwYHl_w            bread-crumb-ohana-cafe-huntington-beach
# 24  MFmYTmAsQl6aAfIXuJKKjg                    wet-dog-tavern-huntington-beach
# 25  o_5L4Hbe9E_8u3hI6FB-EA           hanki-everyday-korean-huntington-beach-4
# 26  Yx4xqTaak-fP0vKfIziDVw                the-boathouse-on-the-bay-long-beach
# 27  MT5fR6lbW1_T965F2m_0iA                 jay-birds-chicken-huntington-beach
# 28  6IDXE3rFWcsiuy0eYsEZzA                     sushi-on-fire-huntington-beach
# 29  1YgvpICKqq5wOHv0A5kJ8g                the-american-dream-huntington-beach
# 30  5i6DJqQo8IPZeJc7fGXR0Q               habachihana-grill-huntington-beach-2
# 31  H_1KkfGbwvlX2b-81ZJpoQ                                habana-costa-mesa-3
# 32  yogzL6V3_LohxFFCjyJtwg               triple-crown-tavern-huntington-beach
# 33  4rWmTgxh34kL738irQWJaQ               matiki-island-bbq-huntington-beach-2
# 34  781F5q3N17g-gzJWtgJxUg                the-lighthouse-cafe-newport-beach-2
# 35  ZkU0fHAi5fDHyBr-8ZqP5g                    the-recess-room-fountain-valley
# 36  8QrvpmpT9JPoUYOIBNLJHA   board-and-brew-huntington-beach-huntington-beach
# 37  ky8YQASTxK71JqnDOmX24w                         captain-jacks-sunset-beach
# 38  -E3RrsOr4QUIr_q-sS1D4g  subculture-extraordinary-sandwiches-huntington...
# 39  PUpjlBdeCJNd2Nq8Ocvq3w                     hartman-elise-huntington-beach
# 40  bftu1iGPdnjuzlyGV-kKfQ             beach-city-provisions-huntington-beach
# 41  qAxrJXBEkAlGzDdAJoVZ7g  silverlake-ramen-huntington-beach-huntington-b...
# 42  7Pr41OoEm-T97boJ3dI3nA    good-vibes-from-soul-to-bowl-huntington-beach-3
# 43  SO1Bn9OYnBx3mQiUnDf3RA                sugar-shack-café-huntington-beach-2
# 44  LsZx58-wAIXWlXPK_6ixuw               da-hawaiian-kitchen-huntington-beach
# 45  Jl_LyKAb_3Iyo32ypIlFNw                      burnt-crumbs-huntington-beach
# 46  g_7S2kgE7NCqPGtvcJcBrg                    the-beachcomber-newport-coast-4
# 47  rPtjhMAidLbgjzYAkc_0zw               surf-city-ale-house-huntington-beach
# 48  NVB2X8t5Rie8S5AnzOnWJg                                north-italia-irvine
#
#                                          name  \
# 0                     Duke's Huntington Beach
# 1                                Mama's On 39
# 2                 Heirloom a Modern Farmhouse
# 3                   Offshore 9 Rooftop Lounge
# 4                                  Watertable
# 5   The Black Trumpet Bistro Tapas & Wine Bar
# 6                         Ola Mexican Kitchen
# 7                     SOCIAL Huntington Beach
# 8                            Pacific Hideaway
# 9                                    Bluegold
# 10                      BLK Earth Sea Spirits
# 11                          Beale's Texas BBQ
# 12                  Henry's Ocean View Dining
# 13                     Capones Italian Cucina
# 14                             Point 11 Grill
# 15                Simmzy's - Huntington Beach
# 16                            The Vox Kitchen
# 17            HQ Gastropub - Huntington Beach
# 18                             Zankou Chicken
# 19                   Puesto- Huntington Beach
# 20                        Sandy's Beach Shack
# 21                                   Slapfish
# 22                                 25 Degrees
# 23                     Bread Crumb Ohana Cafe
# 24                             Wet Dog Tavern
# 25                      Hanki Everyday Korean
# 26                   The Boathouse on the Bay
# 27                         Jay Bird's Chicken
# 28                              Sushi On Fire
# 29                         The American Dream
# 30                          Habachihana Grill
# 31                                     Habana
# 32                        Triple Crown Tavern
# 33                          Matiki Island BBQ
# 34                        The Lighthouse Cafe
# 35                            The Recess Room
# 36            Board & Brew - Huntington Beach
# 37                             Captain Jack's
# 38        Subculture Extraordinary Sandwiches
# 39                              Hartman Elise
# 40                      Beach City Provisions
# 41        Silverlake Ramen - Huntington Beach
# 42               Good Vibes From Soul to Bowl
# 43                           Sugar Shack Café
# 44                        Da Hawaiian Kitchen
# 45                               Burnt Crumbs
# 46                            The Beachcomber
# 47                        Surf City Ale House
# 48                               North Italia
#
#                                             image_url is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/_KInBr...     False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/4PK-bw...     False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/jam7ve...     False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/gsaRYX...     False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/jbtPm-...     False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/FL74C_...     False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/fs55Cq...     False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/ZwQ-K8...     False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/u8_e_I...     False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/D6gaNw...     False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/4TH43N...     False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/Wdj_nN...     False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/JC_cOy...     False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/yzoUKn...     False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/gYN4Vs...     False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/Ec-fjE...     False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/DHupe_...     False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/Vmvq_H...     False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/toCIoR...     False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/RdsY3u...     False
# 20  https://s3-media3.fl.yelpcdn.com/bphoto/AQB_Fk...     False
# 21  https://s3-media1.fl.yelpcdn.com/bphoto/9sJ87H...     False
# 22  https://s3-media2.fl.yelpcdn.com/bphoto/49CZYT...     False
# 23  https://s3-media1.fl.yelpcdn.com/bphoto/qAI9jw...     False
# 24  https://s3-media1.fl.yelpcdn.com/bphoto/ITcjpU...     False
# 25  https://s3-media2.fl.yelpcdn.com/bphoto/xiLWAj...     False
# 26  https://s3-media1.fl.yelpcdn.com/bphoto/KReXyd...     False
# 27  https://s3-media2.fl.yelpcdn.com/bphoto/ErcH-I...     False
# 28  https://s3-media3.fl.yelpcdn.com/bphoto/59HuWR...     False
# 29  https://s3-media2.fl.yelpcdn.com/bphoto/z4fAd9...     False
# 30  https://s3-media3.fl.yelpcdn.com/bphoto/GOBLIX...     False
# 31  https://s3-media1.fl.yelpcdn.com/bphoto/FbOA0S...     False
# 32  https://s3-media2.fl.yelpcdn.com/bphoto/uMHEvY...     False
# 33  https://s3-media2.fl.yelpcdn.com/bphoto/qoeWEK...     False
# 34  https://s3-media1.fl.yelpcdn.com/bphoto/HnhXCq...     False
# 35  https://s3-media2.fl.yelpcdn.com/bphoto/wBXtlx...     False
# 36  https://s3-media3.fl.yelpcdn.com/bphoto/B96uNx...     False
# 37  https://s3-media4.fl.yelpcdn.com/bphoto/l1lRnL...     False
# 38  https://s3-media1.fl.yelpcdn.com/bphoto/0KJmE3...     False
# 39  https://s3-media3.fl.yelpcdn.com/bphoto/4fD3vR...     False
# 40  https://s3-media3.fl.yelpcdn.com/bphoto/Tlgk4b...     False
# 41  https://s3-media3.fl.yelpcdn.com/bphoto/OqqEHG...     False
# 42  https://s3-media2.fl.yelpcdn.com/bphoto/vcOS6v...     False
# 43  https://s3-media3.fl.yelpcdn.com/bphoto/hLKTBV...     False
# 44  https://s3-media1.fl.yelpcdn.com/bphoto/zOUfKj...     False
# 45  https://s3-media3.fl.yelpcdn.com/bphoto/EzqUb_...     False
# 46  https://s3-media4.fl.yelpcdn.com/bphoto/Fr-Qt8...     False
# 47  https://s3-media2.fl.yelpcdn.com/bphoto/OpUo0g...     False
# 48  https://s3-media1.fl.yelpcdn.com/bphoto/hWa52y...     False
#
#                                                   url review_count  \
# 0   https://www.yelp.com/biz/dukes-huntington-beac...         1930
# 1   https://www.yelp.com/biz/mamas-on-39-huntingto...         3454
# 2   https://www.yelp.com/biz/heirloom-a-modern-far...          242
# 3   https://www.yelp.com/biz/offshore-9-rooftop-lo...          109
# 4   https://www.yelp.com/biz/watertable-huntington...          609
# 5   https://www.yelp.com/biz/the-black-trumpet-bis...          961
# 6   https://www.yelp.com/biz/ola-mexican-kitchen-h...         1866
# 7   https://www.yelp.com/biz/social-huntington-bea...          342
# 8   https://www.yelp.com/biz/pacific-hideaway-hunt...          431
# 9   https://www.yelp.com/biz/bluegold-huntington-b...          935
# 10  https://www.yelp.com/biz/blk-earth-sea-spirits...         1126
# 11  https://www.yelp.com/biz/beales-texas-bbq-hunt...         1039
# 12  https://www.yelp.com/biz/henrys-ocean-view-din...           60
# 13  https://www.yelp.com/biz/capones-italian-cucin...          767
# 14  https://www.yelp.com/biz/point-11-grill-huntin...           92
# 15  https://www.yelp.com/biz/simmzys-huntington-be...          787
# 16  https://www.yelp.com/biz/the-vox-kitchen-fount...         4311
# 17  https://www.yelp.com/biz/hq-gastropub-huntingt...          587
# 18  https://www.yelp.com/biz/zankou-chicken-huntin...          148
# 19  https://www.yelp.com/biz/puesto-huntington-bea...          128
# 20  https://www.yelp.com/biz/sandys-beach-shack-hu...          844
# 21  https://www.yelp.com/biz/slapfish-huntington-b...         2476
# 22  https://www.yelp.com/biz/25-degrees-huntington...         1503
# 23  https://www.yelp.com/biz/bread-crumb-ohana-caf...         1269
# 24  https://www.yelp.com/biz/wet-dog-tavern-huntin...          104
# 25  https://www.yelp.com/biz/hanki-everyday-korean...          223
# 26  https://www.yelp.com/biz/the-boathouse-on-the-...         1567
# 27  https://www.yelp.com/biz/jay-birds-chicken-hun...          200
# 28  https://www.yelp.com/biz/sushi-on-fire-hunting...         2099
# 29  https://www.yelp.com/biz/the-american-dream-hu...          700
# 30  https://www.yelp.com/biz/habachihana-grill-hun...           68
# 31  https://www.yelp.com/biz/habana-costa-mesa-3?a...         4342
# 32  https://www.yelp.com/biz/triple-crown-tavern-h...          138
# 33  https://www.yelp.com/biz/matiki-island-bbq-hun...          116
# 34  https://www.yelp.com/biz/the-lighthouse-cafe-n...         1802
# 35  https://www.yelp.com/biz/the-recess-room-fount...         1621
# 36  https://www.yelp.com/biz/board-and-brew-huntin...          321
# 37  https://www.yelp.com/biz/captain-jacks-sunset-...         1481
# 38  https://www.yelp.com/biz/subculture-extraordin...         2011
# 39  https://www.yelp.com/biz/hartman-elise-hunting...            1
# 40  https://www.yelp.com/biz/beach-city-provisions...           19
# 41  https://www.yelp.com/biz/silverlake-ramen-hunt...          686
# 42  https://www.yelp.com/biz/good-vibes-from-soul-...           25
# 43  https://www.yelp.com/biz/sugar-shack-caf%C3%A9...         1299
# 44  https://www.yelp.com/biz/da-hawaiian-kitchen-h...          967
# 45  https://www.yelp.com/biz/burnt-crumbs-huntingt...          610
# 46  https://www.yelp.com/biz/the-beachcomber-newpo...         2506
# 47  https://www.yelp.com/biz/surf-city-ale-house-h...          194
# 48  https://www.yelp.com/biz/north-italia-irvine?a...         3648
#
#                                            categories  rating  \
# 0   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 2   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 3   [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.0
# 4   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 5   [{'alias': 'mediterranean', 'title': 'Mediterr...     4.5
# 6          [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
# 7   [{'alias': 'newamerican', 'title': 'American (...     4.0
# 8   [{'alias': 'newamerican', 'title': 'American (...     4.0
# 9   [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 10  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 11            [{'alias': 'bbq', 'title': 'Barbeque'}]     4.5
# 12  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 13  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 14  [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     5.0
# 15  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.0
# 16  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     4.5
# 17  [{'alias': 'gastropubs', 'title': 'Gastropubs'...     4.0
# 18  [{'alias': 'falafel', 'title': 'Falafel'}, {'a...     4.5
# 19  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.0
# 20  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.0
# 21  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 22  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 23  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 24  [{'alias': 'tradamerican', 'title': 'American ...     4.5
# 25           [{'alias': 'korean', 'title': 'Korean'}]     4.5
# 26  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.0
# 27  [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.5
# 28  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 29  [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 30       [{'alias': 'japanese', 'title': 'Japanese'}]     4.5
# 31  [{'alias': 'cuban', 'title': 'Cuban'}, {'alias...     4.0
# 32  [{'alias': 'newamerican', 'title': 'American (...     5.0
# 33  [{'alias': 'polynesian', 'title': 'Polynesian'...     4.5
# 34  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 35  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.0
# 36  [{'alias': 'beerbar', 'title': 'Beer Bar'}, {'...     4.5
# 37  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 38   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     4.5
# 39  [{'alias': 'restaurants', 'title': 'Restaurant...     5.0
# 40  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 41             [{'alias': 'ramen', 'title': 'Ramen'}]     4.5
# 42  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...     5.0
# 43  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 44       [{'alias': 'hawaiian', 'title': 'Hawaiian'}]     4.5
# 45  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.0
# 46  [{'alias': 'diners', 'title': 'Diners'}, {'ali...     4.0
# 47  [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.5
# 48  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
#
#                                           coordinates  \
# 0   {'latitude': 33.656629, 'longitude': -118.002219}
# 1     {'latitude': 33.65734, 'longitude': -117.98711}
# 2     {'latitude': 33.69601, 'longitude': -117.98834}
# 3      {'latitude': 33.6523, 'longitude': -117.99353}
# 4   {'latitude': 33.651300643275626, 'longitude': ...
# 5   {'latitude': 33.680305, 'longitude': -118.005161}
# 6   {'latitude': 33.6544387, 'longitude': -117.997...
# 7     {'latitude': 33.65495, 'longitude': -117.98796}
# 8   {'latitude': 33.65816560863984, 'longitude': -...
# 9   {'latitude': 33.6551945, 'longitude': -117.998...
# 10  {'latitude': 33.657525, 'longitude': -118.000788}
# 11  {'latitude': 33.724337, 'longitude': -118.0761...
# 12  {'latitude': 33.65308494655343, 'longitude': -...
# 13  {'latitude': 33.6767621, 'longitude': -117.988...
# 14  {'latitude': 33.663790333, 'longitude': -118.0...
# 15  {'latitude': 33.6547675, 'longitude': -117.998...
# 16    {'latitude': 33.72744, 'longitude': -117.95568}
# 17  {'latitude': 33.6580881372787, 'longitude': -1...
# 18    {'latitude': 33.69316, 'longitude': -117.98926}
# 19  {'latitude': 33.732558, 'longitude': -117.992236}
# 20    {'latitude': 33.65596, 'longitude': -118.00135}
# 21  {'latitude': 33.6767007, 'longitude': -117.988...
# 22  {'latitude': 33.658492, 'longitude': -118.001519}
# 23  {'latitude': 33.6853215981096, 'longitude': -1...
# 24  {'latitude': 33.658935, 'longitude': -118.000613}
# 25  {'latitude': 33.7305421, 'longitude': -117.99952}
# 26  {'latitude': 33.7475314086796, 'longitude': -1...
# 27    {'latitude': 33.65868, 'longitude': -117.99952}
# 28  {'latitude': 33.6594426, 'longitude': -117.999...
# 29  {'latitude': 33.6541672717691, 'longitude': -1...
# 30  {'latitude': 33.712248, 'longitude': -117.989534}
# 31  {'latitude': 33.677473708454, 'longitude': -11...
# 32  {'latitude': 33.6719751, 'longitude': -117.990...
# 33  {'latitude': 33.721553, 'longitude': -118.0423...
# 34  {'latitude': 33.608054, 'longitude': -117.922632}
# 35  {'latitude': 33.695703, 'longitude': -117.953787}
# 36  {'latitude': 33.676057, 'longitude': -117.988082}
# 37   {'latitude': 33.71826, 'longitude': -118.070355}
# 38     {'latitude': 33.71513, 'longitude': -117.9905}
# 39     {'latitude': 33.6905, 'longitude': -118.00941}
# 40    {'latitude': 33.69585, 'longitude': -118.04835}
# 41  {'latitude': 33.732551, 'longitude': -117.992236}
# 42  {'latitude': 33.6613951, 'longitude': -117.999...
# 43  {'latitude': 33.6585809201002, 'longitude': -1...
# 44  {'latitude': 33.6720001, 'longitude': -117.956...
# 45    {'latitude': 33.654605, 'longitude': -117.9965}
# 46  {'latitude': 33.57432392026669, 'longitude': -...
# 47  {'latitude': 33.6591751190573, 'longitude': -1...
# 48  {'latitude': 33.67173395544756, 'longitude': -...
#
#                                   transactions price  \
# 0                           [delivery, pickup]    $$
# 1                           [delivery, pickup]    $$
# 2                                   [delivery]    $$
# 3                                   [delivery]   NaN
# 4                                   [delivery]   $$$
# 5                                   [delivery]    $$
# 6           [delivery, restaurant_reservation]    $$
# 7                           [delivery, pickup]    $$
# 8                           [delivery, pickup]    $$
# 9                                   [delivery]   $$$
# 10          [delivery, restaurant_reservation]   $$$
# 11                                  [delivery]    $$
# 12                                  [delivery]   $$$
# 13                          [delivery, pickup]    $$
# 14                                  [delivery]   NaN
# 15                          [delivery, pickup]    $$
# 16  [delivery, restaurant_reservation, pickup]    $$
# 17                          [delivery, pickup]    $$
# 18                          [delivery, pickup]   NaN
# 19                                          []   NaN
# 20                                  [delivery]    $$
# 21                          [delivery, pickup]    $$
# 22                          [delivery, pickup]    $$
# 23                                  [delivery]    $$
# 24                          [delivery, pickup]    $$
# 25                          [delivery, pickup]    $$
# 26          [delivery, restaurant_reservation]    $$
# 27                                          []   NaN
# 28                                  [delivery]    $$
# 29                                  [delivery]    $$
# 30                          [delivery, pickup]   NaN
# 31                          [delivery, pickup]    $$
# 32                                  [delivery]    $$
# 33                          [delivery, pickup]   NaN
# 34  [delivery, restaurant_reservation, pickup]    $$
# 35  [delivery, restaurant_reservation, pickup]    $$
# 36                                  [delivery]     $
# 37                                  [delivery]   $$$
# 38                                  [delivery]     $
# 39                                          []   NaN
# 40                                          []   NaN
# 41                          [delivery, pickup]   NaN
# 42                                          []   NaN
# 43                                          []    $$
# 44                                  [delivery]    $$
# 45                          [delivery, pickup]    $$
# 46                    [restaurant_reservation]    $$
# 47                          [delivery, pickup]    $$
# 48                                  [delivery]    $$
#
#                                              location         phone  \
# 0   {'address1': '317 Pacific Coast Hwy', 'address...  +17143746446
# 1   {'address1': '21022 Beach Blvd', 'address2': '...  +17143741166
# 2   {'address1': '18344 Beach Blvd', 'address2': N...  +17143756543
# 3   {'address1': '21100 Pacific Coast Hwy', 'addre...  +17148458000
# 4   {'address1': '21500 Pacific Coast Hwy', 'addre...  +17148454776
# 5   {'address1': '7041 Yorktown Ave', 'address2': ...  +17148421122
# 6   {'address1': '21040 Pacific Coast Hwy', 'addre...  +17149697300
# 7   {'address1': '21214 Beach Blvd', 'address2': '...  +17143747715
# 8   {'address1': '500 Pacific Coast Hwy', 'address...  +17149654448
# 9   {'address1': '21016 Pacific Coast Hwy', 'addre...  +17143740038
# 10  {'address1': '300 Pacific Coast Hwy', 'address...  +17149600996
# 11  {'address1': '16400 Pacific Coast Hwy', 'addre...  +15625883070
# 12  {'address1': '21100 Pacific Coast Hwy', 'addre...  +17148458450
# 13  {'address1': '19688 Beach Blvd', 'address2': '...  +17145932888
# 14  {'address1': '327 11th St', 'address2': 'Ste 1...  +17149160027
# 15  {'address1': '21028 Pacific Coast Hwy', 'addre...  +17148311240
# 16  {'address1': '16161 Brookhurst St', 'address2'...  +16572316493
# 17  {'address1': '155 5th St', 'address2': None, '...  +17143692155
# 18  {'address1': '18541 Beach Blvd', 'address2': '...  +17145158960
# 19  {'address1': '7821 Edinger Ave', 'address2': '...  +17143160151
# 20  {'address1': '315 Pacific Coast Hwy', 'address...  +17143747273
# 21  {'address1': '19696 Beach Blvd', 'address2': '...  +17149633900
# 22  {'address1': '412 Walnut Ave', 'address2': Non...  +17149602525
# 23  {'address1': '19079 Beach Blvd', 'address2': '...  +17149605051
# 24  {'address1': '221 Main St', 'address2': 'Ste B...  +17145362234
# 25  {'address1': '7451 Edinger Ave', 'address2': '...  +17146224073
# 26  {'address1': '190 N Marina Dr', 'address2': ''...  +15624931100
# 27  {'address1': '303 3rd St', 'address2': 'Ste 10...  +17145943233
# 28  {'address1': '301 Main St', 'address2': 'Ste 1...  +17143748885
# 29  {'address1': '21058 Pacific Coast Hwy', 'addre...  +17143741330
# 30  {'address1': '17221 Beach Blvd', 'address2': '...  +17145890214
# 31  {'address1': '2930 Bristol St', 'address2': 'S...  +17145560176
# 32  {'address1': '714 Adams Ave', 'address2': 'Ste...  +17144659041
# 33  {'address1': '16561 Bolsa Chica St', 'address2...  +17146988225
# 34  {'address1': '1600 W Balboa Blvd', 'address2':...  +19499331001
# 35  {'address1': '18380 Brookhurst St', 'address2'...  +17143770398
# 36  {'address1': '19720 Beach Blvd', 'address2': '...  +17143777100
# 37  {'address1': '16812 Pacific Coast Hwy', 'addre...  +15625922514
# 38  {'address1': '7862 Warner Ave', 'address2': 'S...  +17148471113
# 39  {'address1': '18722 Jockey Cir', 'address2': N...  +15625972378
# 40  {'address1': '17851 Pacific Coast Hwy', 'addre...  +17146984188
# 41  {'address1': '7821 Edinger Ave', 'address2': '...  +17149021055
# 42  {'address1': '501 Main St', 'address2': 'Ste E...  +17145360210
# 43  {'address1': '213 Main St', 'address2': '', 'a...  +17145360355
# 44  {'address1': '9842 Adams Ave', 'address2': 'St...  +17149688900
# 45  {'address1': '21058 Pacific Coast Hwy', 'addre...  +17143740777
# 46  {'address1': '15 Crystal Cv', 'address2': '', ...  +19493766900
# 47  {'address1': '301 Main St', 'address2': 'Ste 1...  +17143692581
# 48  {'address1': '2957 Michelson Dr', 'address2': ...  +19496297060
#
#      display_phone      distance
# 0   (714) 374-6446   4004.463159
# 1   (714) 374-1166   4453.139520
# 2   (714) 375-6543   2231.854979
# 3   (714) 845-8000   4696.751440
# 4   (714) 845-4776   4897.321363
# 5   (714) 842-1122   1408.083691
# 6   (714) 969-7300   4323.404914
# 7   (714) 374-7715   4641.764800
# 8   (714) 965-4448   3821.928874
# 9   (714) 374-0038   4239.182568
# 10  (714) 960-0996   3936.150232
# 11  (562) 588-3070   6977.861717
# 12  (714) 845-8450   4587.713352
# 13  (714) 593-2888   2854.055511
# 14  (714) 916-0027   3159.263745
# 15  (714) 831-1240   4292.867489
# 16  (657) 231-6493   6504.805501
# 17  (714) 369-2155   3832.416945
# 18  (714) 515-8960   2085.279537
# 19  (714) 316-0151   4890.998865
# 20  (714) 374-7273   4016.040974
# 21  (714) 963-3900   2862.203327
# 22  (714) 960-2525   3815.052798
# 23  (714) 960-5051   2084.527204
# 24  (714) 536-2234   3790.704530
# 25  (714) 622-4073   4459.519110
# 26  (562) 493-1100  11423.687920
# 27  (714) 594-3233   3842.134254
# 28  (714) 374-8885   3754.609278
# 29  (714) 374-1330   4395.892425
# 30  (714) 589-0214   3066.224932
# 31  (714) 556-0176  11760.934717
# 32  (714) 465-9041   2986.283601
# 33  (714) 698-8225   4359.172609
# 34  (949) 933-1001  12432.343202
# 35  (714) 377-0398   5376.292080
# 36  (714) 377-7100   2793.772084
# 37  (562) 592-2514   6173.350938
# 38  (714) 847-1113   3255.338546
# 39  (562) 597-2378    248.151328
# 40  (714) 698-4188   3292.016203
# 41  (714) 902-1055   4890.998865
# 42  (714) 536-0210   3551.378280
# 43  (714) 536-0355   3821.373158
# 44  (714) 968-8900   5556.637326
# 45  (714) 374-0777   4362.139365
# 46  (949) 376-6900  20549.942561
# 47  (714) 369-2581   3773.059157
# 48  (949) 629-7060  15571.715619

# %%
data.count()
# Out:
# id               50
# alias            50
# name             50
# image_url        50
# is_closed        50
# url              50
# review_count     50
# categories       50
# rating           50
# coordinates      50
# transactions     50
# price            39
# location         50
# phone            50
# display_phone    50
# distance         50
# dtype: int64

# %%
print(data.location[0])
# Out:
# {'address1': '14370 Culver Dr', 'address2': 'Unit 2H', 'address3': '', 'city': 'Irvine', 'zip_code': '92604', 'country': 'US', 'state': 'CA', 'display_address': ['14370 Culver Dr', 'Unit 2H', 'Irvine, CA 92604']}

# %%
# Out:
# {'error': {'code': 'VALIDATION_ERROR', 'description': 'Authorization is a required parameter.', 'field': 'Authorization', 'instance': None}}
