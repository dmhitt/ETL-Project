# %%
#dependencies
import requests
import json
import pandas as pd

# Google developer API key
from config import gkey

# %%
restaurants = pd.read_csv("restaurants3.csv")
df=pd.DataFrame(restaurants)
df
# Out:
#                                 name                     place_id
# 0    Olive Garden Italian Restaurant  ChIJDbFMCzPc3IARRxMp3wxdPZI
# 1              Rubio's Coastal Grill  ChIJb74NDIDe3IAR4yBcZK1S5sc
# 2                      Corner Bakery  ChIJY0_ZGIDe3IARvc542OqLQ18
# 3                Chili's Grill & Bar  ChIJj7w0CjPc3IAR5vgvTUiOc5Y
# 4                          Boudin SF  ChIJyaIKPYTe3IARfmhSAvGyCFM
# ..                               ...                          ...
# 111                     Harry's Cafe  ChIJz_6Qi_wl3YARHgbNp1plmp8
# 112                           Subway  ChIJH4KBdyon3YAR5YPiKYgO4i8
# 113                  In-N-Out Burger  ChIJQfmLI1ff3IARmz2onB6YoqM
# 114                          Mi Casa  ChIJ1y0U5PLf3IARLMW7NsL2gYs
# 115                           Subway  ChIJh4ZLX30m3YARzbQog51Vslc
#
# [116 rows x 2 columns]

# %%
#Dinnara

first_time = True

for index,row in df.iterrows():
    place = row['place_id']
    target_placeid = place
    target_fields = "name,rating,vicinity,reviews"
    #set up a parameters dictionary
    params = {
        "place_id": target_placeid,
        "fields": target_fields,
        "key": gkey}

    #URL for GET requests to retrieve restaurant data
    url="https://maps.googleapis.com/maps/api/place/details/json"
    # run a request using our params dictionary
    response = requests.get(url, params=params)
    restaurants_data=response.json()
    #print(json.dumps(restaurants_data, indent=4, sort_keys=True))
    
    if first_time:
        cols = ['name', 'author_name', 'author_url', 'rating','relative_time_description','text','time']
        data_google = pd.DataFrame(columns=cols)
        first_time = False


    name = restaurants_data['result']['name']
    #print(name)
    try:
        for resp in restaurants_data['result']['reviews']:
            my_row = {"name": name,
                      "author_name":resp['author_name'],
                      "author_url":resp['author_url'],
                      "rating":resp['rating'],
                      "relative_time_description":resp['relative_time_description'],
                      "text":resp['text'],
                      "time":resp['time']}
            data_google=data_google.append(my_row, ignore_index=True)
            my_row.clear()

    except (KeyError, IndexError):
            print("Missing field/reviews... skipping.")
# Out:
# Missing field/reviews... skipping.
# Missing field/reviews... skipping.

# %%
#Dinnara
data_google.tail(30)
# Out:
#                 name        author_name  \
# 523    The Donuttery  Cassandra Eguiluz
# 524    The Donuttery          Red Curls
# 525    The Donuttery      Jacqui Foster
# 526    The Donuttery       Gina Hermosa
# 527    The Donuttery          Ruby Raze
# 528     Harry's Cafe            Casey F
# 529     Harry's Cafe      Evelyn Amador
# 530     Harry's Cafe    Paige Colquette
# 531     Harry's Cafe      Debbie Thomas
# 532     Harry's Cafe    Kristin Roberts
# 533           Subway                L T
# 534           Subway    Jamie Ainsworth
# 535           Subway           JC Rules
# 536           Subway         Tony Adams
# 537           Subway        Billy Merrz
# 538  In-N-Out Burger             Adrian
# 539  In-N-Out Burger       allie Conway
# 540  In-N-Out Burger        Josh Fisher
# 541  In-N-Out Burger  Estefany Calderon
# 542  In-N-Out Burger            Angie S
# 543          Mi Casa         Mel Bellah
# 544          Mi Casa        Ashley Hook
# 545          Mi Casa       Juan Alvarez
# 546          Mi Casa               Mike
# 547          Mi Casa    Katie Thierjung
# 548           Subway            Godzuki
# 549           Subway           Aaron HB
# 550           Subway            Alisa M
# 551           Subway       Tracy Randol
# 552           Subway              HB CZ
#
#                                             author_url rating  \
# 523  https://www.google.com/maps/contrib/1018846845...      5
# 524  https://www.google.com/maps/contrib/1037760776...      5
# 525  https://www.google.com/maps/contrib/1035312428...      5
# 526  https://www.google.com/maps/contrib/1182882337...      5
# 527  https://www.google.com/maps/contrib/1033725766...      5
# 528  https://www.google.com/maps/contrib/1004677942...      5
# 529  https://www.google.com/maps/contrib/1087307572...      5
# 530  https://www.google.com/maps/contrib/1149345749...      5
# 531  https://www.google.com/maps/contrib/1023703634...      2
# 532  https://www.google.com/maps/contrib/1089408426...      5
# 533  https://www.google.com/maps/contrib/1051201596...      1
# 534  https://www.google.com/maps/contrib/1104330641...      5
# 535  https://www.google.com/maps/contrib/1073818841...      5
# 536  https://www.google.com/maps/contrib/1025800716...      5
# 537  https://www.google.com/maps/contrib/1013692642...      5
# 538  https://www.google.com/maps/contrib/1048368501...      5
# 539  https://www.google.com/maps/contrib/1111427533...      2
# 540  https://www.google.com/maps/contrib/1108538929...      5
# 541  https://www.google.com/maps/contrib/1158327856...      5
# 542  https://www.google.com/maps/contrib/1092256086...      4
# 543  https://www.google.com/maps/contrib/1078016744...      5
# 544  https://www.google.com/maps/contrib/1156197274...      4
# 545  https://www.google.com/maps/contrib/1178829320...      5
# 546  https://www.google.com/maps/contrib/1007016533...      5
# 547  https://www.google.com/maps/contrib/1158417433...      5
# 548  https://www.google.com/maps/contrib/1070053339...      4
# 549  https://www.google.com/maps/contrib/1070466686...      1
# 550  https://www.google.com/maps/contrib/1035392687...      4
# 551  https://www.google.com/maps/contrib/1146287560...      4
# 552  https://www.google.com/maps/contrib/1090240624...      1
#
#     relative_time_description  \
# 523               3 weeks ago
# 524                a week ago
# 525                a week ago
# 526              9 months ago
# 527               a month ago
# 528               a month ago
# 529               a month ago
# 530          in the last week
# 531              8 months ago
# 532              2 months ago
# 533               3 weeks ago
# 534              3 months ago
# 535                a year ago
# 536              2 months ago
# 537             10 months ago
# 538              9 months ago
# 539              2 months ago
# 540               a month ago
# 541              3 months ago
# 542               a month ago
# 543               3 weeks ago
# 544                a week ago
# 545              9 months ago
# 546               2 weeks ago
# 547              4 months ago
# 548               a month ago
# 549                a year ago
# 550                a year ago
# 551              6 months ago
# 552                a year ago
#
#                                                   text        time
# 523  I will always 5 star here! You cannot miss wit...  1621276332
# 524  This was our first time here. There was a huge...  1622524607
# 525  This place has amazing Donuts! My two favorite...  1622699574
# 526  So many vegan donuts! And usually, vegan donut...  1599939655
# 527  These donuts were amazing! The staff we had wa...  1619560694
# 528  Friendly staff. Lots of regular people get the...  1620952627
# 529  Great food! Wonderful friendly service! Huge h...  1618768435
# 530  Home style cooking at its best! Have some more...  1623442596
# 531  This place is changing...  Usually a 5 star pl...  1602604048
# 532   Good food. Friendly courteous service and staff.  1616970870
# 533  Terrible service today. Girl working the regis...  1621713245
# 534  The nicest people at any subway ever!  So cari...  1613252625
# 535  One of the best, if not the best, subways I’ve...  1567527686
# 536                  Not the closest but my fav Subway  1618118710
# 537  Go to this one rather than the others that may...  1597171522
# 538  Can never go wrong, always a great experience ...  1600118269
# 539  The whole experience was a mess. They made my ...  1616542562
# 540  Shout out to Travis working the counter tonigh...  1619074107
# 541  Busy but worth the wait! Delicious classic bur...  1614489670
# 542  My coworkers rave about this place so I finall...  1619654083
# 543  The food was so yummy. It was so fresh and hot...  1621619537
# 544  Overall I always love the food. Great quality....  1622412079
# 545  Great place to eat Now that they have out pati...  1598851302
# 546  Excellent hard shell chicken tacos - probably ...  1622075555
# 547  Ordered dinner for takeaway last night and I w...  1612245263
# 548  I have 3 Subway locations within 1 mile of me....  1619639203
# 549  Just trying to do our part in supporting local...  1587757412
# 550  They are very nice at this Subway.  They make ...  1576108373
# 551                           Sandy is always great!!!  1606260196
# 552  Ordered online, waited 15 minutes then headed ...  1581091921

# %%
#Dinnara
data_google.count()
# Out:
# name                         553
# author_name                  553
# author_url                   553
# rating                       553
# relative_time_description    553
# text                         553
# time                         553
# dtype: int64

# %%
first_time = True

#target_fields=address_component,name,geometry
target_placeid="ChIJY0_ZGIDe3IARvc542OqLQ18" 
target_fields="name,rating,vicinity,reviews"
#set up a parameters dictionary
params = {
    "place_id": target_placeid,
    "fields": target_fields,
    "key": gkey}

#URL for GET requests to retrieve restaurant data
url="https://maps.googleapis.com/maps/api/place/details/json"
# run a request using our params dictionary
response = requests.get(url, params=params)
restaurants_data=response.json()
print(json.dumps(restaurants_data, indent=4, sort_keys=True))

if first_time:
    cols = ['name', 'author_name', 'author_url', 'rating','relative_time_description','text','time']
    data_google = pd.DataFrame(columns=cols)
    first_time = False


name = restaurants_data['result']['name']
#rating = restaurants_data['result']['rating']
#reviews_customers = restaurants_data['result']['reviews']
#address = restaurants_data['result']['vicinity']


for resp in restaurants_data['result']['reviews']:
        
    my_row = {"name": name,
              "author_name":resp['author_name'],
              "author_url":resp['author_url'],
              "rating":resp['rating'],
              "relative_time_description":resp['relative_time_description'],
              "text":resp['text'],
              "time":resp['time']}
                              
       
    data_google=data_google.append(my_row, ignore_index=True)
    my_row.clear()
# Out:
# {
#     "html_attributions": [],
#     "result": {
#         "name": "Corner Bakery",
#         "rating": 4.1,
#         "reviews": [
#             {
#                 "author_name": "Vaibhav Kumar",
#                 "author_url": "https://www.google.com/maps/contrib/113383002468079500538/reviews",
#                 "language": "en",
#                 "profile_photo_url": "https://lh3.googleusercontent.com/a-/AOh14GiU_q8kq01scb_tf6FVbvs9mwwkNywUSDjxbWlhJQ=s128-c0x00000000-cc-rp-mo-ba4",
#                 "rating": 5,
#                 "relative_time_description": "2 months ago",
#                 "text": "I missed taking pictures..my bad but this is a fine bakery place. I had one croissant and one Brownie. They both were amazing. I probably never had such an amazing croissant. When they say bakery is in house. They mean it. I even had an ice tea and it was okay. Nothing fantastic. Also they don't put sugar in ice tea - if that's something which concerns you..",
#                 "time": 1616705990
#             },
#             {
#                 "author_name": "Hugo Olivares",
#                 "author_url": "https://www.google.com/maps/contrib/115211457431937123121/reviews",
#                 "language": "en",
#                 "profile_photo_url": "https://lh3.googleusercontent.com/a/AATXAJwRIq0DntXWY1f1jL3iP5BRL3CFcoRBJbFtNIqf=s128-c0x00000000-cc-rp-mo",
#                 "rating": 5,
#                 "relative_time_description": "9 months ago",
#                 "text": "Clean",
#                 "time": 1598569497
#             },
#             {
#                 "author_name": "Faith Bowman",
#                 "author_url": "https://www.google.com/maps/contrib/116417088858078109636/reviews",
#                 "language": "en",
#                 "profile_photo_url": "https://lh3.googleusercontent.com/a-/AOh14GiQWTv_sDRasR_DaXU4B9LJ9JCCYlRDgW4NxjA8=s128-c0x00000000-cc-rp-mo",
#                 "rating": 1,
#                 "relative_time_description": "4 months ago",
#                 "text": "Food was good, service was not! Ordering originally was fine but when waiting for our food to the left of the soda machine we were told very rudely to move by an employee so people could get through (the place was dead and it\u2019s not like you can sit down because all seating was closed due to covid19). Then I noticed a picture saying free coffee for members, so naturally I downloaded the app to receive the offer but when I walked up to claim the offer the cashier was on a phone/tablet....I assumed maybe for doordash but it was a few minutes later that she finally asked what I wanted and I pointed to the sign and showed her the corner bakery account I just made and said I don\u2019t qualify for the offer. She didn\u2019t look up my account number or anything. Needless to say I will stick to using corner bakery south coast on lunch break than this one. (Went the following week to south coast location to try to claim the free cold brew and the lady didn\u2019t even ask to see my app and kindly handed me my beverage which was amazing!!!)",
#                 "time": 1611957236
#             },
#             {
#                 "author_name": "Ruby Godinez",
#                 "author_url": "https://www.google.com/maps/contrib/108662320427220881845/reviews",
#                 "language": "en",
#                 "profile_photo_url": "https://lh3.googleusercontent.com/a/AATXAJzv1ZNWSTrazO-BdVyqWAqG9IUQmBUT0LFRvPTU=s128-c0x00000000-cc-rp-mo",
#                 "rating": 5,
#                 "relative_time_description": "3 weeks ago",
#                 "text": "I am sooo happy this place has reopened\ud83d\ude0a. Love the crunch raisin bread and love the cheddar cheese broccoli soup. I will be back soon.\ud83d\ude0a",
#                 "time": 1621531469
#             },
#             {
#                 "author_name": "Flora Fuller",
#                 "author_url": "https://www.google.com/maps/contrib/101584939908463442601/reviews",
#                 "language": "en",
#                 "profile_photo_url": "https://lh3.googleusercontent.com/a/AATXAJzU-CN3mGwwcl6VWzOpnnElIfu8lWPYmFnvzmjn=s128-c0x00000000-cc-rp-mo",
#                 "rating": 4,
#                 "relative_time_description": "in the last week",
#                 "text": "Delicious chicken bacon panini, cobb salad was fresh with the delicious dressing.   My favorite was raisin Pecan crisps. Couldn't stop eating them.",
#                 "time": 1623417664
#             }
#         ],
#         "vicinity": "17575 Harvard Avenue Ste A, Irvine"
#     },
#     "status": "OK"
# }

# %%
#pd.set_option('display.max_colwidth', -1)
data_google.head()
# Out:
#             name    author_name  \
# 0  Corner Bakery  Vaibhav Kumar
# 1  Corner Bakery  Hugo Olivares
# 2  Corner Bakery   Faith Bowman
# 3  Corner Bakery   Ruby Godinez
# 4  Corner Bakery   Flora Fuller
#
#                                           author_url rating  \
# 0  https://www.google.com/maps/contrib/1133830024...      5
# 1  https://www.google.com/maps/contrib/1152114574...      5
# 2  https://www.google.com/maps/contrib/1164170888...      1
# 3  https://www.google.com/maps/contrib/1086623204...      5
# 4  https://www.google.com/maps/contrib/1015849399...      4
#
#   relative_time_description  \
# 0              2 months ago
# 1              9 months ago
# 2              4 months ago
# 3               3 weeks ago
# 4          in the last week
#
#                                                 text        time
# 0  I missed taking pictures..my bad but this is a...  1616705990
# 1                                              Clean  1598569497
# 2  Food was good, service was not! Ordering origi...  1611957236
# 3  I am sooo happy this place has reopened😊. Love...  1621531469
# 4  Delicious chicken bacon panini, cobb salad was...  1623417664

# %%
#target_fields=address_component,name,geometry
target_placeid="ChIJY0_ZGIDe3IARvc542OqLQ18" 
target_fields="name,rating,vicinity,reviews"
#set up a parameters dictionary
params = {
    "place_id": target_placeid,
    "fields": target_fields,
    "key": gkey}

#URL for GET requests to retrieve restaurant data
url="https://maps.googleapis.com/maps/api/place/details/json"
# run a request using our params dictionary
response = requests.get(url, params=params)
restaurants_data=response.json()
print(json.dumps(restaurants_data, indent=4, sort_keys=True))
#print(restaurants_data)
# Out:
# {
#     "html_attributions": [],
#     "result": {
#         "name": "Corner Bakery",
#         "rating": 4.1,
#         "reviews": [
#             {
#                 "author_name": "Vaibhav Kumar",
#                 "author_url": "https://www.google.com/maps/contrib/113383002468079500538/reviews",
#                 "language": "en",
#                 "profile_photo_url": "https://lh3.googleusercontent.com/a-/AOh14GiU_q8kq01scb_tf6FVbvs9mwwkNywUSDjxbWlhJQ=s128-c0x00000000-cc-rp-mo-ba4",
#                 "rating": 5,
#                 "relative_time_description": "2 months ago",
#                 "text": "I missed taking pictures..my bad but this is a fine bakery place. I had one croissant and one Brownie. They both were amazing. I probably never had such an amazing croissant. When they say bakery is in house. They mean it. I even had an ice tea and it was okay. Nothing fantastic. Also they don't put sugar in ice tea - if that's something which concerns you..",
#                 "time": 1616705990
#             },
#             {
#                 "author_name": "Hugo Olivares",
#                 "author_url": "https://www.google.com/maps/contrib/115211457431937123121/reviews",
#                 "language": "en",
#                 "profile_photo_url": "https://lh3.googleusercontent.com/a/AATXAJwRIq0DntXWY1f1jL3iP5BRL3CFcoRBJbFtNIqf=s128-c0x00000000-cc-rp-mo",
#                 "rating": 5,
#                 "relative_time_description": "9 months ago",
#                 "text": "Clean",
#                 "time": 1598569497
#             },
#             {
#                 "author_name": "Faith Bowman",
#                 "author_url": "https://www.google.com/maps/contrib/116417088858078109636/reviews",
#                 "language": "en",
#                 "profile_photo_url": "https://lh3.googleusercontent.com/a-/AOh14GiQWTv_sDRasR_DaXU4B9LJ9JCCYlRDgW4NxjA8=s128-c0x00000000-cc-rp-mo",
#                 "rating": 1,
#                 "relative_time_description": "4 months ago",
#                 "text": "Food was good, service was not! Ordering originally was fine but when waiting for our food to the left of the soda machine we were told very rudely to move by an employee so people could get through (the place was dead and it\u2019s not like you can sit down because all seating was closed due to covid19). Then I noticed a picture saying free coffee for members, so naturally I downloaded the app to receive the offer but when I walked up to claim the offer the cashier was on a phone/tablet....I assumed maybe for doordash but it was a few minutes later that she finally asked what I wanted and I pointed to the sign and showed her the corner bakery account I just made and said I don\u2019t qualify for the offer. She didn\u2019t look up my account number or anything. Needless to say I will stick to using corner bakery south coast on lunch break than this one. (Went the following week to south coast location to try to claim the free cold brew and the lady didn\u2019t even ask to see my app and kindly handed me my beverage which was amazing!!!)",
#                 "time": 1611957236
#             },
#             {
#                 "author_name": "Ruby Godinez",
#                 "author_url": "https://www.google.com/maps/contrib/108662320427220881845/reviews",
#                 "language": "en",
#                 "profile_photo_url": "https://lh3.googleusercontent.com/a/AATXAJzv1ZNWSTrazO-BdVyqWAqG9IUQmBUT0LFRvPTU=s128-c0x00000000-cc-rp-mo",
#                 "rating": 5,
#                 "relative_time_description": "3 weeks ago",
#                 "text": "I am sooo happy this place has reopened\ud83d\ude0a. Love the crunch raisin bread and love the cheddar cheese broccoli soup. I will be back soon.\ud83d\ude0a",
#                 "time": 1621531469
#             },
#             {
#                 "author_name": "Flora Fuller",
#                 "author_url": "https://www.google.com/maps/contrib/101584939908463442601/reviews",
#                 "language": "en",
#                 "profile_photo_url": "https://lh3.googleusercontent.com/a/AATXAJzU-CN3mGwwcl6VWzOpnnElIfu8lWPYmFnvzmjn=s128-c0x00000000-cc-rp-mo",
#                 "rating": 4,
#                 "relative_time_description": "in the last week",
#                 "text": "Delicious chicken bacon panini, cobb salad was fresh with the delicious dressing.   My favorite was raisin Pecan crisps. Couldn't stop eating them.",
#                 "time": 1623417664
#             }
#         ],
#         "vicinity": "17575 Harvard Avenue Ste A, Irvine"
#     },
#     "status": "OK"
# }

# %%
print(restaurants_data['result']['name'])
# Out:
# Corner Bakery

# %%
print(restaurants_data['result']['rating'])
# Out:
# 4.1

# %%
print(restaurants_data['result']['reviews'])
# Out:
# [{'author_name': 'Vaibhav Kumar', 'author_url': 'https://www.google.com/maps/contrib/113383002468079500538/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14GiU_q8kq01scb_tf6FVbvs9mwwkNywUSDjxbWlhJQ=s128-c0x00000000-cc-rp-mo-ba4', 'rating': 5, 'relative_time_description': '2 months ago', 'text': "I missed taking pictures..my bad but this is a fine bakery place. I had one croissant and one Brownie. They both were amazing. I probably never had such an amazing croissant. When they say bakery is in house. They mean it. I even had an ice tea and it was okay. Nothing fantastic. Also they don't put sugar in ice tea - if that's something which concerns you..", 'time': 1616705990}, {'author_name': 'Hugo Olivares', 'author_url': 'https://www.google.com/maps/contrib/115211457431937123121/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/a/AATXAJwRIq0DntXWY1f1jL3iP5BRL3CFcoRBJbFtNIqf=s128-c0x00000000-cc-rp-mo', 'rating': 5, 'relative_time_description': '9 months ago', 'text': 'Clean', 'time': 1598569497}, {'author_name': 'Faith Bowman', 'author_url': 'https://www.google.com/maps/contrib/116417088858078109636/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14GiQWTv_sDRasR_DaXU4B9LJ9JCCYlRDgW4NxjA8=s128-c0x00000000-cc-rp-mo', 'rating': 1, 'relative_time_description': '4 months ago', 'text': 'Food was good, service was not! Ordering originally was fine but when waiting for our food to the left of the soda machine we were told very rudely to move by an employee so people could get through (the place was dead and it’s not like you can sit down because all seating was closed due to covid19). Then I noticed a picture saying free coffee for members, so naturally I downloaded the app to receive the offer but when I walked up to claim the offer the cashier was on a phone/tablet....I assumed maybe for doordash but it was a few minutes later that she finally asked what I wanted and I pointed to the sign and showed her the corner bakery account I just made and said I don’t qualify for the offer. She didn’t look up my account number or anything. Needless to say I will stick to using corner bakery south coast on lunch break than this one. (Went the following week to south coast location to try to claim the free cold brew and the lady didn’t even ask to see my app and kindly handed me my beverage which was amazing!!!)', 'time': 1611957236}, {'author_name': 'Ruby Godinez', 'author_url': 'https://www.google.com/maps/contrib/108662320427220881845/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/a/AATXAJzv1ZNWSTrazO-BdVyqWAqG9IUQmBUT0LFRvPTU=s128-c0x00000000-cc-rp-mo', 'rating': 5, 'relative_time_description': '3 weeks ago', 'text': 'I am sooo happy this place has reopened😊. Love the crunch raisin bread and love the cheddar cheese broccoli soup. I will be back soon.😊', 'time': 1621531469}, {'author_name': 'Flora Fuller', 'author_url': 'https://www.google.com/maps/contrib/101584939908463442601/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/a/AATXAJzU-CN3mGwwcl6VWzOpnnElIfu8lWPYmFnvzmjn=s128-c0x00000000-cc-rp-mo', 'rating': 4, 'relative_time_description': 'in the last week', 'text': "Delicious chicken bacon panini, cobb salad was fresh with the delicious dressing.   My favorite was raisin Pecan crisps. Couldn't stop eating them.", 'time': 1623417664}]

# %%
print(restaurants_data['result']['vicinity'])
# Out:
# 17575 Harvard Avenue Ste A, Irvine

# %%
restaurants_data.keys()
# Out:
# dict_keys(['html_attributions', 'result', 'status'])

# %%
restaurants_data['result'].keys()
# Out:
# dict_keys(['name', 'rating', 'reviews', 'vicinity'])

# %%
restaurants_data['result']['reviews'][0].keys()
# Out:
# dict_keys(['author_name', 'author_url', 'language', 'profile_photo_url', 'rating', 'relative_time_description', 'text', 'time'])

# %%
cols = list(restaurants_data['result'].keys())

# %%
print(cols)
# Out:
# ['name', 'rating', 'reviews', 'vicinity']

# %%
data_google = pd.DataFrame(columns=cols)

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJY0_ZGIDe3IARvc542OqLQ18&fields=name%2Crating%2Cvicinity%2Creviews&key=AIzaSyBzyFnYZltJKc9RAbuaH8ezzvFQfIDcnXk

# %%
restaurants_data=response.json()

# %%
# Print the json (pretty printed)
#print(json.dumps(restaurants_data, indent=4, sort_keys=True))

# %%
#restaurants_data.keys()

# %%
#restaurants_data['result'].keys()

# %%
result_ready=restaurants_data['result']
for item in result_ready.keys():
    print(item)
    print
# Out:
# name
# rating
# reviews
# vicinity

# %%
restaurants_data['html_attributions']
# Out:
# []

# %%
restaurants_data['status']
# Out:
# 'OK'

# %%
type(restaurants_data)
# Out:
# dict

# %%
result_ready  = restaurants_data['result']
type(result_ready)
# Out:
# dict

# %%
#cols = list(restaurants_data['result'][0].keys())
df = pd.DataFrame(result_ready)
df.head()
# Out:
#             name  rating                                            reviews  \
# 0  Corner Bakery     4.1  {'author_name': 'Vaibhav Kumar', 'author_url':...
# 1  Corner Bakery     4.1  {'author_name': 'Hugo Olivares', 'author_url':...
# 2  Corner Bakery     4.1  {'author_name': 'Faith Bowman', 'author_url': ...
# 3  Corner Bakery     4.1  {'author_name': 'Ruby Godinez', 'author_url': ...
# 4  Corner Bakery     4.1  {'author_name': 'Flora Fuller', 'author_url': ...
#
#                              vicinity
# 0  17575 Harvard Avenue Ste A, Irvine
# 1  17575 Harvard Avenue Ste A, Irvine
# 2  17575 Harvard Avenue Ste A, Irvine
# 3  17575 Harvard Avenue Ste A, Irvine
# 4  17575 Harvard Avenue Ste A, Irvine
